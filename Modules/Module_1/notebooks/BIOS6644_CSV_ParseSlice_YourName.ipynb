# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangling Footballer Names Data
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_Fottballer_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub push
#
##################################################################################################################

# %% [markdown]
# # Python used in this exercise
# - File Input/Output
# - for loop
# - list
#     - list methods:
#         - join()
#     - list comprehension
# - string
#     - string methods
#         - split()
#         - strip()
#         - slice

# %%
# Python stuff used here:


the_things = [1, 2, 'A', "B", 9.4, set([1,2])]

# for loops repeat code once for each thing in the_things
for this_thing in the_things:
    print('The current thing is: ', this_thing)
# Out:
# The current thing is:  1
# The current thing is:  2
# The current thing is:  A
# The current thing is:  B
# The current thing is:  9.4
# The current thing is:  {1, 2}

# %%
# Strings can be "split" into a list, on a boundary marker which you provide
string2split = '''Hello.  My name is Inigo Montoya. You killed my brother.  Prepare to die'''
print(string2split)

# split on "." 
# Note that a list of strings is returned.
# and that the split boundary character is removed.
string2split.split(".")
# Out:
# Hello.  My name is Inigo Montoya. You killed my brother.  Prepare to die
# ['Hello',
#  '  My name is Inigo Montoya',
#  ' You killed my brother',
#  '  Prepare to die']

# %%
# Mini wrangle goals:
#  1) remove stray space characters
#  2) Correct "brother" to be "father"
#  3) Write as 4 sentences, returning the "." characters

for chunk in string2split.split("."):
    print(chunk)
    chunk=chunk.strip()
    print(chunk) # strip removes whitespace from the ends

    chunk = chunk.replace('brother', 'father')
    print(chunk+'.')
# Out:
# Hello
# Hello
# Hello.
#   My name is Inigo Montoya
# My name is Inigo Montoya
# My name is Inigo Montoya.
#  You killed my brother
# You killed my brother
# You killed my father.
#   Prepare to die
# Prepare to die
# Prepare to die.

# %%
for chunk in string2split.split("."):
    chunk=chunk.strip()

    chunk = chunk.replace('brother', 'father')
    print(chunk+'.')
# Out:
# Hello.
# My name is Inigo Montoya.
# You killed my father.
# Prepare to die.

# %%
#A different approach using a for-loop shortcut called
#    a List Comprehension
output = [xx.strip().replace("brother", "father") for xx in string2split.split(".")]
print(output)

print('.\n'.join(output))
# Out:
# ['Hello', 'My name is Inigo Montoya', 'You killed my father', 'Prepare to die']
# Hello.
# My name is Inigo Montoya.
# You killed my father.
# Prepare to die

# %%
# as a 1-liner
print('.\n'.join([xx.strip().replace("brother", "father") for xx in string2split.split(".")]))
# Out:
# Hello.
# My name is Inigo Montoya.
# You killed my father.
# Prepare to die

# %% [markdown]
# # Wrangling Footballer Names

# %%
# Goal: extract footballer's names into format Last, First, other & discard
#  other data
#
# General info & data here:
#   https://www.kaggle.com/datasets/maso0dahmed/football-players-data
#
# I unzipped mine put it in the data folder
data = '../data/fifa_players.csv'

# %%
#read data
with open(data,'r') as thefile:
    lines = thefile.readlines()

# %%
test_line = lines[33]
header = lines[0]
print(header, test_line)
# Out:
# name,full_name,birth_date,age,height_cm,weight_kgs,positions,nationality,overall_rating,potential,value_euro,wage_euro,preferred_foot,international_reputation(1-5),weak_foot(1-5),skill_moves(1-5),body_type,release_clause_euro,national_team,national_rating,national_team_position,national_jersey_number,crossing,finishing,heading_accuracy,short_passing,volleys,dribbling,curve,freekick_accuracy,long_passing,ball_control,acceleration,sprint_speed,agility,reactions,balance,shot_power,jumping,stamina,strength,long_shots,aggression,interceptions,positioning,vision,penalties,composure,marking,standing_tackle,sliding_tackle
#  Kepa,Kepa Arrizabalaga,10/3/1994,24,185.42,84.8,GK,Spain,84,90,31000000,92000,Right,1,4,1,Lean,63600000,Spain,85,SUB,13,25,11,17,32,18,10,25,19,36,16,34,33,41,79,39,25,71,37,51,14,18,21,15,55,24,63,19,18,16

# %%
# Notice that the player name is in the 2nd field (field 1)
# The string split(',') method divides a string into a list of strings, 
# breaking on commas. 
print(test_line.split(','))
# Out:
# ['Kepa', 'Kepa Arrizabalaga', '10/3/1994', '24', '185.42', '84.8', 'GK', 'Spain', '84', '90', '31000000', '92000', 'Right', '1', '4', '1', 'Lean', '63600000', 'Spain', '85', 'SUB', '13', '25', '11', '17', '32', '18', '10', '25', '19', '36', '16', '34', '33', '41', '79', '39', '25', '71', '37', '51', '14', '18', '21', '15', '55', '24', '63', '19', '18', '16\n']

# %%
test_line.split(',')[1]  # split and grab position-1 entry
# Out:
# 'Kepa Arrizabalaga'

# %%
# Split the name up into a list
test_line.split(',')[1].split(' ')
# Out:
# ['Kepa', 'Arrizabalaga']

# %%
# Save the names as split so we can re-arrange them
name_list = test_line.split(',')[1].split(' ')
print(name_list)
# Out:
# ['Kepa', 'Arrizabalaga']

# %%
# Re-arrange them
print(name_list[1], name_list[0])
# Out:
# Arrizabalaga Kepa

# %%
# Add a comma
print(name_list[1]+ ', ' +name_list[0])
# Out:
# Arrizabalaga, Kepa

# %%
for this_player in lines:
    name_list = this_player.split(',')[1].split(' ')
    print(name_list)
# Out:
# ['full_name']
# ['Lionel', 'Andrés', 'Messi', 'Cuccittini']
# ['Christian', '', 'Dannemann', 'Eriksen']
# ['Paul', 'Pogba']
# ['Lorenzo', 'Insigne']
# ['Kalidou', 'Koulibaly']
# ['Virgil', 'van', 'Dijk']
# ['Kylian', 'Mbappé']
# ['Sergio', 'Leonel', 'Agüero', 'del', 'Castillo']
# ['Manuel', 'Neuer']
# ['Edinson', 'Roberto', 'Cavani', 'Gómez']
# ['Sergio', 'Busquets', 'i', 'Burgos']
# ['Thibaut', 'Courtois']
# ['Marc-André', 'ter', 'Stegen']
# ['Antoine', 'Griezmann']
# ['Mohamed', '', 'Salah', 'Ghaly']
# ['Paulo', 'Bruno', 'Exequiel', 'Dybala']
# ['Milan', 'Škriniar']
# ['Fernando', 'Luiz', 'Rosa']
# ['Gonzalo', 'Gerardo', 'Higuaín']
# ['Ivan', 'Rakitić']
# ['Jan', 'Vertonghen']
# ['Dries', 'Mertens']
# ['Marcelo', 'Vieira', 'da', 'Silva', 'Júnior']
# ['Toby', 'Alderweireld']
# ['Jordi', 'Alba', 'Ramos']
# ['Thiago', 'Alcântara', 'do', 'Nascimento']
# ['Ciro', 'Immobile']
# ['Keylor', 'Navas']
# ['Francisco', 'Román', 'Alarcón', 'Suárez']
# ['James', 'David', 'Rodríguez', 'Rubio']
# ['Carlos', 'Henrique', 'Venancio', 'Casimiro']
# ['Mauro', 'Emanuel', 'Icardi', 'Rivero']
# ['Kepa', 'Arrizabalaga']
# ['Hakim', 'Ziyech']
# ['Fábio', 'Henrique', 'Tavares']
# ['Anthony', 'Martial']
# ['Timo', 'Werner']
# ['Niklas', 'Süle']
# ['Bruno', 'Miguel', 'Borges', 'Fernandes']
# ['Alex', 'Nicolao', 'Telles']
# ['José', 'María', 'Giménez', 'de', 'Vargas']
# ['Nabil', 'Fekir']
# ['Davinson', 'Sánchez']
# ['Marco', 'Asensio', 'Willemsen']
# ['Ousmane', 'Dembélé']
# ['Andrés', 'Iniesta', 'Luján']
# ['Zlatan', 'Ibrahimović']
# ['Luiz', 'Frello', 'Filho', 'Jorge']
# ['Edin', 'Višća']
# ['Serge', 'Gnabry']
# ['Mateo', 'Kovačić']
# ['William', 'Silva', 'de', 'Carvalho']
# ['Felipe', 'Augusto', 'de', 'Almeida', 'Monteiro']
# ['Yannick', 'Ferreira', 'Carrasco']
# ['Lucas', 'Vázquez', 'Iglesias']
# ['Quincy', 'Anton', 'Promes']
# ['Leon', 'Goretzka']
# ['Adrien', 'Rabiot']
# ['Alessio', 'Romagnoli']
# ['João', 'Pedro', 'Cavaco', 'Cancelo']
# ['Anderson', 'Souza', 'Conceição']
# ['Kingsley', 'Coman']
# ['Thomas', 'Lemar']
# ['Jonathan', 'Tah']
# ['Matteo', 'Politano']
# ['Clément', 'Lenglet']
# ['Pau', 'López', 'Sabata']
# ['Hirving', 'Rodrigo', 'Lozano', 'Bahena']
# ['Malcom', 'Filipe', 'Silva', 'de', 'Oliveira']
# ['Lucas', 'Torreira', 'Di', 'Pascua']
# ['Gonçalo', 'Manuel', 'Ganchinho', 'Guedes']
# ['Giovani', 'Lo', 'Celso']
# ['Fabián', 'Ruiz', 'Peña']
# ['Frenkie', 'de', 'Jong']
# ['Raphael', 'William', 'Anjos', 'Rochedo']
# ['Juan', 'Everton', 'Mestres', 'de', 'Mesquita']
# ['Rosberto', 'J.', 'Dourado', 'Santos']
# ['Arthur', 'Henrique', 'Ramos', 'Oliveira', 'Melo']
# ['Rodrigo', 'Hernández', 'Cascante']
# ['Marco', 'Parolo']
# ['Max', 'Kruse']
# ['Jordan', 'Brian', 'Henderson']
# ['Osvaldo', 'Nicolás', 'Fabián', 'Gaitán']
# ['Marko', 'Arnautović']
# ['Sebastian', 'Giovinco']
# ['Gylfi', 'Þór', 'Sigurðsson']
# ['Giuliano', 'Victor', 'de', 'Paula']
# ['Péter', 'Gulácsi']
# ['Luiz', 'Gustavo', 'Dias']
# ['Kieran', 'Trippier']
# ['Aaron', 'Ramsey']
# ['Mario', '', 'Barwuah', 'Balotelli']
# ['Marlos', 'Romero', 'Bonfim']
# ['Taison', 'Barcellos', 'Freda']
# ['Giacomo', 'Bonaventura']
# ['Geoffrey', 'Kondogbia']
# ['Jérôme', 'Roussillon']
# ['Simone', 'Zaza']
# ['Šime', 'Vrsaljko']
# ['Christoph', 'Kramer']
# ['Benjamin', 'Mendy']
# ['Marcel', 'Sabitzer']
# ['Matija', 'Nastasić']
# ['Alassane', 'Plea']
# ['Matthias', 'Ginter']
# ['Gerard', 'Moreno', 'Balagueró']
# ['Abdoulaye', 'Doucouré']
# ['Raphaël', 'Guerreiro']
# ['Ricardo', 'Barbosa', 'Pereira']
# ['Samuel', 'Castillejo', 'Azuaga']
# ['Julian', 'Brandt']
# ['Nicolas', 'Pépé']
# ['Steven', 'Bergwijn']
# ['André', 'Onana']
# ['Fabián', 'Balbuena']
# ['André', 'Miguel', 'Valente', 'da', 'Silva']
# ['Mikel', 'Oyarzabal', 'Ugarte']
# ['Everton', 'Jorge', 'Andrade', 'Zanon']
# ['Welington', 'Kauê', 'Dano', 'Nascimento']
# ['Richarlison', 'de', 'Andrade']
# ['Álvaro', 'Odriozola', 'Arzalluz']
# ['Carlos', 'Soler', 'Barragán']
# ['Houssem', 'Aouar']
# ['Tanguy', 'NDombèlé', 'Alvaro']
# ['Maximiliano', 'Gómez']
# ['Joaquín', 'Sánchez', 'Rodríguez']
# ['Jérémy', 'Mathieu']
# ['Joël', 'Andre', 'Job', 'Matip']
# ['Serge', 'Aurier']
# ['Josuha', 'Guilavogui']
# ['Alex', 'Oxlade-Chamberlain']
# ['Mathew', 'Ryan']
# ['Vincent', 'Paté', 'Aboubakar']
# ['Luis', 'Fernando', 'Muriel', 'Fruto']
# ['Domagoj', 'Vida']
# ['Ibai', 'Gómez', 'Pérez']
# ['Cristian', 'Tello', 'Herrera']
# ['Ismaily', 'Gonçalves', 'dos', 'S.']
# ['Aïssa', 'Mandi']
# ['Anton', 'Ciprian', 'Tătărușanu']
# ['Jeison', 'Fabián', 'Murillo', 'Cerón']
# ['Eric', 'Dier']
# ['Jack', 'Butland']
# ['Stefano', 'Sorrentino']
# ['Wayne', 'Mark', 'Rooney']
# ['Miguel', 'Ángel', 'Moyá', 'Rumbo']
# ['Lisandro', 'López']
# ['Javier', 'Alejandro', 'Mascherano']
# ['Raffael', 'Caetano', 'de', 'Araújo']
# ['Diego', 'López', 'Rodríguez']
# ['Juan', 'Francisco', 'Torres', 'Belén']
# ['Igor', 'Denisov']
# ['Igor', 'Akinfeev']
# ['André-Pierre', 'Gignac']
# ['Andreas', 'Granqvist']
# ['Manuel', 'Henrique', 'Tavares', 'Fernandes']
# ['Dante', 'Bonfim', 'da', 'Costa', 'Santos']
# ['Loïc', 'Perrin']
# ['Borja', 'Valero', 'Iglesias']
# ['Adnan', 'Januzaj']
# ['Jonas', 'Hector']
# ['Moanes', 'Dabour']
# ['Óliver', 'Torres', 'Muñoz']
# ['Yassine', 'Bounou']
# ['Jonas', 'Hofmann']
# ['Otávio', 'Edmilson', 'da', 'Silva', 'Monteiro']
# ['Jonathan', 'Castro', 'Otto']
# ['Leander', 'Dendoncker']
# ['Roman', 'Zobnin']
# ['Ricardo', 'Jorge', 'da', 'Luz', 'Horta']
# ['Thiago', 'Henrique', 'Mendes', 'Ribeiro']
# ['Jefferson', 'Andrés', 'Lerma', 'Solís']
# ['Jean-Philippe', 'Gbamin']
# ['Iván', 'Marcone']
# ['Darío', 'Benedetto']
# ['Marwin', 'Hitz']
# ['Nathaniel', 'Edwin', 'Clyne']
# ['Adem', 'Ljajić']
# ['Johann', '', 'Berg', 'Guðmunds\xadson']
# ['Elkeson', 'de', 'Oliveira', 'Cardoso']
# ['Enrique', 'García', 'Martínez']
# ['Sergio', 'Escudero', 'Palomo']
# ['Iago', 'Herrerín', 'Buisán']
# ['Víctor', 'Ruíz', 'Torre']
# ['Gary', 'Alexis', 'Medel', 'Soto']
# ['Younès', 'Belhanda']
# ['Hugo', 'Mallo', 'Novegil']
# ['Borja', 'García', 'Freire']
# ['Wahbi', 'Khazri']
# ['Phil', 'Jones']
# ['Alfreð', 'Finnbogason']
# ['Vinícius', 'José', 'de', 'Oliveira', 'Júnior']
# ['Héctor', 'Junior', 'Firpo', 'Adamés']
# ['Emre', 'Belözoğlu']
# ['Fernando', 'José', 'Torres', 'Sanz']
# ['Bastian', 'Schweinsteiger']
# ['Burak', 'Yılmaz']
# ['Mario', 'Gómez', 'García']
# ['Ashley', 'Young']
# ['Ryan', 'Guno', 'Babel']
# ['Benoît', 'Costil']
# ['Salomon', 'Armand', 'Magloire', 'Kalou']
# ['Ezequiel', 'Iván', 'Lavezzi']
# ['Hatem', 'Ben', 'Arfa']
# ['Ben', 'Foster']
# ['Tom', 'Heaton']
# ['Charles', 'Dias', 'De', 'Oliveira']
# ['Gary', 'Cahill']
# ['Alex', 'Iwobi']
# ['Ruben', 'Loftus-Cheek']
# ['Alexandr', 'Selikhov']
# ['Johan', 'Andrés', 'Mojica', 'Palacio']
# ['Wílmar', 'Enrique', 'Barrios', 'Terán']
# ['Carlos', 'Roberto', 'Izquierdoz']
# ['Walter', 'Benítez']
# ['Nikola', 'Maksimović']
# ['Aleksandar', 'Mitrović']
# ['Marco', 'Sportiello']
# ['Ander', 'Capa', 'Rodríguez']
# ['Marcelo', 'Augusto', 'Ferreira', 'Teixeira']
# ['Youri', 'Tielemans']
# ['Stanislav', 'Lobotka']
# ['Maximilian', 'Philipp']
# ['Léo', 'Dubois']
# ['Lewis', 'Dunk']
# ['Christopher', 'Schindler']
# ['Yevhen', 'Konoplyanka']
# ['Pedro', 'Filipe', 'Teodósio', 'Mendes']
# ['Riccardo', 'Saponara']
# ['Layvin', 'Kurzawa']
# ['Martin', 'Hinteregger']
# ['Danny', '', 'Vieira', 'da', 'Costa']
# ['Fernando', 'Lucas', 'Martins']
# ['Willy', 'Boly']
# ['Alexander', 'Schwolow']
# ['Gregoire', 'Defrel']
# ['Álvaro', 'González', 'Soberón']
# ['Leonardo', 'Bittencourt']
# ['André', 'Martín', 'Carrillo', 'Díaz']
# ['Mohamed', 'Elyounoussi']
# ['Orestis', 'Karnezis']
# ['Óscar', 'de', 'Marcos', 'Arana']
# ['Rémy', 'Cabella']
# ['Joe', 'Hart']
# ['José', 'Manuel', 'Jurado', 'Marín']
# ['Elías', 'Hernán', 'Hernández', 'Jacuinde']
# ['Daniel', 'Ginczek']
# ['Lucas', 'Pérez', 'Martínez']
# ['Jefferson', 'Agustín', 'Farfán', 'Guadalupe']
# ['Asmir', 'Begović']
# ['Vitorino', 'Hilton', 'da', 'Silva']
# ['Julian', 'Baumgartlinger']
# ['Esteban', 'Félix', 'Granero', 'Molina']
# ['Zlatko', 'Junuzović']
# ['Victor', 'Moses']
# ['Mathieu', 'Debuchy']
# ['Guillermo', 'Alfonso', 'Maripán', 'Loaysa']
# ['Iván', 'Cuéllar', 'Sacristán']
# ['Fabian', 'Johnson']
# ['Aarón', 'Martín', 'Caricol']
# ['Gastón', 'Rodrigo', 'Pereiro', 'López']
# ['Benjamin', 'Moukandjo', 'Bilé']
# ['Martin', 'Harnik']
# ['James', '', 'Ward-Prowse']
# ['Romain', 'Alessandrini']
# ['Manuel', 'Alejandro', 'García', 'Sánchez']
# ['Michail', 'Antonio']
# ['Adrien', 'Sebastian', 'Perruchet', 'Silva']
# ['Steve', 'Cook']
# ['Ben', 'Mee']
# ['Adriano', 'Correia', 'Claro']
# ['Jeremain', 'Lens']
# ['José', 'Salomón', 'Rondón', 'Giménez']
# ['Andreas', 'Hugo', 'Hoelgebaum', 'Pereira']
# ['Vedad', 'Ibišević']
# ['Lucas', 'Ocampos']
# ['Nicolai', 'Müller']
# ['Simão', 'Alvin', 'Acunha', 'Bardini']
# ['Jonathan', 'Calleri']
# ['Alireza', 'Jahanbakhsh']
# ['Aleksandar', 'Prijović']
# ['Fabricio', 'Martín', 'Agosto', 'Ramírez']
# ['Mohamed', 'Elneny']
# ['Jorge', 'Meré', 'Pérez']
# ['Wilson', 'Bruno', 'Naval', 'Costa', 'Eduardo']
# ['Alejandro', 'Remiro', 'Gargallo']
# ['Teófilo', 'Gutiérrez']
# ['Andriy', 'Pyatov']
# ['Diego', 'Javier', 'Llorente', 'Ríos']
# ['Ignazio', 'Abate']
# ['Thomas', 'Vermaelen']
# ['Niclas', 'Füllkrug']
# ['Pedro', '', 'Mba', 'Obiang', 'Avomo']
# ['Wallace', 'Fortuna', 'dos', 'Santos']
# ['Jorge', 'Djaniny', '', 'Tavares', 'Semedo']
# ['Roberto', 'Jiménez', 'Gago']
# ['Serdar', 'Taşçı']
# ['Lasse', 'Schøne']
# ['Jermain', '', 'Defoe']
# ['Volkan', 'Babacan']
# ['Odion', 'Jude', 'Ighalo']
# ['André', 'Schürrle']
# ['Ellyes', 'Skhiri']
# ['Waldemar', 'Anton']
# ['Rodrigo', 'Sebastián', 'Palacio']
# ['Kevin', 'Lasagna']
# ['Darío', 'Cvitanich']
# ['Sebastian', 'De', 'Maio']
# ['Simon', 'Terodde']
# ['Jonathan', '', 'de', 'Guzmán']
# ['Renato', 'Civelli']
# ['Pablo', 'Maffeo', 'Becerra']
# ['Cédric', 'Ricardo', 'Alves', 'Soares']
# ['Kyriakos', 'Papadopoulos']
# ['Alexander', 'Szymanowski']
# ['Juraj', 'Kucka']
# ['Phil', 'Jagielka']
# ['Marco', 'Benassi']
# ['Pontus', 'Jansson']
# ['Bernardo', 'José', 'Espinosa', 'Zúñiga']
# ['José', 'Pedro', 'Malheiro', 'de', 'Sá']
# ['Matz', 'Sels']
# ['Yuri', 'Berchiche', 'Izeta']
# ['Rafael', 'Santos', 'Borré']
# ['João', 'Paulo', 'Dias', 'Fernandes']
# ['Cristiano', 'Piccini']
# ['Benjamin', 'André']
# ['Antonio', 'Barragán', 'Fernández']
# ['Mbwana', 'Ally', 'Samatta']
# ['Issa', 'Diop']
# ['Matthew', 'Lowton']
# ['Theo', 'Bernard', 'François', 'Hernández']
# ['Juan', 'Pedro', 'Ramírez', 'López']
# ['Kenny', 'Tete']
# ['Blerim', 'Džemaili']
# ['André', 'Filipe', 'Brás', 'André']
# ['Mikel', 'Balenziaga', 'Oruesagasti']
# ['Valon', 'Behrami']
# ['Diego', 'Antonio', 'Reyes', 'Rosales']
# ['Caiuby', 'Francisco', 'da', 'Silva']
# ['Seydou', 'Doumbia']
# ['João', 'Félix', 'Sequeira']
# ['Lisandro', 'López']
# ['Mario', 'Suárez', 'Mata']
# ['Jonas', 'Lössl']
# ['Gonzalo', 'Castro', 'Randon']
# ['Matt', 'Phillips']
# ['Gabriel', 'Boschilia']
# ['武磊']
# ['Nicolás', 'Blandi']
# ['Lovre', 'Kalinić']
# ['Federico', 'Fernández']
# ['Jackson', 'Martínez']
# ['Emerson', 'Palmieri', 'dos', 'Santos']
# ['Rômulo', '', 'Souza', 'Orestes', 'Caldeira']
# ['Christian', 'Benteke', 'Liolo']
# ['Milot', 'Rashica']
# ['Leighton', 'Baines']
# ['Mark', 'Noble']
# ['Filip', 'Benković']
# ['Cristian', 'Miguel', 'Riveros', 'Núñez']
# ["M'Baye", 'Babacar', 'Niang']
# ['Davide', 'Santon']
# ['Ivan', 'Ordets']
# ['Francisco', 'Geraldes']
# ['Robert', 'Snodgrass']
# ['Vitor', 'Hugo', 'Franchescoli', 'de', 'Souza']
# ['Mario', 'Pašalić']
# ['Fabio', 'Borini']
# ['Nikola', 'Vukčević']
# ['Atiba', 'Hutchinson']
# ['Maximiliano', 'Nicol', 'Moralez']
# ['Charlie', 'Austin']
# ['Robert', 'Kenedy', 'Nunes', 'do', 'Nascimento']
# ['Eltildo', 'Lucas', 'Correia', 'Pitta']
# ['João', 'Pedro', 'Geraldino', 'dos', 'Santos', 'Galvão']
# ['Alessandro', 'Diamanti']
# ['Guilherme', 'dos', 'Santos', 'Torres']
# ['Jérémy', 'Morel']
# ['Fernando', 'Javier', 'Llorente', 'Torres']
# ['Gökhan', 'Gönül']
# ['Alberto', 'Paloschi']
# ['Julio', 'Leonardo', 'Dourado', 'de', 'Freitas']
# ['Markel', 'Bergara', 'Larrañaga']
# ['Lee', 'Nguyen']
# ['Anthony', 'Knockaert']
# ['Iñigo', 'Córdoba', 'Kerejeta']
# ['Joël', 'Veltman']
# ['Nicola', 'Sansone']
# ['Arda', 'Turan']
# ['Haris', 'Seferović']
# ['Rafael', 'Jorgino', 'Cachoira', 'Rebelo']
# ['Amadou', 'Haidara']
# ['Francesco', 'Caputo']
# ['Manuel', 'Locatelli']
# ['Jordan', 'Ayew']
# ['Tin', 'Jedvaj']
# ['Sofiane', 'Hanni']
# ['Andrés', 'Eduardo', 'Fernández', 'Moreno']
# ['Thomas', 'Monconduit']
# ['Nordi', 'Mukiele']
# ['Dominique', 'Heintz']
# ['Uílson', 'de', 'Souza', 'Paula', 'Júnior']
# ['Aaron', '', 'Lennon']
# ['Jetro', 'Willems']
# ['Miloš', 'Veljković']
# ['Ishak', 'Belfodil']
# ['Hugo', 'Miguel', 'Almeida', 'Costa', 'Lopes']
# ['Dale', 'Stephens']
# ['Brais', 'Méndez', 'Portela']
# ['Adam', 'Smith']
# ['José', 'Luis', 'García', 'del', 'Pozo']
# ['Francisco', 'Femenía', 'Far']
# ['Mijat', 'Gaćinović']
# ['Per', 'Ciljan', 'Skjelbred']
# ['Da', 'Conceição', 'Fernando', 'Henrique']
# ['Scott', 'Brown']
# ['Marko', 'Grujić']
# ['Adama', 'Soumaoro']
# ['Raúl', 'Rodríguez', 'Navas']
# ['Ádám', 'Szalai']
# ['Amadou', 'Diawara']
# ['Łukasz', 'Skorupski']
# ['Romain', 'Hamouma']
# ['Kevin', 'Stöger']
# ['Karol', 'Linetty']
# ['Stefan', 'Bell']
# ['Alfred', 'John', 'Momar', "N'Diaye"]
# ['Yusuf', 'Yazıcı']
# ['Bastian', 'Oczipka']
# ['Federico', 'Valverde']
# ['Martín', 'Benítez']
# ['Michel', 'Vorm']
# ['Nampalys', 'Mendy']
# ['José', 'Juan', 'Vázquez', 'Gómez']
# ['Unai', 'Núñez', 'Gestoso']
# ['Nemanja', 'Radoja']
# ['Kieran', '', 'Gibbs']
# ['Abderrazak', 'Hamdallah']
# ['Pablo', 'Renan', 'dos', 'Santos']
# ['Seko', 'Fofana']
# ['Felipe', 'Dias', 'da', 'Silva', 'dal', 'Belo']
# ['Carlos', 'Andrés', 'Villanueva', 'Roland']
# ['José', 'Márcio', 'da', 'Costa']
# ['Diego', 'Rico', 'Salguero']
# ['Alberto', 'Moreno', 'Pérez']
# ['Jordy', 'Clasie']
# ['Rogelio', 'Gabriel', 'Funes', 'Mori']
# ['Osvaldo', 'Alonso', 'Moreno']
# ['Alexander', 'Djiku']
# ['Jonathan', 'Hogg']
# ['Dominic', 'Calvert-Lewin']
# ['Marvin', 'Zeegelaar']
# ['Guido', 'Carrillo']
# ['Jozabed', 'Sánchez', 'Ruiz']
# ['Alan', 'Javier', 'Franco']
# ['David', 'Brooks']
# ['Jeffrey', 'Bruma']
# ['Luigi', 'Sepe']
# ['Sam', 'Vokes']
# ['Javier', 'López', 'Rodríguez']
# ['Jordan', 'Amavi']
# ['Idrissa', 'Mandiang']
# ['Alper', 'Potuk']
# ['Oliver', 'Norwood']
# ['Rani', 'Khedira']
# ['Darwin', 'Machís']
# ['Robin', 'Quaison']
# ['Paul', 'Dummett']
# ['Landry', 'Dimata']
# ['Allan', 'Norberto', 'Bardini', 'Paneira']
# ['Ludovic', 'Butelle']
# ['Sebastián', 'Cristóforo']
# ['David', 'Jason', 'Remeseiro', 'Salgueiro']
# ['Mikel', 'Agu']
# ['Emmanuel', 'Badu']
# ['Nathan', 'Redmond']
# ['Sandro', 'Ranieri', 'Guimarães', 'Cordeiro']
# ['Anthony', 'Mounier']
# ['Matheus', 'Fellipe', 'Costa', 'Pereira']
# ['Christophe', 'Jallet']
# ['Diego', 'Castro', 'Giménez']
# ['岡崎', '慎司']
# ['Ola', '', 'Williams', 'Kamara']
# ['Miguel', 'Ângelo', 'da', 'Silva', 'Rocha']
# ['Rick', 'Karsdorp']
# ['José', 'Carlos', 'Coentrão', 'Marafona']
# ['Diego', 'Valdés']
# ['Maxime', 'Gonalons']
# ['Jorge', 'Franco', 'Alviz']
# ['Fredy', 'Alejandro', 'Guarín', 'Vásquez']
# ['Mathias', 'Jensen']
# ['Ryan', 'Thomas']
# ['Bogdan', 'Butko']
# ['Luca', 'Cigarini']
# ['Ahmed', 'Musa']
# ['Mykola', 'Morozyuk']
# ['Georgiy', 'Schennikov']
# ['André', 'Ramalho', 'Silva']
# ['Thomas', 'Foket']
# ['Philip', 'Foden']
# ['Walace', 'Souza', 'Silva']
# ['İrfan', 'Can', 'Kahveci']
# ['Jimmy', 'Briand']
# ['Diego', 'Rolán']
# ['Cyril', 'Théréau']
# ['Bruno', 'Valdez']
# ['Pape', 'Moussa', 'Konaté']
# ['Hugo', 'Ayala', 'Castro']
# ['Justin', 'Kluivert']
# ['Percy', 'Tau']
# ['Javier', 'Eraso', 'Goñi']
# ['Artur', 'Boruc']
# ['Sam', 'Larsson']
# ['Paulo', 'Henrique', 'Soares', 'dos', 'Santos']
# ['Jonathan', 'Matías', 'Urretaviscaya', 'da', 'Luz']
# ['Youssef', 'Aït', 'Bennasser']
# ['Paul', 'Bernardoni']
# ['Joshua', 'Brenet']
# ['Carles', 'Aleñá', 'Castillo']
# ['Thiago', 'Maia', 'Alencar']
# ['Robert', 'Skov']
# ['Mauricio', 'Aníbal', 'Isla', 'Isla']
# ['Weston', 'McKennie']
# ['James', 'Tavernier']
# ['Samuel', 'Kalu', 'Ojim']
# ['Marlon', 'da', 'Silva', 'Barbosa']
# ['Joseph', 'Alfred', 'Duncan']
# ['Stefano', 'Sturaro']
# ['Harry', 'Arter']
# ['Vitaliy', 'Buyalskyi']
# ['Malang', 'Sarr']
# ['Ignacio', 'Fernández']
# ['Hans', 'Hateboer']
# ['Florian', 'Niederlechner']
# ['Pirmin', 'Schwegler']
# ['Ben', 'Pearson']
# ['Tammy', 'Abraham']
# ['Jefferson', 'Moreira', 'Nascimento']
# ['Joakim', 'Mæhle']
# ['Unai', 'López', 'Cabrera']
# ['Ibrahim', 'Amadou']
# ['Christian', 'Günter']
# ['Ogenyi', 'Eddy', 'Onazi']
# ['Jefferson', 'Antonio', 'Montero', 'Vite']
# ['Oscar', 'Fabián', 'Murillo', 'Murillo']
# ['Borja', 'González', 'Tomás']
# ['Lucas', 'Zelarayán']
# ['Martin', 'Kelly']
# ['Aminu', 'Umar']
# ['Joseba', 'Zaldúa', 'Bengoetxea']
# ['Mbaye', 'Diagne']
# ['Jovane', 'Eduardo', 'Borges', 'Cabral']
# ['Scott', 'Dann']
# ['Mateo', 'Pavlović']
# ['Andrew', 'Surman']
# ['Florian', 'Kainz']
# ['Francisco', 'José', 'Beltrán', 'Peinado']
# ['Kenneth', 'Vermeer']
# ['Andreu', 'Fontàs', 'Prat']
# ['Luis', 'Enrique', 'Quiñónes']
# ['Mathew', 'Leckie']
# ['Danilo', 'das', 'Neves', 'Pinheiro']
# ['Solly', 'March']
# ['Bryan', 'Dabo']
# ['Fredrik', 'Midtsjø']
# ['Alejandro', 'Arribas', 'Garrido']
# ['Duirval', 'Hélton', 'Diniz', 'Cabral']
# ['Ollie', 'Watkins']
# ['Renato', 'Tapia']
# ['Enzo', 'Pablo', 'Roco', 'Roco']
# ['Jonas', 'Svensson']
# ['Lucas', 'Alfonso', 'Orbán', 'Alegre']
# ['Godfred', 'Donsah']
# ['Ladislav', 'Krejčí']
# ['Scott', 'Sinclair']
# ['Bojan', 'Jokič']
# ['Marcus', 'Thuram']
# ['Silvio', 'Ezequiel', 'Romero']
# ['Christian', 'Atsu']
# ['Christian', 'Träsch']
# ['Florentin', 'Pogba']
# ['Sergio', 'Reguilón', 'Rodríguez']
# ['Caio', 'Bruno', 'Milaçar', 'Kenedy']
# ['Marc-Oliver', 'Kempf']
# ['Daniel', 'Sánchez', 'Ayala']
# ['Patrick', 'Roberts']
# ['Guillermo', 'Ortíz']
# ['Rafał', 'Gikiewicz']
# ['Rodrigo', 'Rey']
# ['Yasin', 'Öztekin']
# ['Daniel', 'João', 'Santos', 'Candeias']
# ['Claudio', 'Beauvue']
# ['Marcelo', 'dos', 'Santos', 'Ferreira']
# ['Steve', 'von', 'Bergen']
# ['Joel', 'Obi']
# ['Rafael', 'da', 'Conceição', 'Leão']
# ['Pedro', 'K.', 'Medina', 'da', 'Silva']
# ['Raúl', 'Fernández-Cavada', 'Mateos']
# ['長友', '佑都']
# ['Patrik', 'Hrošovský']
# ['Robert', 'Berić']
# ['Nicolás', 'Federico', 'Spolli']
# ['Liam', 'Moore']
# ['Diego', 'Falcinelli']
# ['Jean-Sylvain', 'Claude', 'Babin']
# ['Jan', 'Kopic']
# ['Matt', 'Besler']
# ['Pablo', 'Martinez']
# ['Renan', 'Bardini', 'Bressan']
# ['Olcay', 'Şahan']
# ['Michael', 'Rensing']
# ['Kalvin', 'Phillips']
# ['Willem', 'Janssen']
# ['Eugenio', 'Mena']
# ['Amato', 'Ciciretti']
# ['Davidson', 'da', 'Luz', 'Pereira']
# ['Diogo', 'Filipe', 'Monteiro', 'Pinto', 'Leite']
# ['Andrea', 'Raggi']
# ['Samuel', 'Grandsir']
# ['Damir', 'Kreilach']
# ['Alan', 'Ruiz']
# ['Iñigo', 'Pérez', 'Soto']
# ['Ludovic', 'Lamine', 'Sané']
# ['Olívio', 'da', 'Rosa']
# ['Gil', 'Bastião', 'Dias']
# ['Ángel', 'Mena']
# ['Jhon', 'Córdoba']
# ['Bruno', 'Écuélé', 'Manga']
# ['Nicola', 'Murru']
# ['Graeme', 'Shinnie']
# ['Jens', 'Stryger', 'Larsen']
# ['Aleksandr', 'Erokhin']
# ['Luis', 'Robles']
# ['Andreas', 'Ulmer']
# ['Fabián', 'Castillo']
# ['Ilija', 'Nestorovski']
# ['Mason', 'Mount']
# ['Olarenwaju', 'Ayoba', 'Kayode']
# ['Matheus', 'Jadson', 'Vidigal', 'Morais']
# ['Paul', 'Verhaegh']
# ['Lucas', 'Cavallini']
# ['Johannes', 'Geis']
# ['Ricky', 'van', 'Wolfswinkel']
# ['Kasim', 'Adams', 'Nuhu']
# ['Kévin', 'Manuel', 'Rodrigues']
# ['Jonás', '', 'Ramalho', 'Chimeno']
# ['Andrey', 'Semenov']
# ['Gaëtan', 'Charbonnier']
# ['Luis', 'Carlos', 'Correia', 'Pinto']
# ['Erik', 'Pieters']
# ['Hannes', 'Wolf']
# ['Joseph', 'Aidoo']
# ['Nicolás', 'Júlio', 'Formido', 'Paiva']
# ['Dimitrios', 'Kourmpelis']
# ['Jagoš', 'Vuković']
# ['Jean', 'André', 'Emanuel', 'Beausejour', 'Coliqueo']
# ['Matthias', 'Ostrzolek']
# ['Jakub', 'Błaszczykowski']
# ['Denis', 'Bouanga']
# ['Rubén', 'Botta']
# ['Darko', 'Lazović']
# ['Lazar', '', 'Marković']
# ['Fábio', 'Ricardo', 'Gomes', 'Fonseca']
# ['Ruben', 'Alexandre', 'Rocha', 'Lima']
# ['宇佐美', '貴史']
# ['Eloy', 'Room']
# ['Koffi', 'Cheikh', 'Konaté']
# ['Rubén', 'Alcaraz', 'Jiménez']
# ['Allan', 'Nyom']
# ['Yuri', 'Oliveira', 'Ribeiro']
# ['Mehmet', 'Ekici']
# ['Víctor', 'Ismael', 'Sosa']
# ['Lorenzo', 'António', 'Melgarejo', 'Sanabria']
# ['William', 'Alves', 'de', 'Oliveira']
# ['Matěj', 'Vydra']
# ['Tiago', 'Manuel', 'Dias', 'Correia']
# ['Adrián', '', 'González', 'Morales']
# ['Çağlar', 'Söyüncü']
# ['Kelechi', 'Iheanacho']
# ['Marcel', 'Tisserand']
# ['Anthony', 'Rubén', 'Lozano', 'Colón']
# ['Luca', 'Waldschmidt']
# ['Adriano', 'Leandro', 'Soares', 'Taffarel']
# ['Sten', 'Michael', 'Grytebust']
# ['Ivan', 'Strinić']
# ['Pedro', 'Miguel', 'Braga', 'Rebocho']
# ['Jerry', 'Mbakogu']
# ['Matheus', 'Dória', 'Macedo']
# ['Musa', 'Çağıran']
# ['Kaiansu', 'Kei', 'Kamara']
# ['Stéphane', 'Bahoken']
# ['Ben', 'Gibson']
# ['José', 'Ignacio', 'Martínez', 'García']
# ['Andreas', 'Evald', 'Cornelius']
# ['Maxime', 'Le', 'Marchand']
# ['Pape', 'Cheikh', 'Diop', 'Gueye']
# ['Şener', 'Özbayraklı']
# ['Steven', 'Davis']
# ['Abdul', 'Rahman', 'Baba']
# ['Ervin', 'Zukanović']
# ['El-Hadji', 'Baye', 'Oumar', 'Niasse']
# ['Paul-José', "M'Poku", 'Ebunge']
# ['Kevin', 'McDonald']
# ['Jesus', 'Fabrício', 'Andrade', 'Simões']
# ['Soslan', 'Dzhanaev']
# ['Miloš', 'Degenek']
# ['Adrien', 'Tameze']
# ['Tiago', 'Rafael', 'Maia', 'Silva']
# ['Éric', 'Bauthéac']
# ['Yoric', 'Ravet']
# ['Duško', 'Tošić']
# ['Daniele', 'Padelli']
# ['Bernard', 'Mensah']
# ['Jonathan', 'Ludovic', 'Biabiany']
# ['Ivo', 'Iličević']
# ['Harvey', 'Lewis', 'Barnes']
# ['Chidozie', 'Collins', 'Awaziem']
# ['Antonio', 'Manuel', 'Luna', 'Rodríguez']
# ['Aurélien', 'Chedjou']
# ['Djavan', 'da', 'Silva', 'Ferreira']
# ['Artem', 'Rebrov']
# ['Georg', 'Margreitter']
# ['Salvador', 'Sánchez', 'Ponce']
# ['Pietro', 'Maurício', 'Mendes', 'Abranches']
# ['Marco', 'Russ']
# ['Hendrik', 'Van', 'Crombrugge']
# ['Abdelaziz', 'Barrada']
# ['中村', '宪剛']
# ['Adam', 'Clayton']
# ['Tim', 'Leibold']
# ['Vyacheslav', 'Karavaev']
# ['Iver', 'Fossum']
# ['Daniel', 'Bessa']
# ['Nelson', 'Acevedo']
# ['Sergiy', 'Rybalka']
# ['Giovanni', 'Di', 'Lorenzo']
# ['Habib', 'Diallo']
# ['Brian', 'Fernández']
# ['José', 'María', 'Basanta']
# ['Sada', 'Thioub']
# ['Che', 'Adams']
# ['José', 'Ignacio', 'Peleteiro', 'Ramallo']
# ['Enzo', 'Crivelli']
# ['Xabier', 'Etxeita', 'Gorritxategi']
# ['Daniel', 'Ciofani']
# ['Maximiliano', 'Urruti']
# ['Gerso', 'Fernandes']
# ['Josef', 'Šural']
# ['Bersant', 'Celina']
# ['Salman', 'Mohammed', 'Al', 'Faraj']
# ['Lovro', 'Majer']
# ['Jeremiah', 'St.', 'Juste']
# ['Miler', 'Alejandro', 'Bolaños', 'Reascos']
# ['Roy', 'Krishna']
# ['Edoardo', 'Goldaniga']
# ['석현준', '玄铉俊']
# ['Miguel', 'Alfonso', 'Herrero', 'Javaloyas']
# ['Álejandro', 'Gallar', 'Falguero']
# ['Pablo', 'Insua', 'Blanco']
# ['Ignasi', 'Miquel', 'i', 'Pons']
# ['Luis', 'Gonzalo', 'Bustamante']
# ['Ezequiel', 'Schelotto']
# ['Paulo', 'Sérgio', 'Mota']
# ['Florian', 'Hübner']
# ['André', 'de', 'Castro', 'Pereira']
# ['Rodrigo', 'Aliendro']
# ['金崎', '夢生']
# ['Stoppila', 'Sunzu']
# ['Yaya', 'Sanogo']
# ['南野', '拓実']
# ['Sokratis', 'Dioudis']
# ['Jehad', 'Fadel', 'Al', 'Hussain']
# ['Raúl', 'García', 'Carnero']
# ['Sebastián', 'Hernán', 'Bertoli']
# ['Jérémy', 'Gélin']
# ['Josip', 'Mišić']
# ['Fabiano', 'Ribeiro', 'de', 'Freitas']
# ['Orel', 'Mangala']
# ['Jeremy', 'Toljan']
# ['Javier', 'Marcelo', 'Gandolfi']
# ['Joe', 'Lewis']
# ['Jan', 'Bořil']
# ['Sam', 'Clucas']
# ['Alexander', 'Grünwald']
# ['Jakob', 'Bendix', 'Uhd', 'Poulsen']
# ['César', 'Jasib', 'Montes', 'Castro']
# ['Riccardo', 'Meggiorini']
# ['Niko', 'Bungert']
# ['Christian', 'Kouamé']
# ['Francisco', 'Javier', 'Meza', 'Palma']
# ['Ángelo', 'Henríquez']
# ['Nélson', 'Miguel', 'Castro', 'Oliveira']
# ['Emanuele', 'Terranova']
# ['Renaud', 'Emond']
# ['Gary', 'Hooper']
# ['Luke', 'Anthony', 'Freeman']
# ['Luís', 'Miguel', 'Vieira', 'da', 'Silva']
# ['Andrea', 'Rispoli']
# ['Nicolás', 'Gastón', 'Navarro']
# ['Alexander', 'Nahuel', 'Barboza', 'Ullúa']
# ['Alexandru', 'Iulian', 'Maxim']
# ['Ola', 'John']
# ['Alex', 'Smithies']
# ['Pablo', 'César', 'Barrientos']
# ['Fabián', 'Andrés', 'Rinaudo']
# ['Luca', 'Mazzitelli']
# ['Eduardo', 'Antônio', 'Machado', 'Teixeira']
# ['Giampaolo', 'Pazzini']
# ['Abdoulaye', 'Bamba']
# ['Arturo', 'Mina']
# ['Ibrahima', 'Mbaye']
# ['Mahmut', 'Tekdemir']
# ['Leonardo', 'Fabián', 'Burián', 'Castro']
# ['Michel', 'David', 'Cruceiro', 'Muscato']
# ['Ricardo', 'Jorge', 'Vaz', 'Té']
# ['Yeison', 'Stiven', 'Gordillo', 'Vargas']
# ['Gino', 'Peruzzi']
# ['汉超于']
# ['Keiren', 'Westwood']
# ['Evandro', 'Sérgio', 'Rochedo', 'Paulino']
# ['Daniel', 'Pacheco', 'Lobato']
# ['Antonio', 'Ríos', 'Martínez']
# ['Deniz', 'Kadah']
# ['Adama', 'Diakhaby']
# ['Juan', 'Carlos', 'Martín', 'Corral']
# ['Isaac', 'Success']
# ['Salem', 'Al', 'Dawsari']
# ['Aras', 'Özbiliz']
# ['Geovanni', 'Banguera']
# ['Karl-Johan', 'Johnsson']
# ['Uğur', 'Demirok']
# ['Nana', 'Kwesi', 'Asare']
# ['Manuel', 'Pucciarelli']
# ['Diego', 'Santiago', 'Fagúndez', 'Pepe']
# ['William', 'Troost-Ekong']
# ['Paulo', 'José', 'de', 'Oliveira']
# ['Juan', 'Marcos', 'Foyth']
# ['Martin', 'Linnes']
# ['Sérgio', 'Antônio', 'Soler', 'Oliveira', 'Jr']
# ['Hélder', 'Filipe', 'Oliveira', 'Lopes']
# ['Erik', 'Berg']
# ['Rasmus', 'Bengtsson']
# ['Fernando', 'Martín', 'Forestieri']
# ['Kamil', 'Wilczek']
# ['Gojko', 'Cimirot']
# ['Ismaël', 'Bennacer']
# ['Luca', 'Marrone']
# ['Rafik', 'Halliche']
# ['Valentín', 'Vada']
# ['Yves', 'Bissouma']
# ['Rodrigo', 'Salinas', 'Dorantes']
# ['堂安', '律']
# ['Édgar', 'Felipe', 'Pardo', 'Castro']
# ['Jhon', 'Duque']
# ['David', 'Jensen']
# ['Julián', 'Omar', 'Ramos', 'Suárez']
# ['Darren', 'Randolph']
# ['Stefano', 'Sensi']
# ['Andrés', 'Ricaurte', 'Vélez']
# ['Matías', 'Aguirregaray', 'Guruceaga']
# ['João', 'António', 'Antunes', 'Carvalho']
# ['Arbër', 'Zeneli']
# ['Dario', 'Dainelli']
# ['Kian', 'Hansen']
# ['Ryan', 'Bennett']
# ['이청용', '李青龙']
# ['Valerio', 'Verre']
# ['권순태', '权纯泰']
# ['Mauro', 'Pierre', 'Cildinho', 'Conradi']
# ['Arnaldo', 'Edi', 'Lopes', 'da', 'Silva']
# ['Leonardo', 'Nicolás', 'Pisculichi']
# ['Yohan', 'Benalouane']
# ['Antonino', 'Ragusa']
# ['Fabien', 'Lemoine']
# ['Cristian', 'Roldan']
# ['Didier', '', 'Ndong', 'Ibrahim']
# ['Vladimír', 'Coufal']
# ['Mislav', 'Oršić']
# ['Éder', 'Marvin', 'Oliveira', 'Simão']
# ['Barry', 'Bannan']
# ['Robin', 'Koch']
# ['Nicolás', 'Pasquini']
# ['Alessandro', 'Rosina']
# ['Tim', 'Parker']
# ['Marcos', 'G.', 'Santos', 'Matos']
# ['Derrick', 'Luckassen']
# ['Shaun', 'Hutchinson']
# ['Bruno', 'José', 'Pavani', 'Lamas']
# ['Alexandru', 'Bălută']
# ['Miguel', 'Ángel', 'De', 'las', 'Cuevas', 'Barberá']
# ['Leonardo', 'B.', 'Lohner', 'Maia']
# ['Daniel', 'Kolář']
# ['青山', '敏弘']
# ['Santiago', 'Montoya']
# ['Victor', 'Emanuel', 'Aguilera']
# ['山口', '蛍']
# ['Ilombe', 'Mboyo']
# ['Bruno', 'Vinícius', 'Souza', 'Ramos']
# ['Borna', 'Barišić']
# ['Wilson', 'Miguéis', 'Manafá', 'Jancó']
# ['Christian', 'Nørgaard']
# ['George', 'Friend']
# ['Davit', 'Khotcholava']
# ['Bassem', '', 'Srarfi']
# ['Romário', 'Ricardo', 'da', 'Silva']
# ['Mateus', 'Galiano', 'da', 'Costa']
# ['Wes', 'Hoolahan']
# ['Ramon', 'Olamilekan', 'Azeez']
# ['Michael', 'Frey']
# ['Jean-Daniel', 'Akpa', 'Akpro']
# ['Joan', 'Isaac', 'Cuenca', 'López']
# ['Fábio', 'José', 'Ferreira', 'Pacheco']
# ['Gustavo', 'Lucas', 'Domingues', 'Piazon']
# ['Timoteo', 'Samuel', 'Triano', 'Branco']
# ['Alexander', 'Scholz']
# ['Yussif', 'Raman', 'Chibsah']
# ['Mark', 'Duffy']
# ['Gareth', 'McAuley']
# ['Nawaf', 'Shaker', 'Al', 'Abid']
# ['Alessandro', 'Nuno', 'Vaz', 'Laranjeiras']
# ['Daniele', 'Verde']
# ['Pierre-Michel', 'Lasogga']
# ['Marlon', 'Pack']
# ['Zinedine', 'Ferhat']
# ['Chad', 'Marshall']
# ['Jean-Christophe', 'Bahebeck']
# ['Róger', 'Espinoza', 'Ramírez']
# ['Nicolás', 'Iván', 'González']
# ['Nuno', 'Miguel', 'Gomes', 'dos', 'Santos']
# ['Kasper', 'Kusk', 'Vangsgaard']
# ['Eugenio', 'Lamanna']
# ['Gilles', 'Sunu']
# ['Emil', 'Berggreen']
# ['Jonathan', 'Guillermo', 'Nuñez', 'Espinoza']
# ['Luciano', 'Aued']
# ['蒿俊闵']
# ['Marius', 'Valerică', 'Găman']
# ['Jorge', 'Pulido', 'Mayoral']
# ['Abbubaker', 'Mobara']
# ['Joe', 'Ledley']
# ['Ahmet', 'Çalık']
# ['Alberto', 'Cerri']
# ['킴진수', '金珍洙']
# ['Christian', 'Gytkjær']
# ['이강인', 'Kangin', 'Lee']
# ['Edigar', 'Junio', 'Teixeira', 'Lima']
# ['John', 'Bostock']
# ['Sergio', 'Pellissier']
# ['Marcus', 'Antonsson']
# ['Moise', 'Kean']
# ['James', '', 'Collins']
# ['Nyasha', 'Liberty', 'Mushekwi']
# ['Leiton', 'Jiménez']
# ['Delvin', 'N’Dinga']
# ['Felix', 'Kroos']
# ['Mimoun', 'Mahi']
# ['Joris', 'van', 'Overeem']
# ['Alexander', 'Esswein']
# ['Jorge', 'Moreira']
# ['Jorge', 'Pietro', 'Carvalho', 'Porfírio']
# ['Jair', 'Pereira', 'Rodríguez']
# ['Nino', 'Galović']
# ['Hárold', 'Santiago', '', 'Mosquera', 'Caicedo']
# ['Juan', 'Pablo', 'Nieto', 'Salazar']
# ['Claudio', 'Ariel', 'Yacob']
# ['Ludovic', 'Ajorque']
# ['Hernán', 'Barcos']
# ['中村', '俊輔']
# ['Moussa', 'Doumbia']
# ['Gennaro', 'Tutino']
# ['Agustín', 'Allione']
# ['Germán', 'Lanaro']
# ['Walker', 'Zimmerman']
# ['Luca', 'Rizzo']
# ['Roberto', 'Carlos', 'Gutiérrez', 'Gamboa']
# ['Mario', 'Gavranović']
# ['Özer', 'Hurmacı']
# ['Andres', 'Tello']
# ['Simon', 'Gustafson']
# ['Fabio', 'Giovanni', 'Ceravolo']
# ['Fabricio', 'Coloccini']
# ['Gianluca', 'Curci']
# ['Daniel', 'Martins', 'Guimarães']
# ['Emil', 'Hallfreðsson']
# ['Miiko', 'Martín', 'Albornoz', 'Inola']
# ['Juan', 'Ignacio', 'Mercier']
# ['Mitchell', 'Glenn', 'Donald']
# ['Mickaël', 'Cuisance']
# ['Amr', 'Warda']
# ['Adama', 'Traoré']
# ['Oliver', 'McBurnie']
# ['Dankler', 'Luís', 'de', 'Jesus', 'Pedreira']
# ['Mauro', 'Daniel', 'Goicoechea', 'Furia']
# ['Lucas', '', 'Andersen']
# ['Chinedu', 'Obasi', 'Ogbuke']
# ['Tim', 'Howard']
# ['Henok', 'Goitom']
# ['Saîf-Eddine', 'Khaoui']
# ['Rajiv', 'van', 'La', 'Parra']
# ['Adrián', 'Marín', 'Gómez']
# ['Lucas', 'Menossi']
# ['Josué', 'Humberto', 'Gonçalves', 'Leal', 'Sá']
# ['Anastasios', 'Chatzigiovanis']
# ['Cristian', 'Enzo', 'Lodeira', 'Araujo']
# ['Aleksandar', 'Pantić']
# ['Jorge', 'Luis', 'Rojas', 'Meza']
# ['Fabian', 'Klos']
# ['Cristian', 'Leonel', 'Ramírez', 'Zambrano']
# ['John', 'Boye']
# ['Maksym', 'Malyshev']
# ['Douglas', 'Pereira', 'dos', 'Santos']
# ['Kris', 'Boyd']
# ['Diego', 'Rodríguez']
# ['Mats', '', 'Møller', 'Dæhli']
# ['Sebastian', 'Polter']
# ['Ricardo', 'van', 'Rhijn']
# ['Nikola', 'Maraš']
# ['Andrés', 'Leandro', 'Castellanos', 'Serrano']
# ['André', 'Biyogo', 'Poko']
# ['Juan', 'Ferney', 'Otero', 'Tovar']
# ['Nicolai', 'Møller', 'Boilesen']
# ['Diego', 'Lainez', 'Leyva']
# ['Yasser', 'Al', 'Shahrani']
# ['Ismaël', 'Tiémoko', 'Diomandé']
# ['Dénes', 'Dibusz']
# ['Damian', 'Kądzior']
# ['Jonathan', 'Pablo', 'Bottinelli']
# ['Gareth', 'Barry']
# ['Robbie', 'Kruse']
# ['Cristian', 'Oscar', 'Bernardi']
# ['Ezequiel', 'Ávila']
# ['Nemanja', 'Radonjić']
# ['Jeff', 'Nazario', 'Meire', 'Costinho']
# ['Javier', 'Güemez', 'López']
# ['Jordan', 'Jones']
# ['David', 'Guzman']
# ['Ángel', 'Zaldívar', 'Caviedes']
# ['Simon', 'Tibbling']
# ['Joshua', 'Eduardo', 'Sá', 'Madeira']
# ['Alexis', 'De', 'Sart']
# ['William', 'Owusu']
# ['Mohamed', 'Aberhoune']
# ['Jason', 'Puncheon']
# ['Marco', 'Stiepermann']
# ['Muhammet', 'Demir']
# ['Salvador', 'Sevilla', 'López']
# ['Benjamin', 'Kololli']
# ['Julian', 'Börner']
# ['Ricardo', 'Ryller', 'Ribeiro', 'Lino', 'Silva']
# ['Bartosz', 'Białkowski']
# ['Martín', 'Maximiliano', 'Mantovani']
# ['Stefan', 'Ortega', 'Moreno']
# ['Serdar', 'Gürler']
# ['Joe', 'Bennett']
# ['Rui', 'Pedro', 'da', 'Rocha', 'Fonte']
# ['Ali', 'Adnan']
# ['Luis', 'Miguel', 'Sánchez', 'Benítez']
# ['Luca', 'Garritano']
# ['Adrián', 'Andrés', 'Cubas']
# ['Jubal', 'Rocha', 'Mendes', 'Junior']
# ['Lebogang', 'Phiri']
# ['Thomas', 'Delaine']
# ['Jamie', 'Murphy']
# ['Alex', 'Martin', 'Frandeira', 'Álvares']
# ['Rolando', 'García', 'Guerreño']
# ['Ken', 'Sema']
# ['José', 'Antonio', 'Reyes', 'Calderón']
# ['Izet', 'Hajrović']
# ['Fernando', 'Henrique', 'Boldrin']
# ['Diego', 'Arturo', 'Peralta', 'González']
# ['Sebastião', 'de', 'Freitas', 'Couto', 'Júnior']
# ['Uroš', 'Ćosić']
# ['Fabio', 'Pisacane']
# ['Diego', 'Rossi']
# ['Roberto', 'Alvarado']
# ['Josh', 'Brownhill']
# ['Marlon', 'Javier', 'Piedrahita', 'Londoño']
# ['Maikel', 'van', 'der', 'Werff']
# ['Dom', 'Dwyer']
# ['Gonzalo', 'Bettini']
# ['Petar', 'Brlek']
# ['M.', 'Vanderlei', 'Paulino', 'Kenedy']
# ['Tobias', 'Pereira', 'Figueiredo']
# ['Erik', 'Morán', 'Arribas']
# ['David', 'Batanero', 'Puigbó']
# ['Gerrit', 'Holtmann']
# ['Antonio', 'Aldo', 'Caracciolo']
# ['Astrit', 'Ajdarević']
# ['정성룡', '郑俊玄']
# ['Aboubakar', 'Kamara']
# ['Ayrton', 'Preciado']
# ['Milton', 'Nahuel', 'Valenzuela']
# ['Edimilson', 'Fernandes']
# ['Ledian', 'Memushaj']
# ['川島', '永嗣']
# ['Jakov', 'Filipović']
# ['Akaki', 'Gogia']
# ['Dominik', 'Schmidt']
# ['Rodrigo', 'Nascimento', 'França']
# ['Marvin', 'Friedrich']
# ['Tom', 'Schütz']
# ['Stanislav', 'Tecl']
# ['Danijel', 'Milićević']
# ['Oliver', 'Fink']
# ['Amro', 'Tarek', 'Abdel', 'Aziz']
# ['Matej', 'Jonjić']
# ['Bryan', 'Heynen']
# ['João', 'Pedro', 'Maturano', 'dos', 'Santos']
# ['Daniel', 'Rosero', 'Valencia']
# ['Rafael', 'Antonio', 'Caroca', 'Cordero']
# ['Elierce', 'Barbosa', 'de', 'Souza']
# ['Kevin', 'Bonifazi']
# ['Daniel', 'Williams']
# ['Óscar', 'Cabezas']
# ['Calvin', 'Stengs']
# ['Borja', 'Lasso', 'De', 'La', 'Vega']
# ['Rémi', 'Oudin']
# ['Ribair', 'Rodríguez', 'Pérez']
# ['Jhasmani', 'Campos']
# ['Jordan', 'Rhodes']
# ['Ivan', 'Šunjić']
# ['Rasmus', 'Thelander']
# ['Nikola', 'Moro']
# ['Mikael', 'Lustig']
# ['西川', '周作']
# ['Marco', 'Natanel', 'Torsiglieri']
# ['Petar', 'Škuletić']
# ['Maximiliano', 'Caire']
# ['Cristian', 'David', 'Lucchetti']
# ['Benik', 'Afobe']
# ['Carlos', 'Alberto', 'Alves', 'Garcia']
# ['Jérémie', 'Bela']
# ['Maximiliano', 'Ángel', 'Coronel']
# ['Ricardo', 'Jorge', 'Oliveira', 'Valente']
# ['Jérémy', 'Perbet']
# ['Alexander', 'Martín', 'Marquinho', 'Callens', 'Asín']
# ['Adriano', 'Facchini']
# ['Rui', 'Filipe', 'Caetano', 'Moura']
# ['Ariel', 'Mauricio', 'Rojas']
# ['Darragh', 'Lenihan']
# ['Barrie', 'McKay']
# ['Nabil', 'Ghilas']
# ['柏好', '文']
# ['Dejan', 'Damjanović']
# ['Frédéric', 'Sammaritano']
# ['Vincenzo', 'Fiorillo']
# ['Richard', 'Keogh']
# ['Matheus', 'Simoneti', 'Bressaneli']
# ['Emrah', 'Başsan']
# ['Julián', 'Andrés', 'Quiñones', 'Quiñones']
# ['Alexis', 'Soto']
# ['Harry', 'Novillo']
# ['Chris', 'Brunt']
# ['David', 'McGoldrick']
# ['Karlo', 'Letica']
# ['Luis', 'Ricardo', 'Reyes', 'Moreno']
# ['Leopold', 'Zingerle']
# ['Florian', 'Müller']
# ['Robert', 'Tesche']
# ['Urby', 'Emanuelson']
# ['José', 'Javier', 'Abella', 'Fanjul']
# ['Tim', 'Kleindienst']
# ['Mustafa', 'Yumlu']
# ['Marvin', 'Matip']
# ['José', 'Gabriel', 'Sambenito']
# ['Smail', 'Prevljak']
# ['David', 'von', 'Ballmoos']
# ['Anthony', 'Nwakaeme']
# ['David', 'Mackalister', 'Silva', 'Mosquera']
# ['Ivan', 'Oblyakov']
# ['Miguel', 'Ángel', 'Fraga', 'Licona']
# ['Bilal', 'Başaçıkoğlu']
# ['Craig', 'Bryson']
# ['Darwin', 'Zamir', 'Andrade', 'Marmolejo']
# ['Eirik', '', 'Ulland', 'Andersen']
# ['Harlee', 'Dean']
# ['Eduardo', 'José', 'Borges', 'Machado']
# ['Erick', 'Germain', 'Aguirre', 'Tafolla']
# ['Matías', 'Nahuel', 'Leiva', 'Esquivel']
# ['Tiago', 'Alves', 'Sales']
# ['Knowledge', 'Musona']
# ['Anthony', 'Gonçalves']
# ['Marc', 'Torrejón', 'Moya']
# ['César', 'Ignacio', 'Pinares', 'Tamayo']
# ['Raffaele', 'Pucino']
# ['Pablo', 'Edson', 'Barrera', 'Acosta']
# ['Jonas', 'Welson', 'Orsi', 'de', 'Meneses']
# ['Heltinho', 'Melo', 'Chaves']
# ['Bengali-Fodé', 'Koita']
# ['Roberto', 'Canella', 'Suárez']
# ['Kieran', 'Lee']
# ['Ramahlwe', 'Mphahlele']
# ['Kevin', 'Müller']
# ['Jefferson', 'Cuero', 'Castro']
# ['Jed', 'Wallace']
# ['Jesús', 'Enrique', 'Sánchez', 'García']
# ['Serhou', 'Guirassy']
# ['Lumor', 'Agbenyenu']
# ['Jack', 'Harrison']
# ['Stefan', 'Schwab']
# ['Dan', 'Burn']
# ['Marcel', 'Correia']
# ['Marlion', 'Rômulo', 'Rolim', 'Nascimento']
# ['Sven', 'Michel']
# ['Paweł', 'Olkowski']
# ['Giorgi', 'Loria']
# ['Javier', 'Castellano', 'Betancor']
# ['Mohamed', 'Fouzair']
# ['Cédric', 'Yambéré']
# ['Bubacarr', 'Sanneh']
# ['Harrison', 'Reed']
# ['Fernando', 'Dos', 'Santos', 'Pedro']
# ['Srdjan', 'Plavšić']
# ['James', '', 'Morrison']
# ['Deiver', 'Machado']
# ['Paulo', 'César', 'Díaz', 'Huincales']
# ['Abdul', 'Rahman', 'Khalili']
# ['Konstantin', 'Kerschbaumer']
# ['Slobodan', 'Medojević']
# ['Gaetano', 'Berardi']
# ['Thiago', 'Santos', 'Santana']
# ['Mario', 'Maloča']
# ['Guilherme', 'Ferreira', 'Pinto']
# ['Scott', 'Malone']
# ['Jake', 'Cooper']
# ['阿部', '浩之']
# ['Raúl', 'Lizoáin', 'Cruz']
# ['Kyle', 'Lafferty']
# ['Wiliam', 'Carlos', 'Santoso', 'Sampaio']
# ['Tom', 'Beugelsdijk']
# ['Fredrik', 'Gulbrandsen']
# ['Luigi', 'Bruins']
# ['大島', '僚太']
# ['Álvaro', 'Vázquez', 'García']
# ['Mohammed', 'Al', 'Buraik']
# ['Raphael', 'Rossi', 'Branco']
# ['Gianluca', 'Litteri']
# ['Matías', 'Nicolás', 'Rodríguez']
# ['Ceyhun', 'Gülselam']
# ['Mickaël', 'Le', 'Bihan']
# ['Rijad', 'Bajić']
# ['Fernando', 'Navarro', 'Morán']
# ['Bartłomiej', 'Drągowski']
# ['Daniel', 'Bentley']
# ['Vitor', 'Gomes', 'Pereira', 'Júnior']
# ['Ricardo', 'Martins', 'de', 'Araújo']
# ['Rafael', 'Mir', 'Vicente']
# ['Mathias', 'Autret']
# ['Adama', 'Valentin', 'Diomande']
# ['Benjamin', 'Jeannot']
# ['Zdravko', 'Kuzmanović']
# ['Damián', 'Oscar', 'Lemos']
# ['David', 'Matías', 'Barbona']
# ['Facundo', 'Adrián', 'Erpen']
# ['Sebastian', 'Andersson']
# ['Michael', 'Hector']
# ['Guillermo', 'Federico', 'Molins', 'Palmeiro']
# ['Lukas', 'Jutkiewicz']
# ['Thomas', 'Nicolas', 'Silva', 'Rangel']
# ['Kevin', 'Balanta']
# ['Vedat', 'Muriqi']
# ['Fernando', 'Márquez']
# ['Hannes', 'Van', 'Der', 'Bruggen']
# ['Lasse', 'Nielsen']
# ['Alexis', 'Mac', 'Allister']
# ['Jonas', 'Gomes', 'de', 'Sousa']
# ['Rodrigo', 'Defendi']
# ['Luis', 'Quintana']
# ['Albert', 'Dorca', 'Masó']
# ['Edgar', 'Prib']
# ['염기훈', '廉基勋']
# ['Gleison', 'Bremer', 'Silva', 'Nascimento']
# ['Rodrigo', 'Alves', 'Soares']
# ['Joseph', 'Attamah']
# ['Álvaro', 'Lemos', 'Collazo']
# ['Justin', 'Meram']
# ['Renato', 'Neto', 'Cardoso', 'Porto']
# ['Alexandre', 'Garcia', 'Guedes']
# ['Emmanuel', 'García']
# ['Abdullah', 'Ateef']
# ['Nir', 'Bitton']
# ['Simon', 'Thern']
# ['Nikola', 'Katić']
# ['Oussama', 'Haddadi']
# ['Hamza', 'Choudhury']
# ['Mile', 'Jedinák']
# ['Djamel', 'Eddine', 'Benlamri']
# ['Sebastián', 'Palacios']
# ['Mohammed', 'Khalil', 'Al', 'Owais']
# ['Osama', 'Rashid']
# ['George', 'Thorne']
# ['Aleksandar', 'Pešić']
# ['Saido', 'Berahino']
# ['Raffaele', 'Bianco']
# ['Noah', 'Joel', 'Sarenren', 'Bazee']
# ['Jón', 'Daði', 'Böðvarsson']
# ['Casper', 'De', 'Norre']
# ['Sean', 'Maguire']
# ['Lorenzo', 'Lollo']
# ['Luis', 'Eduardo', 'Delgado', 'Pacheco']
# ['Aleksandr', 'Kolomeytsev']
# ['Jörg', 'Siebenhandl']
# ['Stewart', 'Downing']
# ['Óscar', 'Pérez', 'Rojas']
# ['Philipp', 'Klingmann']
# ['Leonardo', 'Mancuso']
# ['Iñigo', 'Eguaras', 'Álvarez']
# ['Giorgi', 'Makaridze']
# ['Sidney', 'Sam']
# ['Lucas', 'Possignolo']
# ['Edson', 'Rodrigues', 'Farias']
# ['Gastón', 'Campi']
# ['Alan', 'Hutton']
# ['Bruno', 'Manuel', 'Araújo', 'Braga']
# ['Cristian', 'Ganea']
# ['Esteban', 'Rodrigo', 'Burgos']
# ['Saidy', 'Janko']
# ['Lorenzo', 'Pasciuti']
# ['Johan', 'Cavalli']
# ['Besart', 'Berisha']
# ['Tomás', 'Martínez']
# ['Hamza', 'Mendyl']
# ['Alberto', 'Benito', 'Correo']
# ['Guillermo', 'Varela']
# ['Simon', 'Lundevall']
# ['Jorge', 'Rodríguez']
# ['Micheal', 'Azira']
# ['Alfredo', 'Ortuño', 'Martínez']
# ['Toma', 'Bašić']
# ['Francis', 'Amuzu']
# ['Bismark', 'de', 'Araújo', 'Ferreira']
# ['Jordan', 'Adéoti']
# ['William', 'Fernando', 'da', 'Silva']
# ['Joe', 'Garner']
# ['Mauro', 'Matos']
# ['Cenk', 'Şahin']
# ['Ertaç', 'Özbir']
# ['Javier', 'Ros', 'Añón']
# ['Kelvin', 'Leerdam']
# ['Marco', 'Silvestri']
# ['Samir', 'Ujkani']
# ['Martin', 'Victor', 'Álvares', 'Fachini']
# ['Núrio', 'Domingos', 'Matias', 'Fortuna']
# ['Stergos', 'Marinos']
# ['Grant', 'Leadbitter']
# ['Sébastien', 'Pocognoli']
# ['Kasper', 'Hämäläinen']
# ['Yairo', 'Yesid', 'Moreno', 'Berrío']
# ['Pål', 'André', 'Helland']
# ['Marcus', 'Pedersen']
# ['Víctor', 'Manuel', 'Casadesús', 'Castaño']
# ['Jordan', '', 'Archer']
# ['Pierre', 'Emmanuel', 'Sagna']
# ['Jonathan', 'Diego', 'Menéndez']
# ['柏木', '陽介']
# ['Lucas', 'Henrique', 'da', 'Silva']
# ['Nemanja', 'Mihajlović']
# ['Steve', 'Breitkreuz']
# ['Didier', 'Delgado']
# ['Sean', '', 'Johnson']
# ['Francisco', 'Reis', 'Ferreira']
# ['Claudio', 'Daniel', 'Bieler']
# ['Michael', 'Hefele']
# ['Danny', 'Blum']
# ['Uğur', 'Uçar']
# ['Nehuén', 'Mario', 'Paz']
# ['Bernardo', 'Víctor', 'Cruz', 'Torres']
# ['Mirko', 'Gori']
# ['Rafael', 'Robayo']
# ['Andriy', 'Totovytskyi']
# ['Oliver', 'Hüsing']
# ['Andrea', 'Seculin']
# ['Marco', 'Sangalli', 'Fuentes']
# ['Marcus', 'Danielsson']
# ['김영권', '金英权']
# ['Miguel', 'Barbieri']
# ['Gaëtan', 'Belaud']
# ['Ricardo', 'Abel', 'Barbosa', 'Ferreira']
# ['Kosta', 'Barbarouses']
# ['José', 'Iván', 'Rodríguez']
# ['Cristian', 'Battocchio']
# ['Will', 'Grigg']
# ['Mathieu', 'Coutadeur']
# ['Raoul', 'Petretta']
# ['Steve', 'De', 'Ridder']
# ['Macario', 'André', 'Louro', 'Padilha']
# ['Birger', 'Solberg', 'Meling']
# ['Nwankwo', 'Emeka', 'Obiora']
# ['Antonio', 'José', 'Rodríguez', 'Díaz']
# ['Alfredo', 'Saldívar', 'Medina']
# ['Yoane', 'Wissa']
# ['Roberto', 'Andrés', 'Ovelar', 'Maldonado']
# ['Daniele', 'Dessena']
# ['Nasser', 'Ali', 'Al', 'Shamrani']
# ['Sílvio', 'Manuel', 'Azevedo', 'Ferreira', 'Sá', 'Pereira']
# ['Marcos', 'Bolados', 'Hidalgo']
# ['Diogo', 'Nathan', 'Peixe', 'Barreto']
# ['Sebastian', 'Griesbeck']
# ['Luis', 'Manuel', 'García', 'Palomera']
# ['Jakub', 'Brabec']
# ['Ânderson', 'Miguel', 'da', 'Silva']
# ['伊藤', '達哉']
# ['Lukas', 'Spalvis']
# ['Aitor', 'García', 'Flores']
# ['Juan', 'Carlos', 'Paredes']
# ['Marco', 'Varnier']
# ['Sam', 'Morsy']
# ['Floyd', 'Ayité']
# ['Franco', 'Zuculini']
# ['Bruno', 'Daniel', 'Castro', 'Moreira']
# ['Carlos', 'Eduardo', 'Fierro', 'Guerrero']
# ['Michael', 'Morrison']
# ['Paul', 'Gallagher']
# ['Dany', 'Nounkeu']
# ['Taleb', 'Tawatha']
# ['Daniel', 'Toribio', 'Gutiérrez']
# ['Trevor', 'Carson']
# ['Hosam', 'Aiesh']
# ['Ruud', 'Boffin']
# ['Uroš', 'Matić']
# ['Lautaro', 'Giannetti']
# ['Dejan', 'Sorgić']
# ['José', 'Manuel', 'Arnáiz', 'Díaz']
# ['Dominik', 'Kaiser']
# ['Alessandro', 'Crescenzi']
# ['Darwin', 'Adelso', 'Cerén', 'Delgado']
# ['Yahia', 'Sulaiman', 'Al', 'Shehri']
# ['Renato', 'de', 'Araújo', 'Chaves', 'Júnior']
# ['Abdulwahid', 'Sissoko']
# ['Te', 'Se', 'Chong']
# ['Domilson', 'Cordeiro', 'dos', 'Santos']
# ['Ruben', 'Yttergård', 'Jenssen']
# ['Josh', 'Onomah']
# ['Pedro', 'Camilo', 'Franco', 'Ulloa']
# ['Jeremy', 'Dudziak']
# ['Wilfried', 'Zahibo']
# ['Javier', 'Fabián', 'Toledo']
# ['Christophe', 'Diandy']
# ['Artur', 'Jędrzejczyk']
# ['Wagner', 'da', 'Silva', 'Souza']
# ['Mauro', 'Manotas']
# ['Aderllan', 'de', 'Jesus', 'Santos']
# ['Juan', 'Daniel', 'Roa', 'Reyes']
# ['Daniel', 'Hernández', 'Santos']
# ['Aziz', 'Bouhaddouz']
# ['Niklas', 'Hauptmann']
# ['Leart', 'Paqarada']
# ['David', 'Kinsombi']
# ['Riccardo', 'Improta']
# ['Erick', 'Estéfano', 'Torres', 'Padilla']
# ['Fousseni', 'Diabaté']
# ['Steeven', 'Willems']
# ['Salih', 'Özcan']
# ['Marco', 'Caligiuri']
# ['David', 'Moberg', 'Karlsson']
# ['Ousmane', 'Dramé']
# ['Javier', 'Puado', 'Díaz']
# ['Carlos', 'Alberto', 'Henao', 'Sánchez']
# ['Jeisson', 'Andrés', 'Palacios', 'Palacios']
# ['Maximilian', 'Wittek']
# ['Marcel', 'Hartel']
# ['Martin', 'Frýdek']
# ['Álvaro', 'David', 'Montero', 'Perales']
# ['Eirik', 'Hestad']
# ['Mirko', 'Drudi']
# ['Sebastian', 'Schonlau']
# ['Patricio', 'Daniel', 'Toranzo']
# ['Daniel', 'Lopes', 'Amora']
# ['Matěj', 'Hanousek']
# ['Timothy', 'Derijck']
# ['Edwar', 'López']
# ['Anuar', 'Mohamed', 'Tuhami']
# ['Koray', 'Günter']
# ['Anders', 'Ågnes', '', 'Konradsen']
# ['Gabriel', 'Arturo', 'Torres', 'Tejada']
# ['浅野', '佐藤']
# ['Ionuţ', 'Nedelcearu']
# ['Leonardo', 'Fabio', 'Castro', 'Loaiza']
# ['Scott', 'McKenna']
# ['Danny', 'Fox']
# ['Steven', 'Birnbaum']
# ['Christopher', 'Maxwell']
# ['Denis', 'Stracqualursi']
# ['Waldemar', 'Sobota']
# ['土居', '聖真']
# ['José', 'María', 'Martín', 'Bejarano']
# ['Tom', 'Weilandt']
# ['Andre', 'Wisdom']
# ['Korey', 'Smith']
# ['Mathieu', 'Bodmer']
# ['Fodé', 'Ballo-Touré']
# ['정운', 'Woon', 'Jeong']
# ['Luis', 'Ángel', 'Mendoza', 'Escamilla']
# ['Marco', 'Davide', 'Faraoni']
# ['Donis', 'Avdijaj']
# ['Juan', 'Domínguez', 'Lamas']
# ['Mamadou', 'Sylla', 'Diallo']
# ['Matías', 'Ibáñez']
# ['Fabian', 'Giefer']
# ['Dylan', 'Batubinsika']
# ['金子', '翔太']
# ['Edson', 'Gérson', 'Torres', 'Guerra']
# ['Aleandro', 'Rosi']
# ['Eduardo', 'López']
# ['Stephan', 'Hain']
# ['Juan', 'Caicedo']
# ['Pape', '', "N'Diaye", 'Souaré']
# ['Graham', 'Carey']
# ['Niall', 'McGinn']
# ['Léo', 'Lacroix']
# ['Iliass', 'Bel', 'Hassani']
# ['Luciano', 'Lollo']
# ['Florian', 'Jungwirth']
# ['Jose', 'Miguel', 'Silbeira']
# ['Evan', 'Bush']
# ['Antonio', 'Campillo', 'Medina']
# ['Fabrice', 'Ondoa']
# ['Federico', 'Mancinelli']
# ['Killian', 'Overmeire']
# ['Hugo', 'Armando', 'Campagnaro']
# ['Nikola', 'Đurđić']
# ['Hugo', 'Filipe', 'da', 'Costa', 'Oliveira']
# ['Raúl', 'Alberto', 'Loaiza', 'Morelos']
# ['Brilliant', 'Khuzwayo']
# ['Alessandro', 'Salvi']
# ['Jorge', 'Alejandro', 'Zárate', 'Careaga']
# ['Sebastiaan', 'Bornauw']
# ['Óscar', 'Rodríguez', 'Arnaiz']
# ['Michael', 'Parkhurst']
# ['Marek', 'Rodák']
# ['Rodrigo', 'Ríos', 'Lozano']
# ['Lukáš', 'Mareček']
# ['Arnaud', 'Nordin']
# ['Theoson', 'Jordan', 'Siebatcheu']
# ['Joel', 'Castro', 'Pereira']
# ['Sulley', 'Ali', 'Muntari']
# ['Aurélien', 'Tchouaméni']
# ['Jhonatan', 'Luiz', 'da', 'Siqueira']
# ['Rodrigo', 'Eduardo', 'Echeverría', 'Sáez']
# ['Alessandro', 'Bernardini']
# ['Benno', 'Schmitz']
# ['Dimitri', 'Bisoli']
# ['Idrissa', 'Sylla']
# ['Michael', '', 'Dawson']
# ['Ahmed', 'Fathy', 'Abdel', 'Meneim', 'Ibrahim']
# ['Eduard', 'Löwen']
# ['Robert', 'Green']
# ['Léandre', 'Tawamba']
# ['Pablo', 'Ignacio', 'Galdames', 'Millán']
# ['Marius', 'Müller']
# ['Unai', 'Medina', 'Pérez']
# ['Sami', 'Allagui']
# ['Adrián', 'Jesús', 'Bastía', 'Beruzzi']
# ['Tobias', 'Kempe']
# ['Zargo', 'Touré']
# ['Fidel', 'Chaves', 'de', 'la', 'Torre']
# ['Ondřej', 'Kolář']
# ['James', 'Alexander', 'Lawrence']
# ['Jamie', 'Maclaren']
# ['Artur', 'Sobiech']
# ['Anco', 'Jansen']
# ['Francesco', 'Zampano']
# ['Kevin', 'Stuhr-Ellegaard']
# ['Mark', 'Bunn']
# ['Juan', 'José', 'Ciércoles', 'Sagra']
# ['Denis', 'Odoi']
# ['Joel', 'Ngandu', 'Kayamba']
# ['Michel', 'Morganella']
# ['Volkan', 'Fındıklı']
# ['Denilson', 'Pereira', 'Junior']
# ['Juan', 'Sebastián', 'Villota', 'Vargas']
# ['Ismael', 'López', 'Blanco']
# ['Blas', 'Riveros']
# ['Issam', 'Chebake']
# ['Franz', 'Hermann', 'Schultz', 'Ramírez']
# ['Filip', 'Kurto']
# ['Sergio', 'Andrés', 'Mosquera', 'Zapata']
# ['Felipe', 'Ignacio', 'Seymour', 'Dobud']
# ['Reza', 'Ghoochannejhad', 'Nournia']
# ['Riccardo', 'Maniero']
# ['Norman', 'Theuerkauf']
# ['Frank', 'Fielding']
# ['Carlos', 'Lampe']
# ['Ayaz', 'Guliev']
# ['Luciano', 'Renato', 'Cacheira', 'Sá']
# ['Alberto', 'Jiménez', 'Benítez']
# ['Joseph-Claude', 'Gyau']
# ['Benedikt', 'Gimber']
# ['Camilo', 'Bryan', 'Rodríguez', 'Pedraza']
# ['Kévin', 'Fortuné']
# ['驹井', '善成']
# ['Niclas', 'Eliasson']
# ['Levent', 'Gülen']
# ['Gleidionor', 'Figueiredo', 'Pinto', 'Júnior']
# ['Selim', 'Ay']
# ['Yesus', 'Segundo', 'Cabrera', 'Ramírez']
# ['Ahmed', 'El', 'Messaoudi']
# ['Marcos', 'Mauro', 'López']
# ['Amir', 'Rrahmani']
# ['Calogero', 'Rizzuto']
# ['Roldão', 'Tony', 'Riso', 'Cardenas']
# ['Kelyn', 'Rowe']
# ['Yonathan', 'Emanuel', 'Cabral']
# ['Badra', 'Ali', 'Sangaré']
# ['Dustin', 'Bomheuer']
# ['Lee', 'Gregory']
# ['Alexandre', 'Geijo', 'Pazos']
# ['Nathan', 'Byrne']
# ['Anderson', 'José', 'Lopes', 'de', 'Souza']
# ['Antonio', 'Rosati']
# ['장현수', '张贤秀']
# ['Isaac', 'Sackey']
# ['Jannik', 'Huth']
# ['Terence', 'Mpho', 'Makola']
# ['Janis', 'Blaswich']
# ['Rafael', 'López', 'Gómez']
# ['Lefteris', 'Choutesiotis']
# ['Evangelos', 'Oikonomou']
# ['Fabio', 'Depaoli']
# ['Steven', '', 'Taylor']
# ['Bruno', 'Martella']
# ['Maciej', 'Dąbrowski']
# ['Pedro', 'Filipe', 'Figueiredo', 'Rodrigues']
# ['Elias', 'Cobbaut']
# ['Cameron', 'Carter-Vickers']
# ['Nicola', 'Dalmonte']
# ['Luiz', 'Fernando', 'da', 'Silva', 'Monte']
# ['Robin', 'Pröpper']
# ['Mohamed', '', 'Hamdy', 'Sharaf']
# ['Walter', 'Alberto', 'López', 'Gasco']
# ['Pierre-Yves', 'Hamel']
# ['Facundo', 'Píriz']
# ['Per', 'Kristian', 'Worre', 'Bråtveit']
# ['Javier', 'Guerra', 'Rodríguez']
# ['Maximilian', 'Sax']
# ['Daniel', 'Keita-Ruel']
# ['Maksym', 'Koval']
# ['Ali', 'Gholizadeh']
# ['铃木', '大輔']
# ['Fernando', 'Pellegrino']
# ['Oussama', 'Darfalou']
# ['Ezri', 'Konsa']
# ['Ventura', 'Alvarado']
# ['Patricio', 'Rodríguez']
# ['Daniel', 'Gordon']
# ['Felipe', 'Castaldo', 'Curcio']
# ['Théo', 'Valls']
# ['Nicolas', 'Haas']
# ['Justen', 'Glad']
# ['Will', 'Bruin']
# ['Joe', 'Benny', 'Corona', 'Crespín']
# ['Gianmarco', 'Zigoni']
# ['Miroslav', 'Radović']
# ['Louis', 'Elliott', 'Moult']
# ['Joaquín', 'Matías', 'Ardaiz', 'de', 'los', 'Santos']
# ['Ortwin', 'De', 'Wolf']
# ['Jonathan', 'Martins', 'Pereira']
# ['Alan', 'Jonathan', 'Patrício', 'Botelho']
# ['Javier', 'Muñoz', 'Jiménez']
# ['Lucas', 'Ceballos']
# ['Jack', 'Hunt']
# ['Laurens', 'De', 'Bock']
# ['Adrián', 'Alexei', 'Aldrete', 'Rodríguez']
# ['Bruno', 'Batista', 'Pires']
# ['Jean-Charles', 'Castelletto']
# ['Waleed', 'Bakhashwain']
# ['Ayman', 'Ashraf']
# ['Andraž', 'Šporar']
# ['Daniel', 'Hernández']
# ['Diederik', 'Boer']
# ['Mehdi', 'Zeffane']
# ['Tiago', 'Abiola', 'Delfim', 'Almeida', 'Ilori']
# ['Moses', 'Odubajo']
# ['Ricard', 'Puig', 'Martí']
# ['Miguel', 'Ibarra']
# ['Alexis', 'Rafael', 'Pérez', 'Fontanilla']
# ['Diogo', 'Alexis', 'Rodrigues', 'Coelho']
# ['Matías', 'Nicolás', 'Rojas', 'Romero']
# ['Alfonso', 'Cristián', 'Parot', 'Rojas']
# ['Francisco', 'José', 'Sandaza', 'Asensio']
# ['Daniel', 'Sundgren']
# ['Omri', 'Altman']
# ['Gonzalo', 'Maroni']
# ['Harold', 'Moukoudi']
# ['Lucas', 'Tagliapietra']
# ['Kenan', 'Kodro']
# ['Sam', 'Gallagher']
# ['Alexandre', 'Henrique', 'Gonçalves', 'De', 'Freitas']
# ['Alejandro', 'López', 'Moreno']
# ['Ezequiel', 'Oscar', 'Scarione']
# ['Marc', 'Janko']
# ['Steven', 'Mehrdad', 'Beitashour']
# ['Markus', 'Schubert']
# ['Justin', 'Hoogma']
# ['Juan', 'José', 'Narváez']
# ['Ezequiel', 'Rescaldani']
# ['Mohammed', 'Abu']
# ['Markus', 'Karl']
# ['Cristian', 'Daniel', 'Arango', 'Duque']
# ['Rubenilson', 'dos', 'Santos', 'da', 'Rocha']
# ['Jerdy', 'Schouten']
# ['Patrick', 'Hoban']
# ['戴琳']
# ['Fabrice', "N'Sakala"]
# ['Eros', 'Pisano']
# ['Florent', 'Balmont']
# ['Christoph', 'Leitgeb']
# ['Jarosław', 'Niezgoda']
# ['Lee', 'Wallace']
# ['Marvin', 'Gakpa']
# ['Christopher', 'Cadden']
# ['Ernesto', 'Torregrossa']
# ['Carlos', 'Strandberg']
# ['Salim', 'Khelifi']
# ['Joe', 'Abrigo']
# ['Luca', 'Mora']
# ['东庆', '悟']
# ['Rômulo', 'Roberto', 'Selva', 'Esser']
# ['Paweł', 'Dawidowicz']
# ['Funso-King', 'Ojo']
# ['三竿', '健斗']
# ['Ioannis', 'Mystakidis']
# ['Zacharie', 'Boucher']
# ['Juan', 'Aguilera', 'Aguilera', 'Núñez']
# ['Alexei', 'Coșelev']
# ['Anastasios', 'Avlonitis']
# ['Hueglo', 'dos', 'Santos', 'Neris']
# ['Dimitri', 'Oberlin']
# ['Diego', 'Sánchez', 'Carvajal']
# ['Birkir', 'Bjarnason']
# ['Kik', 'Pierie']
# ...
# ['Djené', 'Dakonam', 'Ortega']
# ['Rodrigo', 'Andrés', 'Battaglia']
# ['Antonio', 'Sanabria']
# ['Jason', 'Denayer']
# ['Yerry', 'Mina']
# ['Nico', 'Elvedi']
# ['Petros', 'Matheus', 'dos', 'Santos', 'Araujo']
# ['Ruben', 'Aguilar']
# ['Omar', 'Al', 'Soma']
# ['Àlex', 'Granell', 'Nogué']
# ['Wout', 'Weghorst']
# ['Adam', 'Marušić']
# ['Borja', 'Iglesias', 'Quintas']
# ['Nicolò', 'Barella']
# ['Joan', 'Jordán', 'Moreno']
# ['Diogo', 'José', 'Teixeira', 'da', 'Silva']
# ['Joe', 'Gomez']
# ['Nadiem', 'Amiri']
# ['Alexandr', 'Golovin']
# ['Mahmoud', 'Hassan']
# ['Marcos', 'Guillermo', 'Díaz']
# ['Daniel', 'Castelo', 'Podence']
# ['Rodrigo', 'Bentancur', 'Colmán']
# ['Christian', 'Pulisic']
# ['Yeray', 'Álvarez', 'López']
# ['Davide', 'Calabria']
# ['Ben', 'Chilwell']
# ['Pierre', 'Lees-Melou']
# ['Ronaldo', 'Diego', 'Esler', 'Domingues']
# ['Claudio', 'Nuno', 'Coíntra', 'Calegari']
# ['Everton', 'Jorge', 'Simão', 'Resende']
# ['Sidney', 'Adrián', 'Pessoa', 'Vidigal']
# ['Alban', 'Lafont']
# ['Ruslan', 'Malinovskyi']
# ['Amine', 'Harit']
# ['Wesley', 'Moraes', 'Ferreira', 'da', 'Silva']
# ['Achraf', 'Hakimi', 'Mouh']
# ['Manuel', 'Lazzari']
# ['Diadie', 'Samassékou']
# ['Cengiz', 'Ünder']
# ['David', 'Neres', 'Campos']
# ['Theo', '', 'Walcott']
# ['Samir', 'Nasri']
# ['Luis', 'Antonio', 'Valencia', 'Mosquera']
# ['Andrea', 'Masiello']
# ['Steven', 'Defour']
# ['José', 'Miguel', 'da', 'Rocha', 'Fonte']
# ['Daniel', 'Andre', 'Sturridge']
# ['Daniel', 'Wass']
# ['David', 'Ospina', 'Ramírez']
# ['Pontus', 'Wernbloom']
# ['Ángel', 'Luís', 'Rodríguez', 'Díaz']
# ['Francisco', 'Casilla', 'Cortés']
# ['Etienne', 'Capoue']
# ['Javier', 'Hernández', 'Balcázar']
# ['Eder', 'Citadin', 'Martins']
# ['Séamus', 'Coleman']
# ['Marcelo', 'Antônio', 'Guedes', 'Filho']
# ['Adam', 'David', 'Lallana']
# ['長谷', '部誠']
# ['Stevan', 'Jovetić']
# ['Mamadou', 'Sakho']
# ['Fabian', 'Delph']
# ['Gabriel', 'Iván', 'Mercado']
# ['Bruno', '', 'Soriano', 'Llido']
# ['Fernando', 'Francisco', 'Reges']
# ['Lucas', 'David', 'Pratto']
# ['Sofiane', 'Feghouli']
# ['Mariano', 'Ferreira', 'Filho']
# ['Nikola', 'Kalinić']
# ['Ron-Robert', 'Zieler']
# ['Kwadwo', 'Asamoah']
# ['Igor', 'Smolnikov']
# ['Alex', 'Teixeira', 'dos', 'Santos']
# ['Ryad', 'Boudebouz']
# ['Victor', 'Wanyama']
# ['Sebastian', 'Rudy']
# ['Francis', 'Coquelin']
# ['Markel', 'Susaeta', 'Laskurain']
# ['Josef', 'de', 'Souza', 'Dias']
# ['Benjamin', 'Hübner']
# ['Jack', 'Wilshere']
# ['Vicente', 'Iborra', 'de', 'la', 'Fuente']
# ['Rafael', 'Pereira', 'da', 'Silva']
# ['Callum', 'Wilson']
# ['Daniel', 'Caligiuri']
# ['Benjamin', 'Stambouli']
# ['Ross', 'Barkley']
# ['Danilo', 'Luiz', 'da', 'Silva']
# ['Michael', 'Gregoritsch']
# ['Manuel', 'Agudo', 'Durán']
# ['José', 'Ángel', 'Gómez', 'Campaña']
# ['Hans', 'Vanaken']
# ['Steven', 'Berghuis']
# ['Mark', 'Uth']
# ['Djibril', 'Sidibé']
# ['Milan', 'Badelj']
# ['David', 'López', 'Silva']
# ['Gastón', 'Exequiel', 'Ramírez', 'Pereyra']
# ['Jordan', 'Veretout']
# ['Faustino', 'Marcos', 'Alberto', 'Rojo']
# ['Jeffrey', 'Gouweleeuw']
# ['Diego', 'Demme']
# ['Gerard', 'Deulofeu', 'Lázaro']
# ['Sergi', 'Darder', 'Moll']
# ['James', 'Tarkowski']
# ['Jannik', 'Vestergaard']
# ['Davy', 'Klaassen']
# ['José', 'Luís', 'Mendes', 'Andrade']
# ['Loris', 'Karius']
# ['Nick', 'Pope']
# ['Alejandro', 'Pozuelo', 'Melero']
# ['John', 'Anthony', 'Brooks']
# ['Santiago', 'Arias', 'Naranjo']
# ['Roque', 'Mesa', 'Quevedo']
# ['Kurt', 'Happy', 'Zouma']
# ['Mário', 'Rui', 'Silva', 'Duarte']
# ['Willi', 'Orban']
# ['Denis', 'Suárez', 'Fernández']
# ['Karim', 'Rekik']
# ['Daniele', 'Baselli']
# ['Zouhair', 'Feddal']
# ['Luka', 'Milivojević']
# ['Sergio', 'Rico', 'González']
# ['Michael', 'Keane']
# ['Roger', 'Martí', 'Salvador']
# ['Guido', 'Pizarro']
# ['Sead', 'Kolašinac']
# ['Joaquín', 'Correa']
# ['Duván', 'Zapata']
# ['Lucas', 'Alario']
# ['Davide', 'Zappacosta']
# ['Allan', 'Saint-Maximin']
# ['Diego', 'Carlos', 'Santos', 'Silva']
# ['Martin', 'Dúbravka']
# ['Harry', 'Winks']
# ['Franco', 'Cervi']
# ['Valentin', 'Rongier']
# ['David', 'Soria', 'Solís']
# ['Karl', 'Brillant', 'Toko', 'Ekambi']
# ['Dyego', 'Wilverson', 'Ferreira', 'Sousa']
# ['Cristian', 'David', 'Pavón']
# ['Martín', 'Campaña']
# ['Abdou', 'Diallo']
# ['Marcos', 'Llorente', 'Moreno']
# ['Benjamin', 'Verbič']
# ['Maximilian', 'Eggestein']
# ['Thilo', 'Kehrer']
# ['Gonzalo', 'Nicolás', 'Martínez']
# ['Benjamin', 'Pavard']
# ['Lucas', 'Tousart']
# ['Marko', 'Dmitrović']
# ['Francisco', 'das', 'Chagas', 'Soares', 'dos', 'Santos']
# ['Lorenzo', 'Pellegrini']
# ['Ferland', 'Mendy']
# ['Andrey', 'Lunev']
# ['Maikel', 'Renan', 'Catarino', 'Fagundes']
# ['A.', 'Benjamin', 'Chiamuloira', 'Paes']
# ['Melvin', 'Luan', 'Parrela', 'Porfírio']
# ['Bernard', 'Gabriel', 'Prestão', 'Chaves']
# ['Luan', 'Vágner', 'Boas', 'Macedo']
# ['Franck', 'Yannick', 'Kessié']
# ['Trent', 'Alexander-Arnold']
# ['Lautaro', 'Martínez']
# ['Jadon', 'Sancho']
# ['Raphael', 'Dias', 'Belloli']
# ['Lucas', 'Tolentino', 'Coelho', 'de', 'Lima']
# ['Federico', 'Chiesa']
# ['Rúben', 'Alves', 'Dias']
# ['Éder', 'Gabriel', 'Militão']
# ['Viktor', 'Tsygankov']
# ['Lorenzo', 'Morón', 'García']
# ['Ştefan', 'Daniel', 'Radu']
# ['Martin', 'Škrtel']
# ['Raúl', 'García', 'Escudero']
# ['Diego', 'Hernán', 'Váleri']
# ['Domenico', 'Criscito']
# ['Antonio', 'Candreva']
# ['Sergio', 'Germán', 'Romero']
# ['Iván', 'Marcano', 'Sierra']
# ['Pedro', 'León', 'Sánchez', 'Gil']
# ['Valter', 'Birsa']
# ['Ignacio', 'Piatti']
# ['Kévin', 'Gameiro']
# ['Augusto', 'Matías', 'Fernández']
# ['Mathieu', 'Valbuena']
# ['Beñat', 'Etxebarria', 'Urkiaga']
# ['Ignacio', 'Monreal', 'Eraso']
# ['Vitorino', 'Gabriel', '', 'Pacheco', 'Antunes']
# ['Alexandre', 'Rodrigues', 'da', 'Silva']
# ['Sidnei', 'Rechel', 'da', 'Silva', 'Júnior']
# ['Anthony', 'Modeste']
# ['Adil', 'Rami']
# ['Diego', 'Perotti']
# ['Ömer', 'Toprak']
# ['Mateo', 'Pablo', 'Musacchio']
# ['Sven', 'Ulreich']
# ['Yann', 'Gérard', "M'Vila"]
# ['Ignacio', 'Camacho', 'Barnola']
# ['Nicolas', "N'Koulou"]
# ['Manuel', 'Lanzini']
# ['香川', '真司']
# ['Vicente', 'Guaita', 'Panadero']
# ['Luuk', 'de', 'Jong']
# ['Chris', 'Smalling']
# ['Iago', 'Falqué', 'Silva']
# ['Jeroen', 'Zoet']
# ['Daley', 'Blind']
# ['Maicon', 'Pereira', 'Roque']
# ['Roberto', 'Pereyra']
# ['Ricardo', 'Rodríguez']
# ['Germán', 'Alejandro', 'Pezzella']
# ['Daniel', 'Didavi']
# ['André', 'Gomes', 'Magalhaes', 'de', 'Almeida']
# ['Andriy', 'Yarmolenko']
# ['Sergio', 'Enrich', 'Ametller']
# ['Pavel', 'Kadeřábek']
# ['Héctor', 'Bellerín', 'Moruno']
# ['Tomáš', 'Vaclík']
# ['Eran', 'Zahavi']
# ['Íñigo', 'Martínez', 'Berridi']
# ['Michy', 'Batshuayi', 'Tunga']
# ['Cristian', 'Portugués', 'Manzanera']
# ['乾', '貴士']
# ['Bernard', '', 'Anício', 'Caldeira', 'Duarte']
# ['Ben', 'Davies']
# ['Luke', 'Shaw']
# ['Taras', 'Stepanenko']
# ['Manuel', 'Trigueros', 'Muñoz']
# ['Leandro', 'Paredes']
# ['Carlos', 'Arturo', 'Bacca', 'Ahumada']
# ['Yussuf', 'Yurary', 'Poulsen']
# ['Hakan', 'Çalhanoğlu']
# ['Emre', 'Can']
# ['Nathan', 'Aké']
# ['Frederico', 'R.', 'de', 'Paula', 'Santos']
# ['Fernando', 'Pacheco', 'Flores']
# ['Juan', 'Fernando', 'Quintero']
# ['Elseid', 'Hysaj']
# ['Morgan', 'Sanson']
# ['Nicolás', 'Alejandro', 'Tagliafico']
# ['André', 'Filipe', 'Tavares', 'Gomes']
# ['José', 'Luís', 'Gayà', 'Peña']
# ['Santiago', 'Mina', 'Lorenzo']
# ['Marcos', 'Paulo', 'Mesquita', 'Lopes']
# ['Andreas', 'Christensen']
# ['Franco', 'Armani']
# ['Gerónimo', 'Rulli']
# ['Keita', 'Baldé']
# ['Iñaki', 'Williams', 'Arthuer']
# ['Jean', 'Michaël', 'Seri']
# ['Rafael', 'Alexandre', 'Fernandes', 'Ferreira', 'da', 'Silva']
# ['Mahmoud', 'Dahoud']
# ['Matias', 'Vecino']
# ['Ante', 'Rebić']
# ['Mattia', 'Caldara']
# ['Raúl', 'Michel', 'Melo', 'da', 'Silva']
# ['Mariano', 'Díaz', 'Mejía']
# ['Julian', 'Weigl']
# ['Marcos', 'Javier', 'Acuña']
# ['David', 'Villa', 'Sánchez']
# ['James', 'Philip', 'Milner']
# ['Luís', 'Carlos', 'Almeida', 'da', 'Cunha']
# ['Jesús', 'Navas', 'González']
# ['Santiago', 'Cazorla', 'González']
# ['Bafétimbi', 'Gomis']
# ['Łukasz', 'Fabiański']
# ['Renato', '', 'Soares', 'de', 'Oliveira', 'Augusto']
# ['Carlos', 'Alberto', 'Vela', 'Garrido']
# ['Danny', 'Rose']
# ['Erik', 'Lamela']
# ['Łukasz', 'Piszczek']
# ['Kevin-Prince', 'Boateng']
# ['Sven', 'Bender']
# ['Simon', 'Thorup', 'Kjær']
# ['Benedikt', 'Höwedes']
# ['Fernando', 'Muslera']
# ['Ljubomir', 'Fejsa']
# ['Cristhian', 'Ricardo', 'Stuani', 'Curbelo']
# ['Lars', 'Stindl']
# ['Fyodor', 'Smolov']
# ['Steven', "N'Kemboanza", 'Mike', 'Christopher', 'Nzonzi']
# ['Kevin', 'Trapp']
# ['Givanildo', 'Vieira', 'de', 'Souza']
# ['Iker', 'Muniain', 'Goñi']
# ['Stephan', 'El', 'Shaarawy']
# ['Eduardo', 'Antonio', 'Salvio']
# ['Javier', 'Matías', 'Pastore']
# ['Ander', 'Herrera', 'Agüera']
# ['Mario', 'Götze']
# ['Kevin', 'Vogt']
# ['Alphonse', 'Areola']
# ['Jesús', 'Corona']
# ['Dejan', 'Lovren']
# ['Simone', 'Verdi']
# ['Dušan', 'Tadić']
# ['Charles', 'Mariano', 'Aránguiz', 'Sandoval']
# ['Granit', 'Xhaka']
# ['Víctor', 'Machín', 'Pérez']
# ['Lucas', 'Digne']
# ['Nico', 'Schulz']
# ['Kevin', 'Volland']
# ['Josip', 'Iličić']
# ['Faouzi', 'Ghoulam']
# ['João', 'Mário', 'Naval', 'Costa', 'Eduardo']
# ['Ángel', 'Correa']
# ['Daniel', 'García', 'Carrillo']
# ['Marcelo', 'Brozović']
# ['José', 'Luis', 'Morales', 'Nogales']
# ['Tiémoué', 'Bakayoko']
# ['Victor', 'Nilsson', 'Lindelöf']
# ['Daniel', 'Ceballos', 'Fernández']
# ['Rúben', 'Diogo', 'da', 'Silva', 'Neves']
# ['Eric', 'Bailly']
# ['Pablo', 'Fornals', 'Malla']
# ['Gelson', 'Dany', 'Batalha', 'Martins']
# ['Onyinye', 'Wilfred', 'Ndidi']
# ['Moussa', 'Marega']
# ['Nélson', 'Cabral', 'Semedo']
# ['Manuel', 'Obafemi', 'Akanji']
# ['Leon', 'Bailey', 'Butler']
# ['Laureano', 'Thomas', 'Santeiro', 'Marre']
# ['Miguel', 'Almirón']
# ['Luka', 'Jović']
# ['Kai', 'Havertz']
# ['José', 'Manuel', '', 'Reina', 'Páez']
# ['Petr', 'Čech']
# ['Aritz', 'Aduriz', 'Zubeldia']
# ['Daniel', 'Alves', 'da', 'Silva']
# ['Héctor', 'Miguel', 'Herrera', 'López']
# ['Lucas', 'Rodrigo', 'Biglia']
# ['Fabio', 'Quagliarella']
# ['Moussa', 'Sidi', 'Yaya', 'Dembélé']
# ['João', 'Filipe', 'Iria', 'Santos', 'Moutinho']
# ['Francesc', 'Fàbregas', 'i', 'Soler']
# ['Andrea', 'Consigli']
# ['Steve', 'Mandanda']
# ['Laurent', 'Koscielny']
# ['Emiliano', 'Viviano']
# ['Jardel', 'Nivaldo', 'Vieira']
# ['Ezequiel', 'Marcelo', 'Garay']
# ['José', 'Andrés', 'Guardado', 'Hernández']
# ['Antonio', 'Adán', 'Garrido']
# ['Juan', 'Manuel', 'Mata', 'García']
# ['Olivier', 'Giroud']
# ['Ralf', 'Fährmann']
# ['Federico', 'Julián', 'Fazio']
# ['Vedran', 'Ćorluka']
# ['Pedro', 'Eliezer', 'Rodríguez', 'Ledesma']
# ['Kevin', 'Strootman']
# ['Kamil', 'Glik']
# ['Shkodran', 'Mustafi']
# ['Danijel', 'Subašić']
# ['Henrikh', 'Mkhitaryan']
# ['Thomas', 'Delaney']
# ['Xherdan', 'Shaqiri']
# ['Mário', 'Figueira', 'Fernandes']
# ['Willian', 'José', 'da', 'Silva']
# ['Sebastián', 'Coates', 'Nión']
# ['Marc', 'Bartra', 'Aregall']
# ['Jonathan', 'Viera', 'Ramos']
# ['Luis', 'Alberto', 'Romero', 'Alconchel']
# ['Wilfried', 'Zaha']
# ['Cédric', 'Bakambu']
# ['Wissam', 'Ben', 'Yedder']
# ['Jasper', 'Cillessen']
# ['Francisco', 'Alcácer', 'García']
# ['Benjamin', 'Lecomte']
# ['Álvaro', 'Borja', 'Morata', 'Martín']
# ['Gabriel', 'Armando', 'de', 'Abreu']
# ['Rafael', 'Alcântara', 'do', 'Nascimento']
# ['Salif', 'Sané']
# ['Thomas', 'Meunier']
# ['Karim', 'Bellarabi']
# ['Harry', 'Maguire']
# ['Alessandro', '', 'Florenzi']
# ['Arkadiusz', 'Milik']
# ['Antonio', 'Rüdiger']
# ['Sébastien', 'Haller']
# ['Franco', 'Vázquez']
# ['Jesse', 'Lingard']
# ['Josef', 'Alexander', 'Martínez']
# ['Emil', 'Forsberg']
# ['Andrea', 'Belotti']
# ['Jamie', 'Vardy']
# ['Thomas', 'Partey']
# ['Alejandro', 'Grimaldo', 'García']
# ['Piotr', 'Zieliński']
# ['Daniele', 'Rugani']
# ['Kerem', 'Demirbay']
# ['Thomas', 'Strakosha']
# ['Federico', 'Bernardeschi']
# ['Jiří', 'Pavlenka']
# ['Iker', 'Casillas', 'Fernández']
# ['Daniele', 'De', 'Rossi']
# ['Rune', '', 'Almenning', 'Jarstein']
# ['Andrea', 'Barzagli']
# ['Franck', 'Bilal', 'Ribéry']
# ['Kasper', 'Schmeichel']
# ['Salvatore', 'Sirigu']
# ['Sokratis', 'Papastathopoulos']
# ['Lucas', '', 'Pezzini', 'Leiva']
# ['Jonas', 'Gonçalves', 'Oliveira']
# ['Dimitri', '', 'Payet']
# ['Lars', 'Bender']
# ['Javier', 'Martínez', 'Aginaga']
# ['Rui', 'Pedro', 'dos', 'Santos', 'Patrício']
# ['Sergio', '', 'Asenjo', 'Andrés']
# ['David', 'Luiz', 'Moreira', 'Marinho']
# ['Georginio', 'Wijnaldum']
# ['Aleksandar', 'Kolarov']
# ['Oscar', 'dos', 'Santos', 'Emboaba', 'Júnior']
# ['Bas', 'Dost']
# ['Sergio', 'Canales', 'Madrazo']
# ['Bernd', 'Leno']
# ['Marcos', 'Alonso', 'Mendoza']
# ['Koen', 'Casteels']
# ['Idrissa', 'Gana', 'Gueye']
# ['Oliver', 'Baumann']
# ['Norberto', 'Murara', 'Neto']
# ['Kevin', 'Kampl']
# ['Luís', 'Miguel', 'Afonso', 'Fernandes']
# ['Rodrigo', 'Moreno', 'Machado']
# ['Pablo', 'Sarabia', 'García']
# ['Sergio', 'Roberto', 'Carnicer']
# ['Francesco', 'Acerbi']
# ['Timo', 'Horn']
# ['José', 'Ignacio', 'Fernández', 'Iglesias']
# ['Danilo', 'Luís', 'Hélio', 'Pereira']
# ['Lucas', 'Rodrigues', 'M.', 'Silva']
# ['Julian', 'Draxler']
# ['Jesús', 'Joaquín', 'Fernández', 'Sáez']
# ['Thorgan', 'Hazard']
# ['John', 'Stones']
# ['Stefan', 'Savić']
# ['Jordan', 'Pickford']
# ['Andrew', 'Robertson']
# ['Andrej', 'Kramarić']
# ['Corentin', 'Tolisso']
# ['Lucas', 'Hernández']
# ['Naby', 'Keïta']
# ['Presnel', 'Kimpembe']
# ['Lourival', 'Adnan', 'Beretta', 'Barbosa']
# ['Josué', 'Durval', 'Chiamulera', 'Vaz']
# ['Ronaldo', 'Jailson', 'Cabrais', 'Petri']
# ['Gabriel', 'Fernando', 'de', 'Jesus']
# ['Gianluigi', 'Donnarumma']
# ['Marcus', 'Rashford']
# ['Matthijs', 'de', 'Ligt']
# ['Arjen', 'Robben']
# ['Ricardo', 'Andrade', 'Quaresma', 'Bernardo']
# ['Alejandro', 'Darío', 'Gómez']
# ['Raúl', 'Albiol', 'Tortajada']
# ['Radamel', 'Falcao', 'García', 'Zárate']
# ['Stéphane', 'Ruffier']
# ['João', 'Miranda', 'de', 'Souza', 'Filho']
# ['Ronaldo', '', 'Aparecido', 'Rodrigues']
# ['Yann', 'Sommer']
# ['Éver', 'Maximiliano', 'David', 'Banega']
# ['Diego', 'da', 'Silva', 'Costa']
# ['Sami', 'Khedira']
# ['Willian', 'Borges', 'da', 'Silva']
# ['Alexis', 'Alejandro', 'Sánchez', 'Sánchez']
# ['José', 'María', 'Callejón', 'Bueno']
# ['İlkay', 'Gündoğan']
# ['Kyle', 'Walker']
# ['Roman', 'Bürki']
# ['Asier', 'Illarramendi', 'Andonegi']
# ['Lukáš', 'Hrádecký']
# ['Nemanja', 'Matić']
# ['Nicolás', 'Hernán', 'Otamendi']
# ['Iago', 'Aspas', 'Juncal']
# ['Juan', 'Cuadrado']
# ['David', 'Olatukunbo', 'Alaba']
# ['Mattia', 'Perin']
# ['Stefan', 'de', 'Vrij']
# ['Allan', 'Marques', 'Loureiro']
# ['Felipe', '', 'Anderson', 'Pereira', 'Gomes']
# ['Memphis', 'Depay']
# ['Florian', 'Thauvin']
# ['Képler', 'Laveran', 'Lima', 'Ferreira']
# ['Vincent', 'Kompany']
# ['Filipe', 'Luís', 'Kasmirski']
# ['Blaise', 'Matuidi']
# ['Mesut', 'Özil']
# ['Axel', '', 'Witsel']
# ['Radja', 'Nainggolan']
# ['Edin', 'Džeko']
# ['Ivan', 'Perišić']
# ['Mario', 'Mandžukić']
# ['Arturo', 'Vidal']
# ['Ángel', 'Fabián', 'Di', 'María', 'Hernández']
# ['Jérôme', 'Boateng']
# ['Yacine', 'Brahimi']
# ['José', 'Paulo', 'Bezzera', 'Maciel', 'Júnior']
# ['Daniel', 'Parejo', 'Muñoz']
# ['Douglas', 'Costa', 'de', 'Souza']
# ['Kostas', 'Manolas']
# ['Alexandre', 'Lacazette']
# ['Jorge', 'Resurrección', 'Merodio']
# ['Anthony', 'Lopes']
# ['손흥민', '孙兴慜']
# ['Riyad', 'Mahrez']
# ['Daniel', 'Carvajal', 'Ramos']
# ['Marcos', '', 'Aoás', 'Corrêa']
# ['Saúl', 'Ñíguez', 'Esclápez']
# ['Bamidele', 'Alli']
# ['Aymeric', '', 'Laporte']
# ['Sergej', 'Milinković-Savić']
# ['Karim', 'Benzema']
# ['Miralem', 'Pjanić']
# ['Leonardo', 'Bonucci']
# ['César', 'Azpilicueta', 'Tanco']
# ['Wojciech', '', 'Szczęsny']
# ['Thomas', 'Müller']
# ['Alex', 'Sandro', 'Lobo', 'Silva']
# ['Romelu', 'Lukaku']
# ['Marco', 'Verratti']
# ['Raphaël', 'Varane']
# ['Roberto', 'Firmino', 'Barbosa', 'de', 'Oliveira']
# ['Sadio', 'Mané']
# ['Ederson', 'Santana', 'de', 'Moraes']
# ['Joshua', 'Kimmich']
# ['Bernardo', 'Mota', 'Veiga', 'de', 'Carvalho', 'e', 'Silva']
# ['Leroy', 'Sané']
# ['Raheem', 'Sterling']
# ['Samuel', 'Umtiti']
# ['Alisson', 'Ramses', 'Becker']
# ['Gianluigi', 'Buffon']
# ['Gerard', 'Piqué', 'Bernabéu']
# ['Samir', 'Handanovič']
# ['Thiago', 'Emiliano', 'da', 'Silva']
# ['Hugo', 'Lloris']
# ['Gareth', 'Frank', 'Bale']
# ['Mats', '', 'Hummels']
# ['Marco', 'Reus']
# ['Pierre-Emerick', 'Aubameyang']
# ['Philippe', 'Coutinho', 'Correia']
# ["N'Golo", 'Kanté']
# ['Giorgio', 'Chiellini']
# ['Sergio', 'Ramos', 'García']
# ['David', 'Josué', 'Jiménez', 'Silva']
# ['Diego', 'Godín']
# ['Toni', 'Kroos']
# ['Robert', 'Lewandowski']
# ['Jan', 'Oblak']
# ['Harry', 'Kane']
# ['Luis', 'Alberto', 'Suárez', 'Díaz']
# ['Luka', 'Modrić']
# ['Eden', 'Hazard']
# ['Kevin', 'De', 'Bruyne']
# ['David', 'De', 'Gea', 'Quintana']
# ['Neymar', 'da', 'Silva', 'Santos', 'Junior']
# ['Cristiano', 'Ronaldo', 'dos', 'Santos', 'Aveiro']
# ['Janni-Luca', 'Serra']
# ['Angel', 'Rodriguez']
# ['André', 'Calisir']
# ['Róger', 'Mauricio', 'Torres', 'Hoya']
# ['Rory', '', 'McKenzie']
# ['Michal', 'Sipľak']
# ['Jan', 'Bekkema']
# ['Abdulrahman', 'Al', 'Yami']
# ['José', 'Francisco', 'dos', 'Santos', 'Júnior']

# %%
# Ok--new problems discoverd!
# 1) Lots of players have >2 names
# 2) It's not obvious how to interpret multiple fields
#   e.g. Is it a hyphenated last name?
#        Is it latin-style and including mother's & father's surnames
#        Is "del Castillo" part of the formal name?
# 3) Some players have "Junior", etc. suffixes
# 4) We imported the header row as "full_name"
#
#

# %%
# Can we use the name column to infer which block is the surname?
lines[0:17]

# Maybe?   Let's print just the name and full_name
# Out:
# ['name,full_name,birth_date,age,height_cm,weight_kgs,positions,nationality,overall_rating,potential,value_euro,wage_euro,preferred_foot,international_reputation(1-5),weak_foot(1-5),skill_moves(1-5),body_type,release_clause_euro,national_team,national_rating,national_team_position,national_jersey_number,crossing,finishing,heading_accuracy,short_passing,volleys,dribbling,curve,freekick_accuracy,long_passing,ball_control,acceleration,sprint_speed,agility,reactions,balance,shot_power,jumping,stamina,strength,long_shots,aggression,interceptions,positioning,vision,penalties,composure,marking,standing_tackle,sliding_tackle\n',
#  'L. Messi,Lionel Andrés Messi Cuccittini,6/24/1987,31,170.18,72.1,"CF,RW,ST",Argentina,94,94,110500000,565000,Left,5,4,4,Messi,226500000,Argentina,82,RF,10,86,95,70,92,86,97,93,94,89,96,91,86,93,95,95,85,68,72,66,94,48,22,94,94,75,96,33,28,26\n',
#  'C. Eriksen,Christian  Dannemann Eriksen,2/14/1992,27,154.94,76.2,"CAM,RM,CM",Denmark,88,89,69500000,205000,Right,3,5,4,Lean,133800000,Denmark,78,CAM,10,88,81,52,91,80,84,86,87,89,91,76,73,80,88,81,84,50,92,58,89,46,56,84,91,67,88,59,57,22\n',
#  'P. Pogba,Paul Pogba,3/15/1993,25,190.5,83.9,"CM,CAM",France,88,91,73000000,255000,Right,4,4,5,Normal,144200000,France,84,RDM,6,80,75,75,86,85,87,85,82,90,90,71,79,76,82,66,90,83,88,87,82,78,64,82,88,82,87,63,67,67\n',
#  'L. Insigne,Lorenzo Insigne,6/4/1991,27,162.56,59,"LW,ST",Italy,88,88,62000000,165000,Right,3,4,4,Normal,105400000,Italy,83,LW,10,86,77,56,85,74,90,87,77,78,93,94,86,94,83,93,75,53,75,44,84,34,26,83,87,61,83,51,24,22\n',
#  'K. Koulibaly,Kalidou Koulibaly,6/20/1991,27,187.96,88.9,CB,Senegal,88,91,60000000,135000,Right,3,3,2,Normal,106500000,,,,,30,22,83,68,14,69,28,28,60,63,70,75,50,82,40,55,81,75,94,15,87,88,24,49,33,80,91,88,87\n',
#  'V. van Dijk,Virgil van Dijk,7/8/1991,27,193.04,92.1,CB,Netherlands,88,90,59500000,215000,Right,3,3,2,Normal,114500000,Netherlands,81,LCB,4,53,52,83,79,45,70,60,70,81,76,74,77,61,87,49,81,88,75,92,64,82,88,41,60,62,87,90,89,84\n',
#  'K. Mbappé,Kylian Mbappé,12/20/1998,20,152.4,73,"RW,ST,RM",France,88,95,81000000,100000,Right,3,4,5,Lean,166100000,France,84,RM,10,77,88,77,82,78,90,77,63,73,91,96,96,92,87,83,79,75,83,71,78,62,38,88,82,70,86,34,34,32\n',
#  'S. Agüero,Sergio Leonel Agüero del Castillo,6/2/1988,30,172.72,69.9,ST,Argentina,89,89,64500000,300000,Right,4,4,4,Stocky,119300000,Argentina,82,SUB,11,70,93,77,81,85,89,82,73,64,89,88,80,86,90,91,88,81,76,73,83,65,24,92,83,83,90,30,20,12\n',
#  'M. Neuer,Manuel Neuer,3/27/1986,32,193.04,92.1,GK,Germany,89,89,38000000,130000,Right,5,4,1,Normal,62700000,Germany,85,GK,1,15,13,25,55,11,30,14,11,59,46,54,60,51,84,35,25,77,43,80,16,29,30,12,70,47,70,17,10,11\n',
#  'E. Cavani,Edinson Roberto Cavani Gómez,2/14/1987,32,185.42,77.1,ST,Uruguay,89,89,60000000,200000,Right,4,4,3,Lean,111000000,Uruguay,81,LS,21,70,89,89,78,90,80,77,76,52,82,75,76,77,91,59,87,88,92,78,79,84,48,93,77,85,82,52,45,39\n',
#  'Sergio Busquets,Sergio Busquets i Burgos,7/16/1988,30,187.96,76.2,"CDM,CM",Spain,89,89,51500000,315000,Right,4,3,3,Lean,105600000,Spain,85,CDM,5,62,67,68,89,44,80,66,68,82,88,50,52,66,87,52,61,66,86,77,54,85,87,77,87,60,93,90,86,80\n',
#  'T. Courtois,Thibaut Courtois,5/11/1992,26,198.12,96.2,GK,Belgium,89,90,53500000,240000,Left,4,2,1,Courtois,113700000,Belgium,85,GK,1,14,14,13,33,12,13,19,20,35,23,46,52,61,84,45,36,68,38,70,17,23,15,13,44,27,66,20,18,16\n',
#  'M. ter Stegen,Marc-André ter Stegen,4/30/1992,26,187.96,84.8,GK,Germany,89,92,58000000,240000,Right,3,4,1,Normal,123300000,Germany,85,SUB,22,18,14,11,42,14,17,18,12,47,18,38,50,37,86,43,22,79,35,78,10,43,22,11,70,25,70,25,13,10\n',
#  'A. Griezmann,Antoine Griezmann,3/21/1991,27,175.26,73,"CF,ST",France,89,90,78000000,145000,Left,4,3,4,Lean,165800000,France,84,CAM,7,82,89,84,84,87,87,86,84,78,90,88,85,90,90,82,82,90,86,62,82,73,49,91,85,83,89,59,54,48\n',
#  'M. Salah,Mohamed  Salah Ghaly,6/15/1992,26,175.26,71.2,"RW,ST",Egypt,89,90,78500000,265000,Left,3,3,4,PLAYER_BODY_TYPE_25,151100000,Egypt,73,RM,10,78,90,59,83,76,89,83,60,74,88,94,91,91,92,88,80,68,84,70,83,63,55,92,84,75,91,38,43,41\n',
#  'P. Dybala,Paulo Bruno Exequiel Dybala,11/15/1993,25,152.4,74.8,"CAM,RW",Argentina,89,94,89000000,205000,Left,3,3,4,Normal,153500000,Argentina,82,LF,21,82,84,68,87,88,92,88,88,75,92,87,83,91,86,85,82,75,80,65,88,48,32,84,87,86,84,23,20,20\n']

# %%
for thisplayer in lines:
    print(thisplayer.split(',')[0:2])
# Out:
# ['name', 'full_name']
# ['L. Messi', 'Lionel Andrés Messi Cuccittini']
# ['C. Eriksen', 'Christian  Dannemann Eriksen']
# ['P. Pogba', 'Paul Pogba']
# ['L. Insigne', 'Lorenzo Insigne']
# ['K. Koulibaly', 'Kalidou Koulibaly']
# ['V. van Dijk', 'Virgil van Dijk']
# ['K. Mbappé', 'Kylian Mbappé']
# ['S. Agüero', 'Sergio Leonel Agüero del Castillo']
# ['M. Neuer', 'Manuel Neuer']
# ['E. Cavani', 'Edinson Roberto Cavani Gómez']
# ['Sergio Busquets', 'Sergio Busquets i Burgos']
# ['T. Courtois', 'Thibaut Courtois']
# ['M. ter Stegen', 'Marc-André ter Stegen']
# ['A. Griezmann', 'Antoine Griezmann']
# ['M. Salah', 'Mohamed  Salah Ghaly']
# ['P. Dybala', 'Paulo Bruno Exequiel Dybala']
# ['M. Škriniar', 'Milan Škriniar']
# ['Fernandinho', 'Fernando Luiz Rosa']
# ['G. Higuaín', 'Gonzalo Gerardo Higuaín']
# ['I. Rakitić', 'Ivan Rakitić']
# ['J. Vertonghen', 'Jan Vertonghen']
# ['D. Mertens', 'Dries Mertens']
# ['Marcelo', 'Marcelo Vieira da Silva Júnior']
# ['T. Alderweireld', 'Toby Alderweireld']
# ['Jordi Alba', 'Jordi Alba Ramos']
# ['Thiago', 'Thiago Alcântara do Nascimento']
# ['C. Immobile', 'Ciro Immobile']
# ['K. Navas', 'Keylor Navas']
# ['Isco', 'Francisco Román Alarcón Suárez']
# ['J. Rodríguez', 'James David Rodríguez Rubio']
# ['Casemiro', 'Carlos Henrique Venancio Casimiro']
# ['M. Icardi', 'Mauro Emanuel Icardi Rivero']
# ['Kepa', 'Kepa Arrizabalaga']
# ['H. Ziyech', 'Hakim Ziyech']
# ['Fabinho', 'Fábio Henrique Tavares']
# ['A. Martial', 'Anthony Martial']
# ['T. Werner', 'Timo Werner']
# ['N. Süle', 'Niklas Süle']
# ['Bruno Fernandes', 'Bruno Miguel Borges Fernandes']
# ['Alex Telles', 'Alex Nicolao Telles']
# ['J. Giménez', 'José María Giménez de Vargas']
# ['N. Fekir', 'Nabil Fekir']
# ['D. Sánchez', 'Davinson Sánchez']
# ['Marco Asensio', 'Marco Asensio Willemsen']
# ['O. Dembélé', 'Ousmane Dembélé']
# ['Iniesta', 'Andrés Iniesta Luján']
# ['Z. Ibrahimović', 'Zlatan Ibrahimović']
# ['Jorginho', 'Luiz Frello Filho Jorge']
# ['E. Višća', 'Edin Višća']
# ['S. Gnabry', 'Serge Gnabry']
# ['M. Kovačić', 'Mateo Kovačić']
# ['William Carvalho', 'William Silva de Carvalho']
# ['Felipe', 'Felipe Augusto de Almeida Monteiro']
# ['Y. Carrasco', 'Yannick Ferreira Carrasco']
# ['Lucas Vázquez', 'Lucas Vázquez Iglesias']
# ['Q. Promes', 'Quincy Anton Promes']
# ['L. Goretzka', 'Leon Goretzka']
# ['A. Rabiot', 'Adrien Rabiot']
# ['A. Romagnoli', 'Alessio Romagnoli']
# ['João Cancelo', 'João Pedro Cavaco Cancelo']
# ['Anderson Talisca', 'Anderson Souza Conceição']
# ['K. Coman', 'Kingsley Coman']
# ['T. Lemar', 'Thomas Lemar']
# ['J. Tah', 'Jonathan Tah']
# ['M. Politano', 'Matteo Politano']
# ['C. Lenglet', 'Clément Lenglet']
# ['Pau López', 'Pau López Sabata']
# ['H. Lozano', 'Hirving Rodrigo Lozano Bahena']
# ['Malcom', 'Malcom Filipe Silva de Oliveira']
# ['L. Torreira', 'Lucas Torreira Di Pascua']
# ['Gonçalo Guedes', 'Gonçalo Manuel Ganchinho Guedes']
# ['G. Lo Celso', 'Giovani Lo Celso']
# ['Fabián', 'Fabián Ruiz Peña']
# ['F. de Jong', 'Frenkie de Jong']
# ['Raphaelito Anjos', 'Raphael William Anjos Rochedo']
# ['Juiano Mestres', 'Juan Everton Mestres de Mesquita']
# ['Rosberto Dourado', 'Rosberto J. Dourado Santos']
# ['Arthur', 'Arthur Henrique Ramos Oliveira Melo']
# ['Rodri', 'Rodrigo Hernández Cascante']
# ['M. Parolo', 'Marco Parolo']
# ['M. Kruse', 'Max Kruse']
# ['J. Henderson', 'Jordan Brian Henderson']
# ['N. Gaitán', 'Osvaldo Nicolás Fabián Gaitán']
# ['M. Arnautović', 'Marko Arnautović']
# ['S. Giovinco', 'Sebastian Giovinco']
# ['G. Sigurðsson', 'Gylfi Þór Sigurðsson']
# ['Giuliano', 'Giuliano Victor de Paula']
# ['P. Gulácsi', 'Péter Gulácsi']
# ['Luiz Gustavo', 'Luiz Gustavo Dias']
# ['K. Trippier', 'Kieran Trippier']
# ['A. Ramsey', 'Aaron Ramsey']
# ['M. Balotelli', 'Mario  Barwuah Balotelli']
# ['Marlos', 'Marlos Romero Bonfim']
# ['Taison', 'Taison Barcellos Freda']
# ['G. Bonaventura', 'Giacomo Bonaventura']
# ['G. Kondogbia', 'Geoffrey Kondogbia']
# ['J. Roussillon', 'Jérôme Roussillon']
# ['S. Zaza', 'Simone Zaza']
# ['S. Vrsaljko', 'Šime Vrsaljko']
# ['C. Kramer', 'Christoph Kramer']
# ['B. Mendy', 'Benjamin Mendy']
# ['M. Sabitzer', 'Marcel Sabitzer']
# ['M. Nastasić', 'Matija Nastasić']
# ['A. Plea', 'Alassane Plea']
# ['M. Ginter', 'Matthias Ginter']
# ['Gerard Moreno', 'Gerard Moreno Balagueró']
# ['A. Doucouré', 'Abdoulaye Doucouré']
# ['R. Guerreiro', 'Raphaël Guerreiro']
# ['Ricardo Pereira', 'Ricardo Barbosa Pereira']
# ['Samu Castillejo', 'Samuel Castillejo Azuaga']
# ['J. Brandt', 'Julian Brandt']
# ['N. Pépé', 'Nicolas Pépé']
# ['S. Bergwijn', 'Steven Bergwijn']
# ['A. Onana', 'André Onana']
# ['F. Balbuena', 'Fabián Balbuena']
# ['André Silva', 'André Miguel Valente da Silva']
# ['Oyarzabal', 'Mikel Oyarzabal Ugarte']
# ['Everton Andrão', 'Everton Jorge Andrade Zanon']
# ['Welington Dano', 'Welington Kauê Dano Nascimento']
# ['Richarlison', 'Richarlison de Andrade']
# ['Odriozola', 'Álvaro Odriozola Arzalluz']
# ['Carlos Soler', 'Carlos Soler Barragán']
# ['H. Aouar', 'Houssem Aouar']
# ['T. Ndombele', 'Tanguy NDombèlé Alvaro']
# ['M. Gómez', 'Maximiliano Gómez']
# ['Joaquín', 'Joaquín Sánchez Rodríguez']
# ['J. Mathieu', 'Jérémy Mathieu']
# ['J. Matip', 'Joël Andre Job Matip']
# ['S. Aurier', 'Serge Aurier']
# ['J. Guilavogui', 'Josuha Guilavogui']
# ['A. Oxlade-Chamberlain', 'Alex Oxlade-Chamberlain']
# ['M. Ryan', 'Mathew Ryan']
# ['V. Aboubakar', 'Vincent Paté Aboubakar']
# ['L. Muriel', 'Luis Fernando Muriel Fruto']
# ['D. Vida', 'Domagoj Vida']
# ['Ibai Gómez', 'Ibai Gómez Pérez']
# ['Cristian Tello', 'Cristian Tello Herrera']
# ['Ismaily', 'Ismaily Gonçalves dos S.']
# ['A. Mandi', 'Aïssa Mandi']
# ['C. Tătăruşanu', 'Anton Ciprian Tătărușanu']
# ['J. Murillo', 'Jeison Fabián Murillo Cerón']
# ['E. Dier', 'Eric Dier']
# ['J. Butland', 'Jack Butland']
# ['S. Sorrentino', 'Stefano Sorrentino']
# ['W. Rooney', 'Wayne Mark Rooney']
# ['Moyá', 'Miguel Ángel Moyá Rumbo']
# ['L. López', 'Lisandro López']
# ['J. Mascherano', 'Javier Alejandro Mascherano']
# ['Raffael', 'Raffael Caetano de Araújo']
# ['Diego López', 'Diego López Rodríguez']
# ['Juanfran', 'Juan Francisco Torres Belén']
# ['I. Denisov', 'Igor Denisov']
# ['I. Akinfeev', 'Igor Akinfeev']
# ['A. Gignac', 'André-Pierre Gignac']
# ['A. Granqvist', 'Andreas Granqvist']
# ['Manuel Fernandes', 'Manuel Henrique Tavares Fernandes']
# ['Dante', 'Dante Bonfim da Costa Santos']
# ['L. Perrin', 'Loïc Perrin']
# ['Borja Valero', 'Borja Valero Iglesias']
# ['A. Januzaj', 'Adnan Januzaj']
# ['J. Hector', 'Jonas Hector']
# ['M. Dabbur', 'Moanes Dabour']
# ['Óliver Torres', 'Óliver Torres Muñoz']
# ['Y. Bounou', 'Yassine Bounou']
# ['J. Hofmann', 'Jonas Hofmann']
# ['Otávio', 'Otávio Edmilson da Silva Monteiro']
# ['Jonny', 'Jonathan Castro Otto']
# ['L. Dendoncker', 'Leander Dendoncker']
# ['R. Zobnin', 'Roman Zobnin']
# ['Ricardo Horta', 'Ricardo Jorge da Luz Horta']
# ['Thiago Mendes', 'Thiago Henrique Mendes Ribeiro']
# ['J. Lerma', 'Jefferson Andrés Lerma Solís']
# ['J. Gbamin', 'Jean-Philippe Gbamin']
# ['I. Marcone', 'Iván Marcone']
# ['D. Benedetto', 'Darío Benedetto']
# ['M. Hitz', 'Marwin Hitz']
# ['N. Clyne', 'Nathaniel Edwin Clyne']
# ['A. Ljajić', 'Adem Ljajić']
# ['J. Guðmundsson', 'Johann  Berg Guðmunds\xadson']
# ['Elkeson', 'Elkeson de Oliveira Cardoso']
# ['Kike García', 'Enrique García Martínez']
# ['Escudero', 'Sergio Escudero Palomo']
# ['Herrerín', 'Iago Herrerín Buisán']
# ['Víctor Ruiz', 'Víctor Ruíz Torre']
# ['G. Medel', 'Gary Alexis Medel Soto']
# ['Y. Belhanda', 'Younès Belhanda']
# ['Hugo Mallo', 'Hugo Mallo Novegil']
# ['Borja García', 'Borja García Freire']
# ['W. Khazri', 'Wahbi Khazri']
# ['P. Jones', 'Phil Jones']
# ['A. Finnbogason', 'Alfreð Finnbogason']
# ['Vinícius Júnior', 'Vinícius José de Oliveira Júnior']
# ['Junior Firpo', 'Héctor Junior Firpo Adamés']
# ['E. Belözoğlu', 'Emre Belözoğlu']
# ['Fernando Torres', 'Fernando José Torres Sanz']
# ['B. Schweinsteiger', 'Bastian Schweinsteiger']
# ['B. Yılmaz', 'Burak Yılmaz']
# ['M. Gómez', 'Mario Gómez García']
# ['A. Young', 'Ashley Young']
# ['R. Babel', 'Ryan Guno Babel']
# ['B. Costil', 'Benoît Costil']
# ['S. Kalou', 'Salomon Armand Magloire Kalou']
# ['E. Lavezzi', 'Ezequiel Iván Lavezzi']
# ['H. Ben Arfa', 'Hatem Ben Arfa']
# ['B. Foster', 'Ben Foster']
# ['T. Heaton', 'Tom Heaton']
# ['Charles', 'Charles Dias De Oliveira']
# ['G. Cahill', 'Gary Cahill']
# ['A. Iwobi', 'Alex Iwobi']
# ['R. Loftus-Cheek', 'Ruben Loftus-Cheek']
# ['A. Selikhov', 'Alexandr Selikhov']
# ['J. Mojica', 'Johan Andrés Mojica Palacio']
# ['W. Barrios', 'Wílmar Enrique Barrios Terán']
# ['C. Izquierdoz', 'Carlos Roberto Izquierdoz']
# ['W. Benítez', 'Walter Benítez']
# ['N. Maksimović', 'Nikola Maksimović']
# ['A. Mitrović', 'Aleksandar Mitrović']
# ['M. Sportiello', 'Marco Sportiello']
# ['Capa', 'Ander Capa Rodríguez']
# ['Marcelo Goiano', 'Marcelo Augusto Ferreira Teixeira']
# ['Y. Tielemans', 'Youri Tielemans']
# ['S. Lobotka', 'Stanislav Lobotka']
# ['M. Philipp', 'Maximilian Philipp']
# ['L. Dubois', 'Léo Dubois']
# ['L. Dunk', 'Lewis Dunk']
# ['C. Schindler', 'Christopher Schindler']
# ['Y. Konoplyanka', 'Yevhen Konoplyanka']
# ['Pedro Mendes', 'Pedro Filipe Teodósio Mendes']
# ['R. Saponara', 'Riccardo Saponara']
# ['L. Kurzawa', 'Layvin Kurzawa']
# ['M. Hinteregger', 'Martin Hinteregger']
# ['D. da Costa', 'Danny  Vieira da Costa']
# ['Fernando', 'Fernando Lucas Martins']
# ['W. Boly', 'Willy Boly']
# ['A. Schwolow', 'Alexander Schwolow']
# ['G. Defrel', 'Gregoire Defrel']
# ['Álvaro', 'Álvaro González Soberón']
# ['L. Bittencourt', 'Leonardo Bittencourt']
# ['A. Carrillo', 'André Martín Carrillo Díaz']
# ['M. Elyounoussi', 'Mohamed Elyounoussi']
# ['O. Karnezis', 'Orestis Karnezis']
# ['De Marcos', 'Óscar de Marcos Arana']
# ['R. Cabella', 'Rémy Cabella']
# ['J. Hart', 'Joe Hart']
# ['Jurado', 'José Manuel Jurado Marín']
# ['E. Hernández', 'Elías Hernán Hernández Jacuinde']
# ['D. Ginczek', 'Daniel Ginczek']
# ['Lucas Pérez', 'Lucas Pérez Martínez']
# ['J. Farfán', 'Jefferson Agustín Farfán Guadalupe']
# ['A. Begović', 'Asmir Begović']
# ['Hilton', 'Vitorino Hilton da Silva']
# ['J. Baumgartlinger', 'Julian Baumgartlinger']
# ['Granero', 'Esteban Félix Granero Molina']
# ['Z. Junuzović', 'Zlatko Junuzović']
# ['V. Moses', 'Victor Moses']
# ['M. Debuchy', 'Mathieu Debuchy']
# ['G. Maripán', 'Guillermo Alfonso Maripán Loaysa']
# ['Iván Cuéllar', 'Iván Cuéllar Sacristán']
# ['F. Johnson', 'Fabian Johnson']
# ['Aarón Martín', 'Aarón Martín Caricol']
# ['G. Pereiro', 'Gastón Rodrigo Pereiro López']
# ['B. Moukandjo', 'Benjamin Moukandjo Bilé']
# ['M. Harnik', 'Martin Harnik']
# ['J. Ward-Prowse', 'James  Ward-Prowse']
# ['R. Alessandrini', 'Romain Alessandrini']
# ['Manu García', 'Manuel Alejandro García Sánchez']
# ['M. Antonio', 'Michail Antonio']
# ['Adrien Silva', 'Adrien Sebastian Perruchet Silva']
# ['S. Cook', 'Steve Cook']
# ['B. Mee', 'Ben Mee']
# ['Adriano', 'Adriano Correia Claro']
# ['J. Lens', 'Jeremain Lens']
# ['S. Rondón', 'José Salomón Rondón Giménez']
# ['Andreas Pereira', 'Andreas Hugo Hoelgebaum Pereira']
# ['V. Ibišević', 'Vedad Ibišević']
# ['L. Ocampos', 'Lucas Ocampos']
# ['N. Müller', 'Nicolai Müller']
# ['Simão Acunha', 'Simão Alvin Acunha Bardini']
# ['J. Calleri', 'Jonathan Calleri']
# ['A. Jahanbakhsh', 'Alireza Jahanbakhsh']
# ['A. Prijović', 'Aleksandar Prijović']
# ['Fabricio', 'Fabricio Martín Agosto Ramírez']
# ['M. Elneny', 'Mohamed Elneny']
# ['Jorge Meré', 'Jorge Meré Pérez']
# ['Wilson Eduardo', 'Wilson Bruno Naval Costa Eduardo']
# ['Álex Remiro', 'Alejandro Remiro Gargallo']
# ['T. Gutiérrez', 'Teófilo Gutiérrez']
# ['A. Pyatov', 'Andriy Pyatov']
# ['Diego Llorente', 'Diego Javier Llorente Ríos']
# ['I. Abate', 'Ignazio Abate']
# ['T. Vermaelen', 'Thomas Vermaelen']
# ['N. Füllkrug', 'Niclas Füllkrug']
# ['Pedro Obiang', 'Pedro  Mba Obiang Avomo']
# ['Wallace', 'Wallace Fortuna dos Santos']
# ['Djaniny', 'Jorge Djaniny  Tavares Semedo']
# ['Roberto', 'Roberto Jiménez Gago']
# ['S. Tasci', 'Serdar Taşçı']
# ['L. Schøne', 'Lasse Schøne']
# ['J. Defoe', 'Jermain  Defoe']
# ['V. Babacan', 'Volkan Babacan']
# ['O. Ighalo', 'Odion Jude Ighalo']
# ['A. Schürrle', 'André Schürrle']
# ['E. Skhiri', 'Ellyes Skhiri']
# ['W. Anton', 'Waldemar Anton']
# ['R. Palacio', 'Rodrigo Sebastián Palacio']
# ['K. Lasagna', 'Kevin Lasagna']
# ['D. Cvitanich', 'Darío Cvitanich']
# ['S. De Maio', 'Sebastian De Maio']
# ['S. Terodde', 'Simon Terodde']
# ['J. De Guzmán', 'Jonathan  de Guzmán']
# ['R. Civelli', 'Renato Civelli']
# ['Pablo Maffeo', 'Pablo Maffeo Becerra']
# ['Cédric', 'Cédric Ricardo Alves Soares']
# ['K. Papadopoulos', 'Kyriakos Papadopoulos']
# ['A. Szymanowski', 'Alexander Szymanowski']
# ['J. Kucka', 'Juraj Kucka']
# ['P. Jagielka', 'Phil Jagielka']
# ['M. Benassi', 'Marco Benassi']
# ['P. Jansson', 'Pontus Jansson']
# ['B. Espinosa', 'Bernardo José Espinosa Zúñiga']
# ['José Sá', 'José Pedro Malheiro de Sá']
# ['M. Sels', 'Matz Sels']
# ['Yuri Berchiche', 'Yuri Berchiche Izeta']
# ['R. Borré', 'Rafael Santos Borré']
# ['Paulinho', 'João Paulo Dias Fernandes']
# ['C. Piccini', 'Cristiano Piccini']
# ['B. André', 'Benjamin André']
# ['Barragán', 'Antonio Barragán Fernández']
# ['M. Samatta', 'Mbwana Ally Samatta']
# ['I. Diop', 'Issa Diop']
# ['M. Lowton', 'Matthew Lowton']
# ['T. Hernández', 'Theo Bernard François Hernández']
# ['Juanpe', 'Juan Pedro Ramírez López']
# ['K. Tete', 'Kenny Tete']
# ['B. Džemaili', 'Blerim Džemaili']
# ['André André', 'André Filipe Brás André']
# ['Balenziaga', 'Mikel Balenziaga Oruesagasti']
# ['V. Behrami', 'Valon Behrami']
# ['D. Reyes', 'Diego Antonio Reyes Rosales']
# ['Caiuby', 'Caiuby Francisco da Silva']
# ['S. Doumbia', 'Seydou Doumbia']
# ['João Félix', 'João Félix Sequeira']
# ['L. López', 'Lisandro López']
# ['Mario Suárez', 'Mario Suárez Mata']
# ['J. Lössl', 'Jonas Lössl']
# ['G. Castro', 'Gonzalo Castro Randon']
# ['M. Phillips', 'Matt Phillips']
# ['Gabriel Boschilia', 'Gabriel Boschilia']
# ['Wu Lei', '武磊']
# ['N. Blandi', 'Nicolás Blandi']
# ['L. Kalinić', 'Lovre Kalinić']
# ['F. Fernández', 'Federico Fernández']
# ['J. Martínez', 'Jackson Martínez']
# ['Emerson', 'Emerson Palmieri dos Santos']
# ['Rômulo', 'Rômulo  Souza Orestes Caldeira']
# ['C. Benteke', 'Christian Benteke Liolo']
# ['M. Rashica', 'Milot Rashica']
# ['L. Baines', 'Leighton Baines']
# ['M. Noble', 'Mark Noble']
# ['F. Benković', 'Filip Benković']
# ['C. Riveros', 'Cristian Miguel Riveros Núñez']
# ['M. Niang', "M'Baye Babacar Niang"]
# ['D. Santon', 'Davide Santon']
# ['I. Ordets', 'Ivan Ordets']
# ['Francisco Geraldes', 'Francisco Geraldes']
# ['R. Snodgrass', 'Robert Snodgrass']
# ['Vitor Hugo', 'Vitor Hugo Franchescoli de Souza']
# ['M. Pašalić', 'Mario Pašalić']
# ['F. Borini', 'Fabio Borini']
# ['N. Vukčević', 'Nikola Vukčević']
# ['A. Hutchinson', 'Atiba Hutchinson']
# ['M. Moralez', 'Maximiliano Nicol Moralez']
# ['C. Austin', 'Charlie Austin']
# ['Kenedy', 'Robert Kenedy Nunes do Nascimento']
# ['Eltildo Correia', 'Eltildo Lucas Correia Pitta']
# ['João Pedro', 'João Pedro Geraldino dos Santos Galvão']
# ['A. Diamanti', 'Alessandro Diamanti']
# ['Guilherme', 'Guilherme dos Santos Torres']
# ['J. Morel', 'Jérémy Morel']
# ['Llorente', 'Fernando Javier Llorente Torres']
# ['G. Gönül', 'Gökhan Gönül']
# ['A. Paloschi', 'Alberto Paloschi']
# ['Juli Freitinho', 'Julio Leonardo Dourado de Freitas']
# ['Markel Bergara', 'Markel Bergara Larrañaga']
# ['L. Nguyen', 'Lee Nguyen']
# ['A. Knockaert', 'Anthony Knockaert']
# ['Córdoba', 'Iñigo Córdoba Kerejeta']
# ['J. Veltman', 'Joël Veltman']
# ['N. Sansone', 'Nicola Sansone']
# ['A. Turan', 'Arda Turan']
# ['H. Seferović', 'Haris Seferović']
# ['Rafael Cachoira', 'Rafael Jorgino Cachoira Rebelo']
# ['A. Haidara', 'Amadou Haidara']
# ['F. Caputo', 'Francesco Caputo']
# ['M. Locatelli', 'Manuel Locatelli']
# ['J. Ayew', 'Jordan Ayew']
# ['T. Jedvaj', 'Tin Jedvaj']
# ['S. Hanni', 'Sofiane Hanni']
# ['Andrés Fernández', 'Andrés Eduardo Fernández Moreno']
# ['T. Monconduit', 'Thomas Monconduit']
# ['N. Mukiele', 'Nordi Mukiele']
# ['D. Heintz', 'Dominique Heintz']
# ['Júnior Caiçara', 'Uílson de Souza Paula Júnior']
# ['A. Lennon', 'Aaron  Lennon']
# ['J. Willems', 'Jetro Willems']
# ['M. Veljković', 'Miloš Veljković']
# ['I. Belfodil', 'Ishak Belfodil']
# ['Miguel Lopes', 'Hugo Miguel Almeida Costa Lopes']
# ['D. Stephens', 'Dale Stephens']
# ['Brais Méndez', 'Brais Méndez Portela']
# ['A. Smith', 'Adam Smith']
# ['Recio', 'José Luis García del Pozo']
# ['Kiko Femenía', 'Francisco Femenía Far']
# ['M. Gaćinović', 'Mijat Gaćinović']
# ['P. Skjelbred', 'Per Ciljan Skjelbred']
# ['Fernandinho', 'Da Conceição Fernando Henrique']
# ['S. Brown', 'Scott Brown']
# ['M. Grujić', 'Marko Grujić']
# ['A. Soumaoro', 'Adama Soumaoro']
# ['Raúl Navas', 'Raúl Rodríguez Navas']
# ['A. Szalai', 'Ádám Szalai']
# ['A. Diawara', 'Amadou Diawara']
# ['L. Skorupski', 'Łukasz Skorupski']
# ['R. Hamouma', 'Romain Hamouma']
# ['K. Stöger', 'Kevin Stöger']
# ['K. Linetty', 'Karol Linetty']
# ['S. Bell', 'Stefan Bell']
# ["A. N'Diaye", "Alfred John Momar N'Diaye"]
# ['Y. Yazıcı', 'Yusuf Yazıcı']
# ['B. Oczipka', 'Bastian Oczipka']
# ['F. Valverde', 'Federico Valverde']
# ['M. Benítez', 'Martín Benítez']
# ['M. Vorm', 'Michel Vorm']
# ['N. Mendy', 'Nampalys Mendy']
# ['J. Vázquez', 'José Juan Vázquez Gómez']
# ['Unai Núñez', 'Unai Núñez Gestoso']
# ['N. Radoja', 'Nemanja Radoja']
# ['K. Gibbs', 'Kieran  Gibbs']
# ['A. Hamdallah', 'Abderrazak Hamdallah']
# ['Pablo Santos', 'Pablo Renan dos Santos']
# ['S. Fofana', 'Seko Fofana']
# ['Felipe', 'Felipe Dias da Silva dal Belo']
# ['C. Villanueva', 'Carlos Andrés Villanueva Roland']
# ['Mossoró', 'José Márcio da Costa']
# ['Diego Rico', 'Diego Rico Salguero']
# ['Alberto Moreno', 'Alberto Moreno Pérez']
# ['J. Clasie', 'Jordy Clasie']
# ['R. Funes Mori', 'Rogelio Gabriel Funes Mori']
# ['O. Alonso', 'Osvaldo Alonso Moreno']
# ['A. Djiku', 'Alexander Djiku']
# ['J. Hogg', 'Jonathan Hogg']
# ['D. Calvert-Lewin', 'Dominic Calvert-Lewin']
# ['M. Zeegelaar', 'Marvin Zeegelaar']
# ['G. Carrillo', 'Guido Carrillo']
# ['Jozabed', 'Jozabed Sánchez Ruiz']
# ['A. Franco', 'Alan Javier Franco']
# ['D. Brooks', 'David Brooks']
# ['J. Bruma', 'Jeffrey Bruma']
# ['L. Sepe', 'Luigi Sepe']
# ['S. Vokes', 'Sam Vokes']
# ['Javi López', 'Javier López Rodríguez']
# ['J. Amavi', 'Jordan Amavi']
# ['Idris', 'Idrissa Mandiang']
# ['A. Potuk', 'Alper Potuk']
# ['O. Norwood', 'Oliver Norwood']
# ['R. Khedira', 'Rani Khedira']
# ['D. Machís', 'Darwin Machís']
# ['R. Quaison', 'Robin Quaison']
# ['P. Dummett', 'Paul Dummett']
# ['L. Dimata', 'Landry Dimata']
# ['Allan Bardinho', 'Allan Norberto Bardini Paneira']
# ['L. Butelle', 'Ludovic Butelle']
# ['S. Cristóforo', 'Sebastián Cristóforo']
# ['Jason', 'David Jason Remeseiro Salgueiro']
# ['M. Agu', 'Mikel Agu']
# ['E. Badu', 'Emmanuel Badu']
# ['N. Redmond', 'Nathan Redmond']
# ['Sandro', 'Sandro Ranieri Guimarães Cordeiro']
# ['A. Mounier', 'Anthony Mounier']
# ['Matheus Pereira', 'Matheus Fellipe Costa Pereira']
# ['C. Jallet', 'Christophe Jallet']
# ['Diego Castro', 'Diego Castro Giménez']
# ['S. Okazaki', '岡崎 慎司']
# ['O. Kamara', 'Ola  Williams Kamara']
# ['Xeka', 'Miguel Ângelo da Silva Rocha']
# ['R. Karsdorp', 'Rick Karsdorp']
# ['Marafona', 'José Carlos Coentrão Marafona']
# ['D. Valdés', 'Diego Valdés']
# ['M. Gonalons', 'Maxime Gonalons']
# ['Burgui', 'Jorge Franco Alviz']
# ['F. Guarín', 'Fredy Alejandro Guarín Vásquez']
# ['M. Jensen', 'Mathias Jensen']
# ['R. Thomas', 'Ryan Thomas']
# ['B. Butko', 'Bogdan Butko']
# ['L. Cigarini', 'Luca Cigarini']
# ['A. Musa', 'Ahmed Musa']
# ['M. Morozyuk', 'Mykola Morozyuk']
# ['G. Schennikov', 'Georgiy Schennikov']
# ['André Ramalho', 'André Ramalho Silva']
# ['T. Foket', 'Thomas Foket']
# ['P. Foden', 'Philip Foden']
# ['Walace', 'Walace Souza Silva']
# ['I. Kahveci', 'İrfan Can Kahveci']
# ['J. Briand', 'Jimmy Briand']
# ['D. Rolán', 'Diego Rolán']
# ['C. Théréau', 'Cyril Théréau']
# ['B. Valdez', 'Bruno Valdez']
# ['M. Konaté', 'Pape Moussa Konaté']
# ['H. Ayala', 'Hugo Ayala Castro']
# ['J. Kluivert', 'Justin Kluivert']
# ['P. Tau', 'Percy Tau']
# ['Eraso', 'Javier Eraso Goñi']
# ['A. Boruc', 'Artur Boruc']
# ['S. Larsson', 'Sam Larsson']
# ['Paulinho', 'Paulo Henrique Soares dos Santos']
# ['J. Urretaviscaya', 'Jonathan Matías Urretaviscaya da Luz']
# ['Y. Aït Bennasser', 'Youssef Aït Bennasser']
# ['P. Bernardoni', 'Paul Bernardoni']
# ['J. Brenet', 'Joshua Brenet']
# ['Aleñá', 'Carles Aleñá Castillo']
# ['Thiago Maia', 'Thiago Maia Alencar']
# ['R. Skov', 'Robert Skov']
# ['M. Isla', 'Mauricio Aníbal Isla Isla']
# ['W. McKennie', 'Weston McKennie']
# ['J. Tavernier', 'James Tavernier']
# ['S. Kalu', 'Samuel Kalu Ojim']
# ['Marlon', 'Marlon da Silva Barbosa']
# ['A. Duncan', 'Joseph Alfred Duncan']
# ['S. Sturaro', 'Stefano Sturaro']
# ['H. Arter', 'Harry Arter']
# ['V. Buyalskyi', 'Vitaliy Buyalskyi']
# ['M. Sarr', 'Malang Sarr']
# ['I. Fernández', 'Ignacio Fernández']
# ['H. Hateboer', 'Hans Hateboer']
# ['F. Niederlechner', 'Florian Niederlechner']
# ['P. Schwegler', 'Pirmin Schwegler']
# ['B. Pearson', 'Ben Pearson']
# ['T. Abraham', 'Tammy Abraham']
# ['Jefferson', 'Jefferson Moreira Nascimento']
# ['J. Mæhle', 'Joakim Mæhle']
# ['Unai López', 'Unai López Cabrera']
# ['I. Amadou', 'Ibrahim Amadou']
# ['C. Günter', 'Christian Günter']
# ['O. Onazi', 'Ogenyi Eddy Onazi']
# ['J. Montero', 'Jefferson Antonio Montero Vite']
# ['O. Murillo', 'Oscar Fabián Murillo Murillo']
# ['Borja Bastón', 'Borja González Tomás']
# ['L. Zelarayán', 'Lucas Zelarayán']
# ['M. Kelly', 'Martin Kelly']
# ['A. Umar', 'Aminu Umar']
# ['Zaldúa', 'Joseba Zaldúa Bengoetxea']
# ['M. Diagne', 'Mbaye Diagne']
# ['Jovane Cabral', 'Jovane Eduardo Borges Cabral']
# ['S. Dann', 'Scott Dann']
# ['M. Pavlović', 'Mateo Pavlović']
# ['A. Surman', 'Andrew Surman']
# ['F. Kainz', 'Florian Kainz']
# ['Fran Beltrán', 'Francisco José Beltrán Peinado']
# ['K. Vermeer', 'Kenneth Vermeer']
# ['Fontàs', 'Andreu Fontàs Prat']
# ['L. Quiñones', 'Luis Enrique Quiñónes']
# ['M. Leckie', 'Mathew Leckie']
# ['Tchê Tchê', 'Danilo das Neves Pinheiro']
# ['S. March', 'Solly March']
# ['B. Dabo', 'Bryan Dabo']
# ['F. Midtsjø', 'Fredrik Midtsjø']
# ['Arribas', 'Alejandro Arribas Garrido']
# ['Duirval Diniz', 'Duirval Hélton Diniz Cabral']
# ['O. Watkins', 'Ollie Watkins']
# ['R. Tapia', 'Renato Tapia']
# ['E. Roco', 'Enzo Pablo Roco Roco']
# ['J. Svensson', 'Jonas Svensson']
# ['L. Orbán', 'Lucas Alfonso Orbán Alegre']
# ['G. Donsah', 'Godfred Donsah']
# ['L. Krejčí', 'Ladislav Krejčí']
# ['S. Sinclair', 'Scott Sinclair']
# ['B. Jokič', 'Bojan Jokič']
# ['M. Thuram', 'Marcus Thuram']
# ['S. Romero', 'Silvio Ezequiel Romero']
# ['C. Atsu', 'Christian Atsu']
# ['C. Träsch', 'Christian Träsch']
# ['F. Pogba', 'Florentin Pogba']
# ['Reguilón', 'Sergio Reguilón Rodríguez']
# ['Caio Milaçar', 'Caio Bruno Milaçar Kenedy']
# ['M. Kempf', 'Marc-Oliver Kempf']
# ['Daniel Ayala', 'Daniel Sánchez Ayala']
# ['P. Roberts', 'Patrick Roberts']
# ['G. Ortíz', 'Guillermo Ortíz']
# ['R. Gikiewicz', 'Rafał Gikiewicz']
# ['R. Rey', 'Rodrigo Rey']
# ['Y. Öztekin', 'Yasin Öztekin']
# ['Daniel Candeias', 'Daniel João Santos Candeias']
# ['C. Beauvue', 'Claudio Beauvue']
# ['Marcelo', 'Marcelo dos Santos Ferreira']
# ['S. von Bergen', 'Steve von Bergen']
# ['J. Obi', 'Joel Obi']
# ['Rafael Leão', 'Rafael da Conceição Leão']
# ['Pedro Henrique', 'Pedro K. Medina da Silva']
# ['Raúl Fernández', 'Raúl Fernández-Cavada Mateos']
# ['Y. Nagatomo', '長友 佑都']
# ['P. Hrošovský', 'Patrik Hrošovský']
# ['R. Berić', 'Robert Berić']
# ['N. Spolli', 'Nicolás Federico Spolli']
# ['L. Moore', 'Liam Moore']
# ['D. Falcinelli', 'Diego Falcinelli']
# ['J. Babin', 'Jean-Sylvain Claude Babin']
# ['J. Kopic', 'Jan Kopic']
# ['M. Besler', 'Matt Besler']
# ['P. Martinez', 'Pablo Martinez']
# ['Renan Bressan', 'Renan Bardini Bressan']
# ['O. Şahan', 'Olcay Şahan']
# ['M. Rensing', 'Michael Rensing']
# ['K. Phillips', 'Kalvin Phillips']
# ['W. Janssen', 'Willem Janssen']
# ['E. Mena', 'Eugenio Mena']
# ['A. Ciciretti', 'Amato Ciciretti']
# ['Davidson', 'Davidson da Luz Pereira']
# ['Diogo Leite', 'Diogo Filipe Monteiro Pinto Leite']
# ['A. Raggi', 'Andrea Raggi']
# ['S. Grandsir', 'Samuel Grandsir']
# ['D. Kreilach', 'Damir Kreilach']
# ['A. Ruiz', 'Alan Ruiz']
# ['Iñigo Pérez', 'Iñigo Pérez Soto']
# ['L. Sané', 'Ludovic Lamine Sané']
# ['Ivo', 'Olívio da Rosa']
# ['Gil Dias', 'Gil Bastião Dias']
# ['A. Mena', 'Ángel Mena']
# ['J. Córdoba', 'Jhon Córdoba']
# ['B. Ecuélé Manga', 'Bruno Écuélé Manga']
# ['N. Murru', 'Nicola Murru']
# ['G. Shinnie', 'Graeme Shinnie']
# ['J. Stryger Larsen', 'Jens Stryger Larsen']
# ['A. Erokhin', 'Aleksandr Erokhin']
# ['L. Robles', 'Luis Robles']
# ['A. Ulmer', 'Andreas Ulmer']
# ['F. Castillo', 'Fabián Castillo']
# ['I. Nestorovski', 'Ilija Nestorovski']
# ['M. Mount', 'Mason Mount']
# ['O. Kayode', 'Olarenwaju Ayoba Kayode']
# ['Jadson Vidigal', 'Matheus Jadson Vidigal Morais']
# ['P. Verhaegh', 'Paul Verhaegh']
# ['L. Cavallini', 'Lucas Cavallini']
# ['J. Geis', 'Johannes Geis']
# ['R. van Wolfswinkel', 'Ricky van Wolfswinkel']
# ['K. Adams Nuhu', 'Kasim Adams Nuhu']
# ['Kévin Rodrigues', 'Kévin Manuel Rodrigues']
# ['Ramalho', 'Jonás  Ramalho Chimeno']
# ['A. Semenov', 'Andrey Semenov']
# ['G. Charbonnier', 'Gaëtan Charbonnier']
# ['Luisinho', 'Luis Carlos Correia Pinto']
# ['E. Pieters', 'Erik Pieters']
# ['H. Wolf', 'Hannes Wolf']
# ['J. Aidoo', 'Joseph Aidoo']
# ['Nicolás Formido', 'Nicolás Júlio Formido Paiva']
# ['D. Kourmpelis', 'Dimitrios Kourmpelis']
# ['J. Vuković', 'Jagoš Vuković']
# ['J. Beausejour', 'Jean André Emanuel Beausejour Coliqueo']
# ['M. Ostrzolek', 'Matthias Ostrzolek']
# ['J. Błaszczykowski', 'Jakub Błaszczykowski']
# ['D. Bouanga', 'Denis Bouanga']
# ['R. Botta', 'Rubén Botta']
# ['D. Lazović', 'Darko Lazović']
# ['L. Marković', 'Lazar  Marković']
# ['Fábio Espinho', 'Fábio Ricardo Gomes Fonseca']
# ['Ruben Lima', 'Ruben Alexandre Rocha Lima']
# ['T. Usami', '宇佐美 貴史']
# ['E. Room', 'Eloy Room']
# ['K. Konaté', 'Koffi Cheikh Konaté']
# ['Rubén Alcaraz', 'Rubén Alcaraz Jiménez']
# ['A. Nyom', 'Allan Nyom']
# ['Yuri Ribeiro', 'Yuri Oliveira Ribeiro']
# ['M. Ekici', 'Mehmet Ekici']
# ['I. Sosa', 'Víctor Ismael Sosa']
# ['L. Melgarejo', 'Lorenzo António Melgarejo Sanabria']
# ['William', 'William Alves de Oliveira']
# ['M. Vydra', 'Matěj Vydra']
# ['Bebé', 'Tiago Manuel Dias Correia']
# ['Adrián González', 'Adrián  González Morales']
# ['C. Söyüncü', 'Çağlar Söyüncü']
# ['K. Iheanacho', 'Kelechi Iheanacho']
# ['M. Tisserand', 'Marcel Tisserand']
# ['A. Lozano', 'Anthony Rubén Lozano Colón']
# ['L. Waldschmidt', 'Luca Waldschmidt']
# ['Adrianiscito', 'Adriano Leandro Soares Taffarel']
# ['S. Grytebust', 'Sten Michael Grytebust']
# ['I. Strinić', 'Ivan Strinić']
# ['Pedro Rebocho', 'Pedro Miguel Braga Rebocho']
# ['J. Mbakogu', 'Jerry Mbakogu']
# ['Dória', 'Matheus Dória Macedo']
# ['M. Çağıran', 'Musa Çağıran']
# ['K. Kamara', 'Kaiansu Kei Kamara']
# ['S. Bahoken', 'Stéphane Bahoken']
# ['B. Gibson', 'Ben Gibson']
# ['Nacho', 'José Ignacio Martínez García']
# ['A. Cornelius', 'Andreas Evald Cornelius']
# ['M. Le Marchand', 'Maxime Le Marchand']
# ['P. Diop', 'Pape Cheikh Diop Gueye']
# ['S. Özbayraklı', 'Şener Özbayraklı']
# ['S. Davis', 'Steven Davis']
# ['A. Baba', 'Abdul Rahman Baba']
# ['E. Zukanović', 'Ervin Zukanović']
# ['O. Niasse', 'El-Hadji Baye Oumar Niasse']
# ['P. Mpoku', "Paul-José M'Poku Ebunge"]
# ['K. McDonald', 'Kevin McDonald']
# ['Jesus Andradaldo', 'Jesus Fabrício Andrade Simões']
# ['S. Dzhanaev', 'Soslan Dzhanaev']
# ['M. Degenek', 'Miloš Degenek']
# ['A. Tameze', 'Adrien Tameze']
# ['Tiago Silva', 'Tiago Rafael Maia Silva']
# ['E. Bauthéac', 'Éric Bauthéac']
# ['Y. Ravet', 'Yoric Ravet']
# ['D. Tošić', 'Duško Tošić']
# ['D. Padelli', 'Daniele Padelli']
# ['B. Mensah', 'Bernard Mensah']
# ['J. Biabiany', 'Jonathan Ludovic Biabiany']
# ['I. Iličević', 'Ivo Iličević']
# ['H. Barnes', 'Harvey Lewis Barnes']
# ['C. Awaziem', 'Chidozie Collins Awaziem']
# ['Luna', 'Antonio Manuel Luna Rodríguez']
# ['A. Chedjou', 'Aurélien Chedjou']
# ['Djavan', 'Djavan da Silva Ferreira']
# ['A. Rebrov', 'Artem Rebrov']
# ['G. Margreitter', 'Georg Margreitter']
# ['Salvi Sánchez', 'Salvador Sánchez Ponce']
# ['Pietrson Mendes', 'Pietro Maurício Mendes Abranches']
# ['M. Russ', 'Marco Russ']
# ['H. Van Crombrugge', 'Hendrik Van Crombrugge']
# ['A. Barrada', 'Abdelaziz Barrada']
# ['K. Nakamura', '中村 宪剛']
# ['A. Clayton', 'Adam Clayton']
# ['T. Leibold', 'Tim Leibold']
# ['V. Karavaev', 'Vyacheslav Karavaev']
# ['I. Fossum', 'Iver Fossum']
# ['D. Bessa', 'Daniel Bessa']
# ['N. Acevedo', 'Nelson Acevedo']
# ['S. Rybalka', 'Sergiy Rybalka']
# ['G. Di Lorenzo', 'Giovanni Di Lorenzo']
# ['H. Diallo', 'Habib Diallo']
# ['B. Fernández', 'Brian Fernández']
# ['J. Basanta', 'José María Basanta']
# ['S. Thioub', 'Sada Thioub']
# ['C. Adams', 'Che Adams']
# ['Jota', 'José Ignacio Peleteiro Ramallo']
# ['E. Crivelli', 'Enzo Crivelli']
# ['Etxeita', 'Xabier Etxeita Gorritxategi']
# ['D. Ciofani', 'Daniel Ciofani']
# ['M. Urruti', 'Maximiliano Urruti']
# ['Gerso', 'Gerso Fernandes']
# ['J. Šural', 'Josef Šural']
# ['B. Celina', 'Bersant Celina']
# ['S. Al Faraj', 'Salman Mohammed Al Faraj']
# ['L. Majer', 'Lovro Majer']
# ['J. St. Juste', 'Jeremiah St. Juste']
# ['M. Bolaños', 'Miler Alejandro Bolaños Reascos']
# ['R. Krishna', 'Roy Krishna']
# ['E. Goldaniga', 'Edoardo Goldaniga']
# ['Suk Hyun Jun', '석현준 玄铉俊']
# ['Míchel', 'Miguel Alfonso Herrero Javaloyas']
# ['Álex Gallar', 'Álejandro Gallar Falguero']
# ['Insua', 'Pablo Insua Blanco']
# ['Ignasi Miquel', 'Ignasi Miquel i Pons']
# ['L. Bustamante', 'Luis Gonzalo Bustamante']
# ['E. Schelotto', 'Ezequiel Schelotto']
# ['Paulinho', 'Paulo Sérgio Mota']
# ['F. Hübner', 'Florian Hübner']
# ['Castro', 'André de Castro Pereira']
# ['R. Aliendro', 'Rodrigo Aliendro']
# ['M. Kanazaki', '金崎 夢生']
# ['S. Sunzu', 'Stoppila Sunzu']
# ['Y. Sanogo', 'Yaya Sanogo']
# ['T. Minamino', '南野 拓実']
# ['S. Dioudis', 'Sokratis Dioudis']
# ['J. Al Hussien', 'Jehad Fadel Al Hussain']
# ['Raul García', 'Raúl García Carnero']
# ['S. Bertoli', 'Sebastián Hernán Bertoli']
# ['J. Gélin', 'Jérémy Gélin']
# ['J. Mišić', 'Josip Mišić']
# ['Fabiano', 'Fabiano Ribeiro de Freitas']
# ['O. Mangala', 'Orel Mangala']
# ['J. Toljan', 'Jeremy Toljan']
# ['J. Gandolfi', 'Javier Marcelo Gandolfi']
# ['J. Lewis', 'Joe Lewis']
# ['J. Bořil', 'Jan Bořil']
# ['S. Clucas', 'Sam Clucas']
# ['A. Grünwald', 'Alexander Grünwald']
# ['J. Poulsen', 'Jakob Bendix Uhd Poulsen']
# ['C. Montes', 'César Jasib Montes Castro']
# ['R. Meggiorini', 'Riccardo Meggiorini']
# ['N. Bungert', 'Niko Bungert']
# ['C. Kouamé', 'Christian Kouamé']
# ['F. Meza', 'Francisco Javier Meza Palma']
# ['A. Henríquez', 'Ángelo Henríquez']
# ['Nélson Oliveira', 'Nélson Miguel Castro Oliveira']
# ['E. Terranova', 'Emanuele Terranova']
# ['R. Emond', 'Renaud Emond']
# ['G. Hooper', 'Gary Hooper']
# ['L. Freeman', 'Luke Anthony Freeman']
# ['Miguel Vieira', 'Luís Miguel Vieira da Silva']
# ['A. Rispoli', 'Andrea Rispoli']
# ['N. Navarro', 'Nicolás Gastón Navarro']
# ['A. Barboza', 'Alexander Nahuel Barboza Ullúa']
# ['A. Maxim', 'Alexandru Iulian Maxim']
# ['O. John', 'Ola John']
# ['A. Smithies', 'Alex Smithies']
# ['P. Barrientos', 'Pablo César Barrientos']
# ['F. Rinaudo', 'Fabián Andrés Rinaudo']
# ['L. Mazzitelli', 'Luca Mazzitelli']
# ['Eduardo', 'Eduardo Antônio Machado Teixeira']
# ['G. Pazzini', 'Giampaolo Pazzini']
# ['A. Bamba', 'Abdoulaye Bamba']
# ['A. Mina', 'Arturo Mina']
# ['I. Mbaye', 'Ibrahima Mbaye']
# ['M. Tekdemir', 'Mahmut Tekdemir']
# ['L. Burián', 'Leonardo Fabián Burián Castro']
# ['Michel Cruceiro', 'Michel David Cruceiro Muscato']
# ['Ricardo', 'Ricardo Jorge Vaz Té']
# ['Y. Gordillo', 'Yeison Stiven Gordillo Vargas']
# ['G. Peruzzi', 'Gino Peruzzi']
# ['Yu Hanchao', '汉超于']
# ['K. Westwood', 'Keiren Westwood']
# ['Evandro Rochedo', 'Evandro Sérgio Rochedo Paulino']
# ['Dani Pacheco', 'Daniel Pacheco Lobato']
# ['A. Ríos', 'Antonio Ríos Martínez']
# ['D. Kadah', 'Deniz Kadah']
# ['A. Diakhaby', 'Adama Diakhaby']
# ['Juan Carlos', 'Juan Carlos Martín Corral']
# ['I. Success', 'Isaac Success']
# ['S. Al Dawsari', 'Salem Al Dawsari']
# ['A. Özbiliz', 'Aras Özbiliz']
# ['G. Banguera', 'Geovanni Banguera']
# ['K. Johnsson', 'Karl-Johan Johnsson']
# ['U. Demirok', 'Uğur Demirok']
# ['N. Asare', 'Nana Kwesi Asare']
# ['M. Pucciarelli', 'Manuel Pucciarelli']
# ['D. Fagundez', 'Diego Santiago Fagúndez Pepe']
# ['W. Troost-Ekong', 'William Troost-Ekong']
# ['Paulinho', 'Paulo José de Oliveira']
# ['J. Foyth', 'Juan Marcos Foyth']
# ['M. Linnes', 'Martin Linnes']
# ['Serginho', 'Sérgio Antônio Soler Oliveira Jr']
# ['Hélder Lopes', 'Hélder Filipe Oliveira Lopes']
# ['E. Berg', 'Erik Berg']
# ['R. Bengtsson', 'Rasmus Bengtsson']
# ['F. Forestieri', 'Fernando Martín Forestieri']
# ['K. Wilczek', 'Kamil Wilczek']
# ['G. Cimirot', 'Gojko Cimirot']
# ['I. Bennacer', 'Ismaël Bennacer']
# ['L. Marrone', 'Luca Marrone']
# ['R. Halliche', 'Rafik Halliche']
# ['V. Vada', 'Valentín Vada']
# ['Y. Bissouma', 'Yves Bissouma']
# ['R. Salinas', 'Rodrigo Salinas Dorantes']
# ['R. Doan', '堂安 律']
# ['F. Pardo', 'Édgar Felipe Pardo Castro']
# ['J. Duque', 'Jhon Duque']
# ['D. Jensen', 'David Jensen']
# ['Omar Ramos', 'Julián Omar Ramos Suárez']
# ['D. Randolph', 'Darren Randolph']
# ['S. Sensi', 'Stefano Sensi']
# ['A. Ricaurte', 'Andrés Ricaurte Vélez']
# ['M. Aguirregaray', 'Matías Aguirregaray Guruceaga']
# ['João Carvalho', 'João António Antunes Carvalho']
# ['A. Zeneli', 'Arbër Zeneli']
# ['D. Dainelli', 'Dario Dainelli']
# ['K. Hansen', 'Kian Hansen']
# ['R. Bennett', 'Ryan Bennett']
# ['Lee Chung Yong', '이청용 李青龙']
# ['V. Verre', 'Valerio Verre']
# ['Kwoun Sun Tae', '권순태 权纯泰']
# ['Mauro Cildinho', 'Mauro Pierre Cildinho Conradi']
# ['Edinho', 'Arnaldo Edi Lopes da Silva']
# ['L. Pisculichi', 'Leonardo Nicolás Pisculichi']
# ['Y. Benalouane', 'Yohan Benalouane']
# ['A. Ragusa', 'Antonino Ragusa']
# ['F. Lemoine', 'Fabien Lemoine']
# ['C. Roldan', 'Cristian Roldan']
# ['D. Ndong', 'Didier  Ndong Ibrahim']
# ['V. Coufal', 'Vladimír Coufal']
# ['M. Oršić', 'Mislav Oršić']
# ['Édundo Oliveira', 'Éder Marvin Oliveira Simão']
# ['B. Bannan', 'Barry Bannan']
# ['R. Koch', 'Robin Koch']
# ['N. Pasquini', 'Nicolás Pasquini']
# ['A. Rosina', 'Alessandro Rosina']
# ['T. Parker', 'Tim Parker']
# ['Marcos Guilherme', 'Marcos G. Santos Matos']
# ['D. Luckassen', 'Derrick Luckassen']
# ['S. Hutchinson', 'Shaun Hutchinson']
# ['Bruno Lamas', 'Bruno José Pavani Lamas']
# ['A. Bălută', 'Alexandru Bălută']
# ['De las Cuevas', 'Miguel Ángel De las Cuevas Barberá']
# ['Léo Bonatini', 'Leonardo B. Lohner Maia']
# ['D. Kolář', 'Daniel Kolář']
# ['T. Aoyama', '青山 敏弘']
# ['S. Montoya', 'Santiago Montoya']
# ['V. Aguilera', 'Victor Emanuel Aguilera']
# ['H. Yamaguchi', '山口 蛍']
# ['I. Mboyo', 'Ilombe Mboyo']
# ['Bruno Tabata', 'Bruno Vinícius Souza Ramos']
# ['B. Barišić', 'Borna Barišić']
# ['Wilson Manafá', 'Wilson Miguéis Manafá Jancó']
# ['C. Nørgaard', 'Christian Nørgaard']
# ['G. Friend', 'George Friend']
# ['D. Khocholava', 'Davit Khotcholava']
# ['B. Srarfi', 'Bassem  Srarfi']
# ['Romarinho', 'Romário Ricardo da Silva']
# ['Mateus', 'Mateus Galiano da Costa']
# ['W. Hoolahan', 'Wes Hoolahan']
# ['R. Azeez', 'Ramon Olamilekan Azeez']
# ['M. Frey', 'Michael Frey']
# ['J. Akpa Akpro', 'Jean-Daniel Akpa Akpro']
# ['Isaac Cuenca', 'Joan Isaac Cuenca López']
# ['Fábio Pacheco', 'Fábio José Ferreira Pacheco']
# ['Lucas Piazon', 'Gustavo Lucas Domingues Piazon']
# ['Timo Triano', 'Timoteo Samuel Triano Branco']
# ['A. Scholz', 'Alexander Scholz']
# ['Y. Chibsah', 'Yussif Raman Chibsah']
# ['M. Duffy', 'Mark Duffy']
# ['G. McAuley', 'Gareth McAuley']
# ['N. Al Abed', 'Nawaf Shaker Al Abid']
# ['Alessinito', 'Alessandro Nuno Vaz Laranjeiras']
# ['D. Verde', 'Daniele Verde']
# ['P. Lasogga', 'Pierre-Michel Lasogga']
# ['M. Pack', 'Marlon Pack']
# ['Z. Ferhat', 'Zinedine Ferhat']
# ['C. Marshall', 'Chad Marshall']
# ['J. Bahebeck', 'Jean-Christophe Bahebeck']
# ['R. Espinoza', 'Róger Espinoza Ramírez']
# ['N. González', 'Nicolás Iván González']
# ['Nuno Santos', 'Nuno Miguel Gomes dos Santos']
# ['K. Kusk', 'Kasper Kusk Vangsgaard']
# ['E. Lamanna', 'Eugenio Lamanna']
# ['G. Sunu', 'Gilles Sunu']
# ['E. Berggreen', 'Emil Berggreen']
# ['G. Núñez', 'Jonathan Guillermo Nuñez Espinoza']
# ['L. Aued', 'Luciano Aued']
# ['Hao Junmin', '蒿俊闵']
# ['V. Găman', 'Marius Valerică Găman']
# ['Pulido', 'Jorge Pulido Mayoral']
# ['A. Mobara', 'Abbubaker Mobara']
# ['J. Ledley', 'Joe Ledley']
# ['A. Çalık', 'Ahmet Çalık']
# ['A. Cerri', 'Alberto Cerri']
# ['Kim Jin Su', '킴진수 金珍洙']
# ['C. Gytkjær', 'Christian Gytkjær']
# ['Kangin Lee', '이강인 Kangin Lee']
# ['Edigar Junio', 'Edigar Junio Teixeira Lima']
# ['J. Bostock', 'John Bostock']
# ['S. Pellissier', 'Sergio Pellissier']
# ['M. Antonsson', 'Marcus Antonsson']
# ['M. Kean', 'Moise Kean']
# ['J. Collins', 'James  Collins']
# ['N. Mushekwi', 'Nyasha Liberty Mushekwi']
# ['L. Jiménez', 'Leiton Jiménez']
# ["D. N'Dinga", 'Delvin N’Dinga']
# ['F. Kroos', 'Felix Kroos']
# ['M. Mahi', 'Mimoun Mahi']
# ['J. van Overeem', 'Joris van Overeem']
# ['A. Esswein', 'Alexander Esswein']
# ['J. Moreira', 'Jorge Moreira']
# ['Jorge Carvallinho', 'Jorge Pietro Carvalho Porfírio']
# ['J. Pereira', 'Jair Pereira Rodríguez']
# ['N. Galović', 'Nino Galović']
# ['S. Mosquera', 'Hárold Santiago  Mosquera Caicedo']
# ['J. Nieto', 'Juan Pablo Nieto Salazar']
# ['C. Yacob', 'Claudio Ariel Yacob']
# ['L. Ajorque', 'Ludovic Ajorque']
# ['H. Barcos', 'Hernán Barcos']
# ['S. Nakamura', '中村 俊輔']
# ['M. Doumbia', 'Moussa Doumbia']
# ['G. Tutino', 'Gennaro Tutino']
# ['A. Allione', 'Agustín Allione']
# ['G. Lanaro', 'Germán Lanaro']
# ['W. Zimmerman', 'Walker Zimmerman']
# ['L. Rizzo', 'Luca Rizzo']
# ['R. Gutiérrez', 'Roberto Carlos Gutiérrez Gamboa']
# ['M. Gavranović', 'Mario Gavranović']
# ['O. Hurmacı', 'Özer Hurmacı']
# ['A. Tello', 'Andres Tello']
# ['S. Gustafson', 'Simon Gustafson']
# ['F. Ceravolo', 'Fabio Giovanni Ceravolo']
# ['F. Coloccini', 'Fabricio Coloccini']
# ['G. Curci', 'Gianluca Curci']
# ['Daniel Guimarães', 'Daniel Martins Guimarães']
# ['E. Hallfreðsson', 'Emil Hallfreðsson']
# ['M. Albornoz', 'Miiko Martín Albornoz Inola']
# ['J. Mercier', 'Juan Ignacio Mercier']
# ['M. Donald', 'Mitchell Glenn Donald']
# ['M. Cuisance', 'Mickaël Cuisance']
# ['A. Warda', 'Amr Warda']
# ['A. Traoré', 'Adama Traoré']
# ['O. McBurnie', 'Oliver McBurnie']
# ['Dankler', 'Dankler Luís de Jesus Pedreira']
# ['M. Goicoechea', 'Mauro Daniel Goicoechea Furia']
# ['L. Andersen', 'Lucas  Andersen']
# ['C. Obasi', 'Chinedu Obasi Ogbuke']
# ['T. Howard', 'Tim Howard']
# ['H. Goitom', 'Henok Goitom']
# ['S. Khaoui', 'Saîf-Eddine Khaoui']
# ['R. van La Parra', 'Rajiv van La Parra']
# ['Adrián Marín', 'Adrián Marín Gómez']
# ['L. Menossi', 'Lucas Menossi']
# ['Josué Sá', 'Josué Humberto Gonçalves Leal Sá']
# ['A. Chatzigiovanis', 'Anastasios Chatzigiovanis']
# ['Cristian Lodeira', 'Cristian Enzo Lodeira Araujo']
# ['A. Pantic', 'Aleksandar Pantić']
# ['J. Rojas', 'Jorge Luis Rojas Meza']
# ['F. Klos', 'Fabian Klos']
# ['C. Ramírez', 'Cristian Leonel Ramírez Zambrano']
# ['J. Boye', 'John Boye']
# ['M. Malyshev', 'Maksym Malyshev']
# ['Douglas', 'Douglas Pereira dos Santos']
# ['K. Boyd', 'Kris Boyd']
# ['D. Rodríguez', 'Diego Rodríguez']
# ['M. Møller Dæhli', 'Mats  Møller Dæhli']
# ['S. Polter', 'Sebastian Polter']
# ['R. van Rhijn', 'Ricardo van Rhijn']
# ['N. Maraš', 'Nikola Maraš']
# ['L. Castellanos', 'Andrés Leandro Castellanos Serrano']
# ['A. Biyogo Poko', 'André Biyogo Poko']
# ['J. Otero', 'Juan Ferney Otero Tovar']
# ['N. Boilesen', 'Nicolai Møller Boilesen']
# ['D. Lainez', 'Diego Lainez Leyva']
# ['Y. Al Shahrani', 'Yasser Al Shahrani']
# ['I. Diomandé', 'Ismaël Tiémoko Diomandé']
# ['D. Dibusz', 'Dénes Dibusz']
# ['D. Kądzior', 'Damian Kądzior']
# ['J. Bottinelli', 'Jonathan Pablo Bottinelli']
# ['G. Barry', 'Gareth Barry']
# ['R. Kruse', 'Robbie Kruse']
# ['C. Bernardi', 'Cristian Oscar Bernardi']
# ['E. Ávila', 'Ezequiel Ávila']
# ['N. Radonjić', 'Nemanja Radonjić']
# ['Jeff Meirson', 'Jeff Nazario Meire Costinho']
# ['J. Güemez', 'Javier Güemez López']
# ['J. Jones', 'Jordan Jones']
# ['D. Guzman', 'David Guzman']
# ['A. Zaldívar', 'Ángel Zaldívar Caviedes']
# ['S. Tibbling', 'Simon Tibbling']
# ['Joshuando Sá', 'Joshua Eduardo Sá Madeira']
# ['A. De Sart', 'Alexis De Sart']
# ['W. Owusu', 'William Owusu']
# ['M. Abarhoun', 'Mohamed Aberhoune']
# ['J. Puncheon', 'Jason Puncheon']
# ['M. Stiepermann', 'Marco Stiepermann']
# ['M. Demir', 'Muhammet Demir']
# ['Salva Sevilla', 'Salvador Sevilla López']
# ['B. Kololli', 'Benjamin Kololli']
# ['J. Börner', 'Julian Börner']
# ['Ricardo Ryller', 'Ricardo Ryller Ribeiro Lino Silva']
# ['B. Białkowski', 'Bartosz Białkowski']
# ['M. Mantovani', 'Martín Maximiliano Mantovani']
# ['S. Ortega', 'Stefan Ortega Moreno']
# ['S. Gürler', 'Serdar Gürler']
# ['J. Bennett', 'Joe Bennett']
# ['Rui Fonte', 'Rui Pedro da Rocha Fonte']
# ['A. Adnan', 'Ali Adnan']
# ['Luismi', 'Luis Miguel Sánchez Benítez']
# ['L. Garritano', 'Luca Garritano']
# ['A. Cubas', 'Adrián Andrés Cubas']
# ['Jubal', 'Jubal Rocha Mendes Junior']
# ['L. Phiri', 'Lebogang Phiri']
# ['T. Delaine', 'Thomas Delaine']
# ['J. Murphy', 'Jamie Murphy']
# ['Alexandre Frandeira', 'Alex Martin Frandeira Álvares']
# ['R. García Guerreño', 'Rolando García Guerreño']
# ['K. Sema', 'Ken Sema']
# ['Reyes', 'José Antonio Reyes Calderón']
# ['I. Hajrović', 'Izet Hajrović']
# ['Fernando Boldrin', 'Fernando Henrique Boldrin']
# ['D. Peralta', 'Diego Arturo Peralta González']
# ['Sebá', 'Sebastião de Freitas Couto Júnior']
# ['U. Ćosić', 'Uroš Ćosić']
# ['F. Pisacane', 'Fabio Pisacane']
# ['D. Rossi', 'Diego Rossi']
# ['R. Alvarado', 'Roberto Alvarado']
# ['J. Brownhill', 'Josh Brownhill']
# ['M. Piedrahita', 'Marlon Javier Piedrahita Londoño']
# ['M. van der Werff', 'Maikel van der Werff']
# ['D. Dwyer', 'Dom Dwyer']
# ['G. Bettini', 'Gonzalo Bettini']
# ['P. Brlek', 'Petar Brlek']
# ['Miltisco Paulino', 'M. Vanderlei Paulino Kenedy']
# ['Tobias Figueiredo', 'Tobias Pereira Figueiredo']
# ['Erik Morán', 'Erik Morán Arribas']
# ['David Batanero', 'David Batanero Puigbó']
# ['G. Holtmann', 'Gerrit Holtmann']
# ['A. Caracciolo', 'Antonio Aldo Caracciolo']
# ['A. Ajdarević', 'Astrit Ajdarević']
# ['Jung Sung Ryong', '정성룡 郑俊玄']
# ['A. Kamara', 'Aboubakar Kamara']
# ['A. Preciado', 'Ayrton Preciado']
# ['M. Valenzuela', 'Milton Nahuel Valenzuela']
# ['E. Fernandes', 'Edimilson Fernandes']
# ['L. Memushaj', 'Ledian Memushaj']
# ['E. Kawashima', '川島 永嗣']
# ['J. Filipović', 'Jakov Filipović']
# ['A. Gogia', 'Akaki Gogia']
# ['D. Schmidt', 'Dominik Schmidt']
# ['Rodrigo Becão', 'Rodrigo Nascimento França']
# ['M. Friedrich', 'Marvin Friedrich']
# ['T. Schütz', 'Tom Schütz']
# ['S. Tecl', 'Stanislav Tecl']
# ['D. Milićević', 'Danijel Milićević']
# ['O. Fink', 'Oliver Fink']
# ['A. Tarek', 'Amro Tarek Abdel Aziz']
# ['M. Jonjić', 'Matej Jonjić']
# ['B. Heynen', 'Bryan Heynen']
# ['João Pedro', 'João Pedro Maturano dos Santos']
# ['D. Rosero Valencia', 'Daniel Rosero Valencia']
# ['R. Caroca', 'Rafael Antonio Caroca Cordero']
# ['Souza', 'Elierce Barbosa de Souza']
# ['K. Bonifazi', 'Kevin Bonifazi']
# ['D. Williams', 'Daniel Williams']
# ['O. Cabezas', 'Óscar Cabezas']
# ['C. Stengs', 'Calvin Stengs']
# ['Borja Lasso', 'Borja Lasso De La Vega']
# ['R. Oudin', 'Rémi Oudin']
# ['R. Rodríguez', 'Ribair Rodríguez Pérez']
# ['J. Campos', 'Jhasmani Campos']
# ['J. Rhodes', 'Jordan Rhodes']
# ['I. Šunjić', 'Ivan Šunjić']
# ['R. Thelander', 'Rasmus Thelander']
# ['N. Moro', 'Nikola Moro']
# ['M. Lustig', 'Mikael Lustig']
# ['S. Nishikawa', '西川 周作']
# ['M. Torsiglieri', 'Marco Natanel Torsiglieri']
# ['P. Škuletić', 'Petar Škuletić']
# ['M. Caire', 'Maximiliano Caire']
# ['C. Lucchetti', 'Cristian David Lucchetti']
# ['B. Afobe', 'Benik Afobe']
# ['Carlitos', 'Carlos Alberto Alves Garcia']
# ['J. Bela', 'Jérémie Bela']
# ['M. Coronel', 'Maximiliano Ángel Coronel']
# ['Ricardo Valente', 'Ricardo Jorge Oliveira Valente']
# ['J. Perbet', 'Jérémy Perbet']
# ['A. Callens', 'Alexander Martín Marquinho Callens Asín']
# ['Adriano Facchini', 'Adriano Facchini']
# ['Carraça', 'Rui Filipe Caetano Moura']
# ['A. Rojas', 'Ariel Mauricio Rojas']
# ['D. Lenihan', 'Darragh Lenihan']
# ['B. McKay', 'Barrie McKay']
# ['N. Ghilas', 'Nabil Ghilas']
# ['Y. Kashiwa', '柏好 文']
# ['D. Damjanović', 'Dejan Damjanović']
# ['F. Sammaritano', 'Frédéric Sammaritano']
# ['V. Fiorillo', 'Vincenzo Fiorillo']
# ['R. Keogh', 'Richard Keogh']
# ['Bressan', 'Matheus Simoneti Bressaneli']
# ['E. Başsan', 'Emrah Başsan']
# ['J. Quiñones', 'Julián Andrés Quiñones Quiñones']
# ['A. Soto', 'Alexis Soto']
# ['H. Novillo', 'Harry Novillo']
# ['C. Brunt', 'Chris Brunt']
# ['D. McGoldrick', 'David McGoldrick']
# ['K. Letica', 'Karlo Letica']
# ['L. Reyes', 'Luis Ricardo Reyes Moreno']
# ['L. Zingerle', 'Leopold Zingerle']
# ['F. Müller', 'Florian Müller']
# ['R. Tesche', 'Robert Tesche']
# ['U. Emanuelson', 'Urby Emanuelson']
# ['J. Abella', 'José Javier Abella Fanjul']
# ['T. Kleindienst', 'Tim Kleindienst']
# ['M. Yumlu', 'Mustafa Yumlu']
# ['M. Matip', 'Marvin Matip']
# ['J. Sambenito', 'José Gabriel Sambenito']
# ['S. Prevljak', 'Smail Prevljak']
# ['D. von Ballmoos', 'David von Ballmoos']
# ['A. Nwakaeme', 'Anthony Nwakaeme']
# ['D. Silva', 'David Mackalister Silva Mosquera']
# ['I. Oblyakov', 'Ivan Oblyakov']
# ['M. Fraga', 'Miguel Ángel Fraga Licona']
# ['B. Başaçıkoğlu', 'Bilal Başaçıkoğlu']
# ['C. Bryson', 'Craig Bryson']
# ['D. Andrade', 'Darwin Zamir Andrade Marmolejo']
# ['E. Andersen', 'Eirik  Ulland Andersen']
# ['H. Dean', 'Harlee Dean']
# ['Edu Machado', 'Eduardo José Borges Machado']
# ['E. Aguirre', 'Erick Germain Aguirre Tafolla']
# ['N. Leiva', 'Matías Nahuel Leiva Esquivel']
# ['Tiago', 'Tiago Alves Sales']
# ['K. Musona', 'Knowledge Musona']
# ['A. Gonçalves', 'Anthony Gonçalves']
# ['Torrejón', 'Marc Torrejón Moya']
# ['C. Pinares', 'César Ignacio Pinares Tamayo']
# ['R. Pucino', 'Raffaele Pucino']
# ['P. Barrera', 'Pablo Edson Barrera Acosta']
# ['Nascimentardo', 'Jonas Welson Orsi de Meneses']
# ['Heltinho Melo', 'Heltinho Melo Chaves']
# ['B. Koita', 'Bengali-Fodé Koita']
# ['Canella', 'Roberto Canella Suárez']
# ['K. Lee', 'Kieran Lee']
# ['R. Mphahlele', 'Ramahlwe Mphahlele']
# ['K. Müller', 'Kevin Müller']
# ['J. Cuero', 'Jefferson Cuero Castro']
# ['J. Wallace', 'Jed Wallace']
# ['J. Sánchez', 'Jesús Enrique Sánchez García']
# ['S. Guirassy', 'Serhou Guirassy']
# ['L. Agbenyenu', 'Lumor Agbenyenu']
# ['J. Harrison', 'Jack Harrison']
# ['S. Schwab', 'Stefan Schwab']
# ['D. Burn', 'Dan Burn']
# ['M. Correia', 'Marcel Correia']
# ['Marlion Rolim', 'Marlion Rômulo Rolim Nascimento']
# ['S. Michel', 'Sven Michel']
# ['P. Olkowski', 'Paweł Olkowski']
# ['G. Loria', 'Giorgi Loria']
# ['Javi Castellano', 'Javier Castellano Betancor']
# ['M. Fouzair', 'Mohamed Fouzair']
# ['C. Yambéré', 'Cédric Yambéré']
# ['B. Sanneh', 'Bubacarr Sanneh']
# ['H. Reed', 'Harrison Reed']
# ['Fernando', 'Fernando Dos Santos Pedro']
# ['S. Plavšić', 'Srdjan Plavšić']
# ['J. Morrison', 'James  Morrison']
# ['D. Machado', 'Deiver Machado']
# ['P. Díaz', 'Paulo César Díaz Huincales']
# ['A. Khalili', 'Abdul Rahman Khalili']
# ['K. Kerschbaumer', 'Konstantin Kerschbaumer']
# ['S. Medojević', 'Slobodan Medojević']
# ['G. Berardi', 'Gaetano Berardi']
# ['Thiago Santana', 'Thiago Santos Santana']
# ['M. Maloča', 'Mario Maloča']
# ['Negueba', 'Guilherme Ferreira Pinto']
# ['S. Malone', 'Scott Malone']
# ['J. Cooper', 'Jake Cooper']
# ['H. Abe', '阿部 浩之']
# ['Raúl Lizoain', 'Raúl Lizoáin Cruz']
# ['K. Lafferty', 'Kyle Lafferty']
# ['Wiliam Santinho', 'Wiliam Carlos Santoso Sampaio']
# ['T. Beugelsdijk', 'Tom Beugelsdijk']
# ['F. Gulbrandsen', 'Fredrik Gulbrandsen']
# ['L. Bruins', 'Luigi Bruins']
# ['R. Oshima', '大島 僚太']
# ['Álvaro', 'Álvaro Vázquez García']
# ['M. Al Buraik', 'Mohammed Al Buraik']
# ['Raphael Rossi', 'Raphael Rossi Branco']
# ['G. Litteri', 'Gianluca Litteri']
# ['M. Rodríguez', 'Matías Nicolás Rodríguez']
# ['C. Gülselam', 'Ceyhun Gülselam']
# ['M. Le Bihan', 'Mickaël Le Bihan']
# ['R. Bajić', 'Rijad Bajić']
# ['F. Navarro', 'Fernando Navarro Morán']
# ['B. Drągowski', 'Bartłomiej Drągowski']
# ['D. Bentley', 'Daniel Bentley']
# ['Juninho', 'Vitor Gomes Pereira Júnior']
# ['Kadu', 'Ricardo Martins de Araújo']
# ['Rafa Mir', 'Rafael Mir Vicente']
# ['M. Autret', 'Mathias Autret']
# ['A. Diomande', 'Adama Valentin Diomande']
# ['B. Jeannot', 'Benjamin Jeannot']
# ['Z. Kuzmanović', 'Zdravko Kuzmanović']
# ['D. Lemos', 'Damián Oscar Lemos']
# ['D. Barbona', 'David Matías Barbona']
# ['F. Erpen', 'Facundo Adrián Erpen']
# ['S. Andersson', 'Sebastian Andersson']
# ['M. Hector', 'Michael Hector']
# ['G. Molins', 'Guillermo Federico Molins Palmeiro']
# ['L. Jutkiewicz', 'Lukas Jutkiewicz']
# ['Silvosinho', 'Thomas Nicolas Silva Rangel']
# ['K. Balanta', 'Kevin Balanta']
# ['V. Muriqi', 'Vedat Muriqi']
# ['F. Márquez', 'Fernando Márquez']
# ['H. Van Der Bruggen', 'Hannes Van Der Bruggen']
# ['L. Nielsen', 'Lasse Nielsen']
# ['A. Mac Allister', 'Alexis Mac Allister']
# ['Jonas', 'Jonas Gomes de Sousa']
# ['Defendi', 'Rodrigo Defendi']
# ['L. Quintana', 'Luis Quintana']
# ['Dorca', 'Albert Dorca Masó']
# ['E. Prib', 'Edgar Prib']
# ['Yeom Ki Hun', '염기훈 廉基勋']
# ['Bremer', 'Gleison Bremer Silva Nascimento']
# ['Rodrigo', 'Rodrigo Alves Soares']
# ['J. Attamah', 'Joseph Attamah']
# ['Álvaro Lemos', 'Álvaro Lemos Collazo']
# ['J. Meram', 'Justin Meram']
# ['Renato Neto', 'Renato Neto Cardoso Porto']
# ['Alexandre Guedes', 'Alexandre Garcia Guedes']
# ['E. García', 'Emmanuel García']
# ['A. Ateef', 'Abdullah Ateef']
# ['N. Bitton', 'Nir Bitton']
# ['S. Thern', 'Simon Thern']
# ['N. Katić', 'Nikola Katić']
# ['O. Haddadi', 'Oussama Haddadi']
# ['H. Choudhury', 'Hamza Choudhury']
# ['M. Jedinák', 'Mile Jedinák']
# ['D. Benlamri', 'Djamel Eddine Benlamri']
# ['S. Palacios', 'Sebastián Palacios']
# ['M. Al Owais', 'Mohammed Khalil Al Owais']
# ['O. Rashid', 'Osama Rashid']
# ['G. Thorne', 'George Thorne']
# ['A. Pešić', 'Aleksandar Pešić']
# ['S. Berahino', 'Saido Berahino']
# ['R. Bianco', 'Raffaele Bianco']
# ['N. Sarenren Bazee', 'Noah Joel Sarenren Bazee']
# ['J. Böðvarsson', 'Jón Daði Böðvarsson']
# ['C. De Norre', 'Casper De Norre']
# ['S. Maguire', 'Sean Maguire']
# ...
# ['Diego Carlos', 'Diego Carlos Santos Silva']
# ['M. Dúbravka', 'Martin Dúbravka']
# ['H. Winks', 'Harry Winks']
# ['F. Cervi', 'Franco Cervi']
# ['V. Rongier', 'Valentin Rongier']
# ['David Soria', 'David Soria Solís']
# ['K. Toko-Ekambi', 'Karl Brillant Toko Ekambi']
# ['Dyego Sousa', 'Dyego Wilverson Ferreira Sousa']
# ['C. Pavón', 'Cristian David Pavón']
# ['M. Campaña', 'Martín Campaña']
# ['A. Diallo', 'Abdou Diallo']
# ['Marcos Llorente', 'Marcos Llorente Moreno']
# ['B. Verbič', 'Benjamin Verbič']
# ['M. Eggestein', 'Maximilian Eggestein']
# ['T. Kehrer', 'Thilo Kehrer']
# ['G. Martínez', 'Gonzalo Nicolás Martínez']
# ['B. Pavard', 'Benjamin Pavard']
# ['L. Tousart', 'Lucas Tousart']
# ['M. Dmitrović', 'Marko Dmitrović']
# ['Soares', 'Francisco das Chagas Soares dos Santos']
# ['L. Pellegrini', 'Lorenzo Pellegrini']
# ['F. Mendy', 'Ferland Mendy']
# ['A. Lunev', 'Andrey Lunev']
# ['Maikel Catarino', 'Maikel Renan Catarino Fagundes']
# ['Antônio Chiamuloira', 'A. Benjamin Chiamuloira Paes']
# ['Melvin Parrela', 'Melvin Luan Parrela Porfírio']
# ['Gabri Prestão', 'Bernard Gabriel Prestão Chaves']
# ['Luimo Boas Santos', 'Luan Vágner Boas Macedo']
# ['F. Kessié', 'Franck Yannick Kessié']
# ['T. Alexander-Arnold', 'Trent Alexander-Arnold']
# ['L. Martínez', 'Lautaro Martínez']
# ['J. Sancho', 'Jadon Sancho']
# ['Raphinha', 'Raphael Dias Belloli']
# ['Lucas Paquetá', 'Lucas Tolentino Coelho de Lima']
# ['F. Chiesa', 'Federico Chiesa']
# ['Rúben Dias', 'Rúben Alves Dias']
# ['Éder Militão', 'Éder Gabriel Militão']
# ['V. Tsygankov', 'Viktor Tsygankov']
# ['Loren', 'Lorenzo Morón García']
# ['S. Radu', 'Ştefan Daniel Radu']
# ['M. Škrtel', 'Martin Škrtel']
# ['Raúl García', 'Raúl García Escudero']
# ['D. Valeri', 'Diego Hernán Váleri']
# ['D. Criscito', 'Domenico Criscito']
# ['A. Candreva', 'Antonio Candreva']
# ['S. Romero', 'Sergio Germán Romero']
# ['Marcano', 'Iván Marcano Sierra']
# ['Pedro León', 'Pedro León Sánchez Gil']
# ['V. Birsa', 'Valter Birsa']
# ['I. Piatti', 'Ignacio Piatti']
# ['K. Gameiro', 'Kévin Gameiro']
# ['A. Fernández', 'Augusto Matías Fernández']
# ['M. Valbuena', 'Mathieu Valbuena']
# ['Beñat', 'Beñat Etxebarria Urkiaga']
# ['Nacho Monreal', 'Ignacio Monreal Eraso']
# ['Antunes', 'Vitorino Gabriel  Pacheco Antunes']
# ['Alexandre Pato', 'Alexandre Rodrigues da Silva']
# ['Sidnei', 'Sidnei Rechel da Silva Júnior']
# ['A. Modeste', 'Anthony Modeste']
# ['A. Rami', 'Adil Rami']
# ['D. Perotti', 'Diego Perotti']
# ['O. Toprak', 'Ömer Toprak']
# ['M. Musacchio', 'Mateo Pablo Musacchio']
# ['S. Ulreich', 'Sven Ulreich']
# ["Y. M'Vila", "Yann Gérard M'Vila"]
# ['Camacho', 'Ignacio Camacho Barnola']
# ['N. Nkoulou', "Nicolas N'Koulou"]
# ['M. Lanzini', 'Manuel Lanzini']
# ['S. Kagawa', '香川 真司']
# ['Guaita', 'Vicente Guaita Panadero']
# ['L. de Jong', 'Luuk de Jong']
# ['C. Smalling', 'Chris Smalling']
# ['Iago Falqué', 'Iago Falqué Silva']
# ['J. Zoet', 'Jeroen Zoet']
# ['D. Blind', 'Daley Blind']
# ['Maicon', 'Maicon Pereira Roque']
# ['R. Pereyra', 'Roberto Pereyra']
# ['R. Rodríguez', 'Ricardo Rodríguez']
# ['G. Pezzella', 'Germán Alejandro Pezzella']
# ['D. Didavi', 'Daniel Didavi']
# ['André Almeida', 'André Gomes Magalhaes de Almeida']
# ['A. Yarmolenko', 'Andriy Yarmolenko']
# ['Sergi Enrich', 'Sergio Enrich Ametller']
# ['P. Kadeřábek', 'Pavel Kadeřábek']
# ['Héctor Bellerín', 'Héctor Bellerín Moruno']
# ['T. Vaclík', 'Tomáš Vaclík']
# ['E. Zahavi', 'Eran Zahavi']
# ['Iñigo Martínez', 'Íñigo Martínez Berridi']
# ['M. Batshuayi', 'Michy Batshuayi Tunga']
# ['Portu', 'Cristian Portugués Manzanera']
# ['T. Inui', '乾 貴士']
# ['Bernard', 'Bernard  Anício Caldeira Duarte']
# ['B. Davies', 'Ben Davies']
# ['L. Shaw', 'Luke Shaw']
# ['T. Stepanenko', 'Taras Stepanenko']
# ['Manu Trigueros', 'Manuel Trigueros Muñoz']
# ['L. Paredes', 'Leandro Paredes']
# ['C. Bacca', 'Carlos Arturo Bacca Ahumada']
# ['Y. Poulsen', 'Yussuf Yurary Poulsen']
# ['H. Çalhanoğlu', 'Hakan Çalhanoğlu']
# ['E. Can', 'Emre Can']
# ['N. Aké', 'Nathan Aké']
# ['Fred', 'Frederico R. de Paula Santos']
# ['Pacheco', 'Fernando Pacheco Flores']
# ['J. Quintero', 'Juan Fernando Quintero']
# ['E. Hysaj', 'Elseid Hysaj']
# ['M. Sanson', 'Morgan Sanson']
# ['N. Tagliafico', 'Nicolás Alejandro Tagliafico']
# ['André Gomes', 'André Filipe Tavares Gomes']
# ['Gayà', 'José Luís Gayà Peña']
# ['Santi Mina', 'Santiago Mina Lorenzo']
# ['Rony Lopes', 'Marcos Paulo Mesquita Lopes']
# ['A. Christensen', 'Andreas Christensen']
# ['F. Armani', 'Franco Armani']
# ['G. Rulli', 'Gerónimo Rulli']
# ['K. Baldé', 'Keita Baldé']
# ['Williams', 'Iñaki Williams Arthuer']
# ['J. Seri', 'Jean Michaël Seri']
# ['Rafa', 'Rafael Alexandre Fernandes Ferreira da Silva']
# ['M. Dahoud', 'Mahmoud Dahoud']
# ['M. Vecino', 'Matias Vecino']
# ['A. Rebić', 'Ante Rebić']
# ['M. Caldara', 'Mattia Caldara']
# ['Raúl', 'Raúl Michel Melo da Silva']
# ['Mariano', 'Mariano Díaz Mejía']
# ['J. Weigl', 'Julian Weigl']
# ['M. Acuña', 'Marcos Javier Acuña']
# ['David Villa', 'David Villa Sánchez']
# ['J. Milner', 'James Philip Milner']
# ['Nani', 'Luís Carlos Almeida da Cunha']
# ['Jesús Navas', 'Jesús Navas González']
# ['Santi Cazorla', 'Santiago Cazorla González']
# ['B. Gomis', 'Bafétimbi Gomis']
# ['L. Fabiański', 'Łukasz Fabiański']
# ['Renato Augusto', 'Renato  Soares de Oliveira Augusto']
# ['C. Vela', 'Carlos Alberto Vela Garrido']
# ['D. Rose', 'Danny Rose']
# ['E. Lamela', 'Erik Lamela']
# ['L. Piszczek', 'Łukasz Piszczek']
# ['K. Boateng', 'Kevin-Prince Boateng']
# ['S. Bender', 'Sven Bender']
# ['S. Kjær', 'Simon Thorup Kjær']
# ['B. Höwedes', 'Benedikt Höwedes']
# ['F. Muslera', 'Fernando Muslera']
# ['L. Fejsa', 'Ljubomir Fejsa']
# ['C. Stuani', 'Cristhian Ricardo Stuani Curbelo']
# ['L. Stindl', 'Lars Stindl']
# ['F. Smolov', 'Fyodor Smolov']
# ['S. Nzonzi', "Steven N'Kemboanza Mike Christopher Nzonzi"]
# ['K. Trapp', 'Kevin Trapp']
# ['Hulk', 'Givanildo Vieira de Souza']
# ['Muniain', 'Iker Muniain Goñi']
# ['S. El Shaarawy', 'Stephan El Shaarawy']
# ['E. Salvio', 'Eduardo Antonio Salvio']
# ['J. Pastore', 'Javier Matías Pastore']
# ['Ander Herrera', 'Ander Herrera Agüera']
# ['M. Götze', 'Mario Götze']
# ['K. Vogt', 'Kevin Vogt']
# ['A. Areola', 'Alphonse Areola']
# ['J. Corona', 'Jesús Corona']
# ['D. Lovren', 'Dejan Lovren']
# ['S. Verdi', 'Simone Verdi']
# ['D. Tadić', 'Dušan Tadić']
# ['C. Aránguiz', 'Charles Mariano Aránguiz Sandoval']
# ['G. Xhaka', 'Granit Xhaka']
# ['Vitolo', 'Víctor Machín Pérez']
# ['L. Digne', 'Lucas Digne']
# ['N. Schulz', 'Nico Schulz']
# ['K. Volland', 'Kevin Volland']
# ['J. Iličić', 'Josip Iličić']
# ['F. Ghoulam', 'Faouzi Ghoulam']
# ['João Mário', 'João Mário Naval Costa Eduardo']
# ['A. Correa', 'Ángel Correa']
# ['Dani García', 'Daniel García Carrillo']
# ['M. Brozović', 'Marcelo Brozović']
# ['Morales', 'José Luis Morales Nogales']
# ['T. Bakayoko', 'Tiémoué Bakayoko']
# ['V. Lindelöf', 'Victor Nilsson Lindelöf']
# ['Dani Ceballos', 'Daniel Ceballos Fernández']
# ['Rúben Neves', 'Rúben Diogo da Silva Neves']
# ['E. Bailly', 'Eric Bailly']
# ['Pablo Fornals', 'Pablo Fornals Malla']
# ['Gelson Martins', 'Gelson Dany Batalha Martins']
# ['W. Ndidi', 'Onyinye Wilfred Ndidi']
# ['M. Marega', 'Moussa Marega']
# ['Nélson Semedo', 'Nélson Cabral Semedo']
# ['M. Akanji', 'Manuel Obafemi Akanji']
# ['L. Bailey', 'Leon Bailey Butler']
# ['Laure Santeiro', 'Laureano Thomas Santeiro Marre']
# ['M. Almirón', 'Miguel Almirón']
# ['L. Jović', 'Luka Jović']
# ['K. Havertz', 'Kai Havertz']
# ['Pepe Reina', 'José Manuel  Reina Páez']
# ['P. Čech', 'Petr Čech']
# ['Aduriz', 'Aritz Aduriz Zubeldia']
# ['Dani Alves', 'Daniel Alves da Silva']
# ['H. Herrera', 'Héctor Miguel Herrera López']
# ['L. Biglia', 'Lucas Rodrigo Biglia']
# ['F. Quagliarella', 'Fabio Quagliarella']
# ['M. Dembélé', 'Moussa Sidi Yaya Dembélé']
# ['João Moutinho', 'João Filipe Iria Santos Moutinho']
# ['Cesc Fàbregas', 'Francesc Fàbregas i Soler']
# ['A. Consigli', 'Andrea Consigli']
# ['S. Mandanda', 'Steve Mandanda']
# ['L. Koscielny', 'Laurent Koscielny']
# ['E. Viviano', 'Emiliano Viviano']
# ['Jardel', 'Jardel Nivaldo Vieira']
# ['E. Garay', 'Ezequiel Marcelo Garay']
# ['A. Guardado', 'José Andrés Guardado Hernández']
# ['Adán', 'Antonio Adán Garrido']
# ['Juan Mata', 'Juan Manuel Mata García']
# ['O. Giroud', 'Olivier Giroud']
# ['R. Fährmann', 'Ralf Fährmann']
# ['F. Fazio', 'Federico Julián Fazio']
# ['V. Ćorluka', 'Vedran Ćorluka']
# ['Pedro', 'Pedro Eliezer Rodríguez Ledesma']
# ['K. Strootman', 'Kevin Strootman']
# ['K. Glik', 'Kamil Glik']
# ['S. Mustafi', 'Shkodran Mustafi']
# ['D. Subašić', 'Danijel Subašić']
# ['H. Mkhitaryan', 'Henrikh Mkhitaryan']
# ['T. Delaney', 'Thomas Delaney']
# ['X. Shaqiri', 'Xherdan Shaqiri']
# ['Mário Fernandes', 'Mário Figueira Fernandes']
# ['Willian José', 'Willian José da Silva']
# ['S. Coates', 'Sebastián Coates Nión']
# ['Bartra', 'Marc Bartra Aregall']
# ['Jonathan Viera', 'Jonathan Viera Ramos']
# ['Luis Alberto', 'Luis Alberto Romero Alconchel']
# ['W. Zaha', 'Wilfried Zaha']
# ['C. Bakambu', 'Cédric Bakambu']
# ['W. Ben Yedder', 'Wissam Ben Yedder']
# ['J. Cillessen', 'Jasper Cillessen']
# ['Paco Alcácer', 'Francisco Alcácer García']
# ['B. Lecomte', 'Benjamin Lecomte']
# ['Morata', 'Álvaro Borja Morata Martín']
# ['Gabriel Paulista', 'Gabriel Armando de Abreu']
# ['Rafinha', 'Rafael Alcântara do Nascimento']
# ['S. Sané', 'Salif Sané']
# ['T. Meunier', 'Thomas Meunier']
# ['K. Bellarabi', 'Karim Bellarabi']
# ['H. Maguire', 'Harry Maguire']
# ['A. Florenzi', 'Alessandro  Florenzi']
# ['A. Milik', 'Arkadiusz Milik']
# ['A. Rüdiger', 'Antonio Rüdiger']
# ['S. Haller', 'Sébastien Haller']
# ['F. Vázquez', 'Franco Vázquez']
# ['J. Lingard', 'Jesse Lingard']
# ['J. Martínez', 'Josef Alexander Martínez']
# ['E. Forsberg', 'Emil Forsberg']
# ['A. Belotti', 'Andrea Belotti']
# ['J. Vardy', 'Jamie Vardy']
# ['T. Partey', 'Thomas Partey']
# ['Grimaldo', 'Alejandro Grimaldo García']
# ['P. Zieliński', 'Piotr Zieliński']
# ['D. Rugani', 'Daniele Rugani']
# ['K. Demirbay', 'Kerem Demirbay']
# ['T. Strakosha', 'Thomas Strakosha']
# ['F. Bernardeschi', 'Federico Bernardeschi']
# ['J. Pavlenka', 'Jiří Pavlenka']
# ['Casillas', 'Iker Casillas Fernández']
# ['D. De Rossi', 'Daniele De Rossi']
# ['R. Jarstein', 'Rune  Almenning Jarstein']
# ['A. Barzagli', 'Andrea Barzagli']
# ['F. Ribéry', 'Franck Bilal Ribéry']
# ['K. Schmeichel', 'Kasper Schmeichel']
# ['S. Sirigu', 'Salvatore Sirigu']
# ['Sokratis', 'Sokratis Papastathopoulos']
# ['Lucas Leiva', 'Lucas  Pezzini Leiva']
# ['Jonas', 'Jonas Gonçalves Oliveira']
# ['D. Payet', 'Dimitri  Payet']
# ['L. Bender', 'Lars Bender']
# ['Javi Martínez', 'Javier Martínez Aginaga']
# ['Rui Patrício', 'Rui Pedro dos Santos Patrício']
# ['Sergio Asenjo', 'Sergio  Asenjo Andrés']
# ['David Luiz', 'David Luiz Moreira Marinho']
# ['G. Wijnaldum', 'Georginio Wijnaldum']
# ['A. Kolarov', 'Aleksandar Kolarov']
# ['Oscar', 'Oscar dos Santos Emboaba Júnior']
# ['B. Dost', 'Bas Dost']
# ['Canales', 'Sergio Canales Madrazo']
# ['B. Leno', 'Bernd Leno']
# ['Marcos Alonso', 'Marcos Alonso Mendoza']
# ['K. Casteels', 'Koen Casteels']
# ['I. Gueye', 'Idrissa Gana Gueye']
# ['O. Baumann', 'Oliver Baumann']
# ['Neto', 'Norberto Murara Neto']
# ['K. Kampl', 'Kevin Kampl']
# ['Pizzi', 'Luís Miguel Afonso Fernandes']
# ['Rodrigo', 'Rodrigo Moreno Machado']
# ['Pablo Sarabia', 'Pablo Sarabia García']
# ['Sergi Roberto', 'Sergio Roberto Carnicer']
# ['F. Acerbi', 'Francesco Acerbi']
# ['T. Horn', 'Timo Horn']
# ['Nacho Fernández', 'José Ignacio Fernández Iglesias']
# ['Danilo Pereira', 'Danilo Luís Hélio Pereira']
# ['Lucas Moura', 'Lucas Rodrigues M. Silva']
# ['J. Draxler', 'Julian Draxler']
# ['Suso', 'Jesús Joaquín Fernández Sáez']
# ['T. Hazard', 'Thorgan Hazard']
# ['J. Stones', 'John Stones']
# ['S. Savić', 'Stefan Savić']
# ['J. Pickford', 'Jordan Pickford']
# ['A. Robertson', 'Andrew Robertson']
# ['A. Kramarić', 'Andrej Kramarić']
# ['C. Tolisso', 'Corentin Tolisso']
# ['L. Hernández', 'Lucas Hernández']
# ['N. Keïta', 'Naby Keïta']
# ['P. Kimpembe', 'Presnel Kimpembe']
# ['Louri Beretta', 'Lourival Adnan Beretta Barbosa']
# ['Josué Chiamulera', 'Josué Durval Chiamulera Vaz']
# ['Ronaldo Cabrais', 'Ronaldo Jailson Cabrais Petri']
# ['Gabriel Jesus', 'Gabriel Fernando de Jesus']
# ['G. Donnarumma', 'Gianluigi Donnarumma']
# ['M. Rashford', 'Marcus Rashford']
# ['M. de Ligt', 'Matthijs de Ligt']
# ['A. Robben', 'Arjen Robben']
# ['Quaresma', 'Ricardo Andrade Quaresma Bernardo']
# ['A. Gómez', 'Alejandro Darío Gómez']
# ['Raúl Albiol', 'Raúl Albiol Tortajada']
# ['Falcao', 'Radamel Falcao García Zárate']
# ['S. Ruffier', 'Stéphane Ruffier']
# ['Miranda', 'João Miranda de Souza Filho']
# ['Naldo', 'Ronaldo  Aparecido Rodrigues']
# ['Y. Sommer', 'Yann Sommer']
# ['E. Banega', 'Éver Maximiliano David Banega']
# ['Diego Costa', 'Diego da Silva Costa']
# ['S. Khedira', 'Sami Khedira']
# ['Willian', 'Willian Borges da Silva']
# ['A. Sánchez', 'Alexis Alejandro Sánchez Sánchez']
# ['José Callejón', 'José María Callejón Bueno']
# ['I. Gündoğan', 'İlkay Gündoğan']
# ['K. Walker', 'Kyle Walker']
# ['R. Bürki', 'Roman Bürki']
# ['Illarramendi', 'Asier Illarramendi Andonegi']
# ['L. Hrádecký', 'Lukáš Hrádecký']
# ['N. Matić', 'Nemanja Matić']
# ['N. Otamendi', 'Nicolás Hernán Otamendi']
# ['Iago Aspas', 'Iago Aspas Juncal']
# ['J. Cuadrado', 'Juan Cuadrado']
# ['D. Alaba', 'David Olatukunbo Alaba']
# ['M. Perin', 'Mattia Perin']
# ['S. de Vrij', 'Stefan de Vrij']
# ['Allan', 'Allan Marques Loureiro']
# ['Felipe Anderson', 'Felipe  Anderson Pereira Gomes']
# ['M. Depay', 'Memphis Depay']
# ['F. Thauvin', 'Florian Thauvin']
# ['Pepe', 'Képler Laveran Lima Ferreira']
# ['V. Kompany', 'Vincent Kompany']
# ['Filipe Luís', 'Filipe Luís Kasmirski']
# ['B. Matuidi', 'Blaise Matuidi']
# ['M. Özil', 'Mesut Özil']
# ['A. Witsel', 'Axel  Witsel']
# ['R. Nainggolan', 'Radja Nainggolan']
# ['E. Džeko', 'Edin Džeko']
# ['I. Perišić', 'Ivan Perišić']
# ['M. Mandžukić', 'Mario Mandžukić']
# ['A. Vidal', 'Arturo Vidal']
# ['A. Di María', 'Ángel Fabián Di María Hernández']
# ['J. Boateng', 'Jérôme Boateng']
# ['Y. Brahimi', 'Yacine Brahimi']
# ['Paulinho', 'José Paulo Bezzera Maciel Júnior']
# ['Parejo', 'Daniel Parejo Muñoz']
# ['Douglas Costa', 'Douglas Costa de Souza']
# ['K. Manolas', 'Kostas Manolas']
# ['A. Lacazette', 'Alexandre Lacazette']
# ['Koke', 'Jorge Resurrección Merodio']
# ['A. Lopes', 'Anthony Lopes']
# ['H. Son', '손흥민 孙兴慜']
# ['R. Mahrez', 'Riyad Mahrez']
# ['Carvajal', 'Daniel Carvajal Ramos']
# ['Marquinhos', 'Marcos  Aoás Corrêa']
# ['Saúl', 'Saúl Ñíguez Esclápez']
# ['D. Alli', 'Bamidele Alli']
# ['A. Laporte', 'Aymeric  Laporte']
# ['S. Milinković-Savić', 'Sergej Milinković-Savić']
# ['K. Benzema', 'Karim Benzema']
# ['M. Pjanić', 'Miralem Pjanić']
# ['L. Bonucci', 'Leonardo Bonucci']
# ['Azpilicueta', 'César Azpilicueta Tanco']
# ['W. Szczęsny', 'Wojciech  Szczęsny']
# ['T. Müller', 'Thomas Müller']
# ['Alex Sandro', 'Alex Sandro Lobo Silva']
# ['R. Lukaku', 'Romelu Lukaku']
# ['M. Verratti', 'Marco Verratti']
# ['R. Varane', 'Raphaël Varane']
# ['Roberto Firmino', 'Roberto Firmino Barbosa de Oliveira']
# ['S. Mané', 'Sadio Mané']
# ['Ederson', 'Ederson Santana de Moraes']
# ['J. Kimmich', 'Joshua Kimmich']
# ['Bernardo Silva', 'Bernardo Mota Veiga de Carvalho e Silva']
# ['L. Sané', 'Leroy Sané']
# ['R. Sterling', 'Raheem Sterling']
# ['S. Umtiti', 'Samuel Umtiti']
# ['Alisson', 'Alisson Ramses Becker']
# ['G. Buffon', 'Gianluigi Buffon']
# ['Piqué', 'Gerard Piqué Bernabéu']
# ['S. Handanovič', 'Samir Handanovič']
# ['Thiago Silva', 'Thiago Emiliano da Silva']
# ['H. Lloris', 'Hugo Lloris']
# ['G. Bale', 'Gareth Frank Bale']
# ['M. Hummels', 'Mats  Hummels']
# ['M. Reus', 'Marco Reus']
# ['P. Aubameyang', 'Pierre-Emerick Aubameyang']
# ['Coutinho', 'Philippe Coutinho Correia']
# ['N. Kanté', "N'Golo Kanté"]
# ['G. Chiellini', 'Giorgio Chiellini']
# ['Sergio Ramos', 'Sergio Ramos García']
# ['David Silva', 'David Josué Jiménez Silva']
# ['D. Godín', 'Diego Godín']
# ['T. Kroos', 'Toni Kroos']
# ['R. Lewandowski', 'Robert Lewandowski']
# ['J. Oblak', 'Jan Oblak']
# ['H. Kane', 'Harry Kane']
# ['L. Suárez', 'Luis Alberto Suárez Díaz']
# ['L. Modrić', 'Luka Modrić']
# ['E. Hazard', 'Eden Hazard']
# ['K. De Bruyne', 'Kevin De Bruyne']
# ['De Gea', 'David De Gea Quintana']
# ['Neymar Jr', 'Neymar da Silva Santos Junior']
# ['Cristiano Ronaldo', 'Cristiano Ronaldo dos Santos Aveiro']
# ['J. Serra', 'Janni-Luca Serra']
# ['A. Rodriguez', 'Angel Rodriguez']
# ['A. Calisir', 'André Calisir']
# ['R. Torres', 'Róger Mauricio Torres Hoya']
# ['R. McKenzie', 'Rory  McKenzie']
# ['M. Sipľak', 'Michal Sipľak']
# ['J. Bekkema', 'Jan Bekkema']
# ['A. Al Yami', 'Abdulrahman Al Yami']
# ['Júnior Brumado', 'José Francisco dos Santos Júnior']

# %%
# Rules:
# 1) If it starts with an initial + ".", the surname follows
#
# Single word 
#  If single word is in "full name" first location, it's a first name
#     elif in 2nd+ location, it's a surname
#    else, is a nickname
# Careful!: ['H. Son', '손흥민 孙兴慜']

# %%
# Verify rules
for tp in lines:
    numname = len(tp.split(',')[0].split(' '))
    if numname<2:
        print(tp.split(',')[0:2])
# Out:
# ['name', 'full_name']
# ['Fernandinho', 'Fernando Luiz Rosa']
# ['Marcelo', 'Marcelo Vieira da Silva Júnior']
# ['Thiago', 'Thiago Alcântara do Nascimento']
# ['Isco', 'Francisco Román Alarcón Suárez']
# ['Casemiro', 'Carlos Henrique Venancio Casimiro']
# ['Kepa', 'Kepa Arrizabalaga']
# ['Fabinho', 'Fábio Henrique Tavares']
# ['Iniesta', 'Andrés Iniesta Luján']
# ['Jorginho', 'Luiz Frello Filho Jorge']
# ['Felipe', 'Felipe Augusto de Almeida Monteiro']
# ['Malcom', 'Malcom Filipe Silva de Oliveira']
# ['Fabián', 'Fabián Ruiz Peña']
# ['Arthur', 'Arthur Henrique Ramos Oliveira Melo']
# ['Rodri', 'Rodrigo Hernández Cascante']
# ['Giuliano', 'Giuliano Victor de Paula']
# ['Marlos', 'Marlos Romero Bonfim']
# ['Taison', 'Taison Barcellos Freda']
# ['Oyarzabal', 'Mikel Oyarzabal Ugarte']
# ['Richarlison', 'Richarlison de Andrade']
# ['Odriozola', 'Álvaro Odriozola Arzalluz']
# ['Joaquín', 'Joaquín Sánchez Rodríguez']
# ['Ismaily', 'Ismaily Gonçalves dos S.']
# ['Moyá', 'Miguel Ángel Moyá Rumbo']
# ['Raffael', 'Raffael Caetano de Araújo']
# ['Juanfran', 'Juan Francisco Torres Belén']
# ['Dante', 'Dante Bonfim da Costa Santos']
# ['Otávio', 'Otávio Edmilson da Silva Monteiro']
# ['Jonny', 'Jonathan Castro Otto']
# ['Elkeson', 'Elkeson de Oliveira Cardoso']
# ['Escudero', 'Sergio Escudero Palomo']
# ['Herrerín', 'Iago Herrerín Buisán']
# ['Charles', 'Charles Dias De Oliveira']
# ['Capa', 'Ander Capa Rodríguez']
# ['Fernando', 'Fernando Lucas Martins']
# ['Álvaro', 'Álvaro González Soberón']
# ['Jurado', 'José Manuel Jurado Marín']
# ['Hilton', 'Vitorino Hilton da Silva']
# ['Granero', 'Esteban Félix Granero Molina']
# ['Adriano', 'Adriano Correia Claro']
# ['Fabricio', 'Fabricio Martín Agosto Ramírez']
# ['Wallace', 'Wallace Fortuna dos Santos']
# ['Djaniny', 'Jorge Djaniny  Tavares Semedo']
# ['Roberto', 'Roberto Jiménez Gago']
# ['Cédric', 'Cédric Ricardo Alves Soares']
# ['Paulinho', 'João Paulo Dias Fernandes']
# ['Barragán', 'Antonio Barragán Fernández']
# ['Juanpe', 'Juan Pedro Ramírez López']
# ['Balenziaga', 'Mikel Balenziaga Oruesagasti']
# ['Caiuby', 'Caiuby Francisco da Silva']
# ['Emerson', 'Emerson Palmieri dos Santos']
# ['Rômulo', 'Rômulo  Souza Orestes Caldeira']
# ['Kenedy', 'Robert Kenedy Nunes do Nascimento']
# ['Guilherme', 'Guilherme dos Santos Torres']
# ['Llorente', 'Fernando Javier Llorente Torres']
# ['Córdoba', 'Iñigo Córdoba Kerejeta']
# ['Recio', 'José Luis García del Pozo']
# ['Fernandinho', 'Da Conceição Fernando Henrique']
# ['Felipe', 'Felipe Dias da Silva dal Belo']
# ['Mossoró', 'José Márcio da Costa']
# ['Jozabed', 'Jozabed Sánchez Ruiz']
# ['Idris', 'Idrissa Mandiang']
# ['Jason', 'David Jason Remeseiro Salgueiro']
# ['Sandro', 'Sandro Ranieri Guimarães Cordeiro']
# ['Xeka', 'Miguel Ângelo da Silva Rocha']
# ['Marafona', 'José Carlos Coentrão Marafona']
# ['Burgui', 'Jorge Franco Alviz']
# ['Walace', 'Walace Souza Silva']
# ['Eraso', 'Javier Eraso Goñi']
# ['Paulinho', 'Paulo Henrique Soares dos Santos']
# ['Aleñá', 'Carles Aleñá Castillo']
# ['Marlon', 'Marlon da Silva Barbosa']
# ['Jefferson', 'Jefferson Moreira Nascimento']
# ['Zaldúa', 'Joseba Zaldúa Bengoetxea']
# ['Fontàs', 'Andreu Fontàs Prat']
# ['Arribas', 'Alejandro Arribas Garrido']
# ['Reguilón', 'Sergio Reguilón Rodríguez']
# ['Marcelo', 'Marcelo dos Santos Ferreira']
# ['Davidson', 'Davidson da Luz Pereira']
# ['Ivo', 'Olívio da Rosa']
# ['Ramalho', 'Jonás  Ramalho Chimeno']
# ['Luisinho', 'Luis Carlos Correia Pinto']
# ['William', 'William Alves de Oliveira']
# ['Bebé', 'Tiago Manuel Dias Correia']
# ['Adrianiscito', 'Adriano Leandro Soares Taffarel']
# ['Dória', 'Matheus Dória Macedo']
# ['Nacho', 'José Ignacio Martínez García']
# ['Luna', 'Antonio Manuel Luna Rodríguez']
# ['Djavan', 'Djavan da Silva Ferreira']
# ['Jota', 'José Ignacio Peleteiro Ramallo']
# ['Etxeita', 'Xabier Etxeita Gorritxategi']
# ['Gerso', 'Gerso Fernandes']
# ['Míchel', 'Miguel Alfonso Herrero Javaloyas']
# ['Insua', 'Pablo Insua Blanco']
# ['Paulinho', 'Paulo Sérgio Mota']
# ['Castro', 'André de Castro Pereira']
# ['Fabiano', 'Fabiano Ribeiro de Freitas']
# ['Eduardo', 'Eduardo Antônio Machado Teixeira']
# ['Ricardo', 'Ricardo Jorge Vaz Té']
# ['Paulinho', 'Paulo José de Oliveira']
# ['Serginho', 'Sérgio Antônio Soler Oliveira Jr']
# ['Edinho', 'Arnaldo Edi Lopes da Silva']
# ['Romarinho', 'Romário Ricardo da Silva']
# ['Mateus', 'Mateus Galiano da Costa']
# ['Alessinito', 'Alessandro Nuno Vaz Laranjeiras']
# ['Pulido', 'Jorge Pulido Mayoral']
# ['Dankler', 'Dankler Luís de Jesus Pedreira']
# ['Douglas', 'Douglas Pereira dos Santos']
# ['Luismi', 'Luis Miguel Sánchez Benítez']
# ['Jubal', 'Jubal Rocha Mendes Junior']
# ['Reyes', 'José Antonio Reyes Calderón']
# ['Sebá', 'Sebastião de Freitas Couto Júnior']
# ['Souza', 'Elierce Barbosa de Souza']
# ['Carlitos', 'Carlos Alberto Alves Garcia']
# ['Carraça', 'Rui Filipe Caetano Moura']
# ['Bressan', 'Matheus Simoneti Bressaneli']
# ['Tiago', 'Tiago Alves Sales']
# ['Torrejón', 'Marc Torrejón Moya']
# ['Nascimentardo', 'Jonas Welson Orsi de Meneses']
# ['Canella', 'Roberto Canella Suárez']
# ['Fernando', 'Fernando Dos Santos Pedro']
# ['Negueba', 'Guilherme Ferreira Pinto']
# ['Álvaro', 'Álvaro Vázquez García']
# ['Juninho', 'Vitor Gomes Pereira Júnior']
# ['Kadu', 'Ricardo Martins de Araújo']
# ['Silvosinho', 'Thomas Nicolas Silva Rangel']
# ['Jonas', 'Jonas Gomes de Sousa']
# ['Defendi', 'Rodrigo Defendi']
# ['Dorca', 'Albert Dorca Masó']
# ['Bremer', 'Gleison Bremer Silva Nascimento']
# ['Rodrigo', 'Rodrigo Alves Soares']
# ['Luso', 'Luis Eduardo Delgado Pacheco']
# ['Eguaras', 'Iñigo Eguaras Álvarez']
# ['Braga', 'Bruno Manuel Araújo Braga']
# ['Ortuño', 'Alfredo Ortuño Martínez']
# ['Bismark', 'Bismark de Araújo Ferreira']
# ['William', 'William Fernando da Silva']
# ['Núrio', 'Núrio Domingos Matias Fortuna']
# ['Casadesús', 'Víctor Manuel Casadesús Castaño']
# ['Ferro', 'Francisco Reis Ferreira']
# ['Bernardo', 'Bernardo Víctor Cruz Torres']
# ['Puertas', 'Antonio José Rodríguez Díaz']
# ['Sílvio', 'Sílvio Manuel Azevedo Ferreira Sá Pereira']
# ['Nenê', 'Ânderson Miguel da Silva']
# ['Toribio', 'Daniel Toribio Gutiérrez']
# ['Dodô', 'Domilson Cordeiro dos Santos']
# ['Waguininho', 'Wagner da Silva Souza']
# ['Puado', 'Javier Puado Díaz']
# ['Anuar', 'Anuar Mohamed Tuhami']
# ['Campillo', 'Antonio Campillo Medina']
# ['Óscar', 'Óscar Rodríguez Arnaiz']
# ['Rodri', 'Rodrigo Ríos Lozano']
# ['Jhonatan', 'Jhonatan Luiz da Siqueira']
# ['Fidel', 'Fidel Chaves de la Torre']
# ['Juanjo', 'Juan José Ciércoles Sagra']
# ['Denilson', 'Denilson Pereira Junior']
# ['Alberto', 'Alberto Jiménez Benítez']
# ['Pêpê', 'Pedro Filipe Figueiredo Rodrigues']
# ['Ilori', 'Tiago Abiola Delfim Almeida Ilori']
# ['Sandaza', 'Francisco José Sandaza Asensio']
# ['Alex', 'Alexandre Henrique Gonçalves De Freitas']
# ['Kanu', 'Rubenilson dos Santos da Rocha']
# ['Aguilera', 'Juan Aguilera Aguilera Núñez']
# ['Neris', 'Hueglo dos Santos Neris']
# ['Hernán', 'Hernán Daniel Santana Trujillo']
# ['César', 'César Henrique Martins']
# ['Ratón', 'Álvaro López Ratón']
# ['Brahim', 'Brahim Díaz']
# ['Avto', 'Avtandil Ebralidze']
# ['Gabrielzinho', 'Gabriel Airton de Souza']
# ['Aridai', 'Aridai Cabrera Suárez']
# ['Macedo', 'Wanderson de Macedo Costa']
# ['Nando', 'Fernando García Puchades']
# ['Juanma', 'Juan Manuel Delgado Lloria']
# ['Chuli', 'Manuel Jesús Vázquez Florido']
# ['Baraka', 'Andrés Fernandes Gonçalves']
# ['Nadjack', 'Eliseu Mendja Nadjack Soares Cassamá']
# ['Olmo', 'Jesús Olmo Lozano']
# ['Zequinha', 'José Egas dos Santos Branco']
# ['Alemão', 'Fágner Ironi Daponte']
# ['Jair', 'Jair Eduardo Britto da Silva']
# ['Ricardinho', 'Ricardo Cavalcante Mendes']
# ['Romário', 'Romário Pereira Sipião']
# ['Basilio', 'Basilio Sancho Agudo']
# ['Juande', 'Juan de Dios Prados López']
# ['Nacho', 'Ignacio Agustín Sánchez Romo']
# ['Lucas', 'Lucas Alves de Araujo']
# ['Valverde', 'Carlos Valverde Doblado']
# ['Alfred', 'Alfred Planas Moyà']
# ['Renato', 'Renato Augusto Santos Júnior']
# ['Higinio', 'Higinio Marín Escavy']
# ['Trujillo', 'Ángel Trujillo Canorea']
# ['Lucas', 'Lucas de Souza Cunha']
# ['Abdón', 'Abdón Prats Bastidas']
# ['Hugo', 'Hugo Claudio Vallejo Avilés']
# ['Avilés', 'Javier Avilés Cortés']
# ['Willy', 'Luis Alfonso Ledesma Galán']
# ['Allef', 'Allef de Andrade Rodrigues']
# ['Loureiro', 'Miguel Loureiro Ameijenda']
# ['Henrique', 'Henrique de Andrade Silva']
# ['Viti', 'Víctor Álvarez Rozada']
# ['Damià', 'Damià Sabater Tous']
# ['Jaquité', 'João Lamine Jaquité']
# ['Mayoral', 'David Mayoral Lastras']
# ['Junio', 'Junio Ricardo da Rocha']
# ['Iury', 'Iury Lirio Freitas de Castilho']
# ['Brugui', 'Roger Brugué Ayguade']
# ['Pité', 'Luís Pedro de Freitas Pinto Trabulo']
# ['Álvaro', 'Álvaro Fernández Llorente']
# ['Marcel', 'Marcel Alves Pereira']
# ['Henrique', 'Henrique Gelain Custódio']
# ['Andújar', 'David Andújar Jiménez']
# ['Kaká', 'Everton Ferreira Guimarães']
# ['Lolo', 'Emmanuel González Rodríguez']
# ['Genís', 'Genís Montolio Lafuente']
# ['Montero', 'Francisco Montero Rubio']
# ['Leonardo', 'Leonardo Navacchio']
# ['Bura', 'Jorge Braíma Candé Nogueira']
# ['Joaquín', 'Joaquín Muñoz Benavides']
# ['Ángel', 'Ángel Moreno Morcillo']
# ['Endika', 'Endika Irigoien Bravo']
# ['Carlitos', 'Juan Carlos Moreno Rojo']
# ['Ángel', 'Ángel García Cabezali']
# ['Sito', 'Andrés Pascual Santonja']
# ['Montoro', 'Adrián Hernández Montoro']
# ['Jimmy', 'Jaime Suárez Juesas']
# ['Kike', 'Enrique Gómez Hermoso']
# ['Antón', 'Antón Escobar Tapiias']
# ['Prendes', 'Alejandro Prendes Reina']
# ['Meseguer', 'Luis Meseguer Villanueva']
# ['Parra', 'Carlos Parra Arauzo']
# ['Leja', 'Alberto Lejárraga Rubio']
# ['Oleaga', 'Hodei Oleaga Alarcia']
# ['Algobia', 'Ángel Algobia Esteves']
# ['Altube', 'Diego Altube Suárez']
# ['Mollejo', 'Víctor Mollejo Carpintero']
# ['Tellado', 'Adrián Tellado']
# ['Maikel', 'Antonio Nieves Martín']
# ['Morro', 'Miguel Ángel Morro Muñoz']
# ['Ruan', 'Ruan Gregório Teixeira']
# ['Strefezza', 'Gabriel Tadeu Strefezza Rebecato']
# ['Taliby', 'Taliby Konate Diakité']
# ['Philippe', 'Philippe Almeida Costa']
# ['Patrick', 'Patrick Ferreira Souza']
# ['Pedrosa', 'Daniel Pedrosa Loureiro']
# ['Javito', 'Javier Almerge Viñuales']
# ['Aparicio', 'Javier Aparicio Gómez']
# ['Lucas', 'Lucas Ribeiro Fonseca']
# ['Grifi', 'David Grifell Monreal']
# ['Reyes', 'David Reyes Segura']
# ['Irizo', 'José Manuel Irizo Fernández']
# ['Fabio', 'Fabio De Sousa Silva']
# ['Montes', 'Èric Montes Arce']
# ['Ramón', 'Ramón Rodríguez da Silva']
# ['Garijo', 'Jaime Garijo']
# ['Baselga', 'Marcos Baselga García']
# ['Adrián', 'Adrián Real Canales']
# ['Altamirano', 'Diego Altamirano']
# ['Lombo', 'Pablo Lombo Suárez']
# ['Salcedo', 'José Antonio Salcedo Sánchez']
# ['Genaro', 'Genaro  Rodríguez Serrano']
# ['Ibañez', 'Roger Ibañez Da Silva']
# ['Leandro', 'Leandro Montagud Balaguer']
# ['Dome', 'Domènec Estorach Ruedas']
# ['Iván', 'Iván Navarro Mateos']
# ['Kiki', 'Juan Antonio Díaz Sanchez']
# ['Campos', 'Gaizka Campos Bahíllo']
# ['Guillamón', 'Hugo Guillamón Sammartín']
# ['Cordero', 'Arturo Cordero López']
# ['Álex', 'Álex Pachón Párraga']
# ['Aarón', 'Aarón Escandell']
# ['Kike', 'Enrique Pérez Muñoz']
# ['Edgar', 'Edgar González Estrada']
# ['Moncayola', 'Jon Moncayola Tollar']
# ['Martín', 'Martín Pascual Castillo']
# ['Bueno', 'Wellington Daniel Bueno']
# ['Viti', 'Víctor Martínez Manrique']
# ['Samuel', 'Samuel Arbelo Hernández']
# ['Rayco', 'Rayco Rodríguez Medina']
# ['Romero', 'Álvaro Romero Morillo']
# ['Perera', 'Antonio Perera Calderón']
# ['Modest', 'Modest Notario Racionero']
# ['Tachi', 'Alberto Rodríguez Baró']
# ['Fachendinho', 'Tiago Vanderlei Fagundes Fachini']
# ['Rafinha', 'Rafael Gimenes da Silva']
# ['Abenza', 'Mario Nicolás Abenza']
# ['Vinicius', 'Caio Vinicius Pirana']
# ['Hernáiz', 'Álvaro Hernáiz Perera']
# ['Pepê', 'João Pedro Vilardi Pinto']
# ['Otaño', 'Ignacio Otaño Aranburu']
# ['Thallyson', 'Thallyson Augusto Tavares Dias']
# ['Bolaños', 'Roberto Jesús Melián Bolaños']
# ['Chema', 'José Manuel Núñez Martín']
# ['Josín', 'Jose Antonio Martinez Álvarez']
# ['Robinho', 'Robinho Barbosa de Lisboa']
# ['Wanderson', 'Wanderson Carvalho Oliveira']
# ['Isi', 'Isaac Gómez Sánchez']
# ['Vallès', 'Enric Vallès Prat']
# ['Guerrero', 'Fernando Delgado Guerrero']
# ['Uxío', 'Uxío Da Pena Gutiérrez']
# ['Quintillá', 'Xavier Quintillá Guasch']
# ['Clemente', 'Enrique Clemente Maza']
# ['PC', 'Victor Pagliari Giro']
# ['Jauregi', 'Eneko Jauregi Escobar']
# ['Tuta', 'Lucas Silva Melo']
# ['Pistu', 'Iván Jorge Vegas']
# ['Miravent', 'Albert Miravent Sans']
# ['Fornos', 'Enrique Fornos Domínguez']
# ['Oribe', 'Jordi Oribe Manzano']
# ['Jaime', 'Jaime Sánchez Muñoz']
# ['Guerrero', 'Adrià Guerrero Aguilar']
# ['Arribas', 'Óscar Arribas Pasero']
# ['Borja', 'Borja Martínez Giner']
# ['Josemi', 'José Miguel Castañeda Macho']
# ['Neto', 'Alvino Volpi Neto']
# ['Rulo', 'Raúl Prieto Odena']
# ['Kikas', 'João Diogo Alves Rodrigues']
# ['Miguel', 'Miguel De la Fuente Escudero']
# ['Diga', 'Diogo Miguel Guedes Almeida']
# ['Vitinho', 'Victor da Silva']
# ['Luan', 'Luan Leite da Silva']
# ['Jeka', 'Yevhenii Serdiuk']
# ['Echu', 'Jesús Rodríguez Ortuño']
# ['Stoichkov', 'Juan Diego Molina Martínez']
# ['Pablo', 'Pablo Rey Fernández']
# ['Pascu', 'José Pascual Alba Seva']
# ['Jaume', 'Jaume Grau Ciscar']
# ['Robert', 'Roberto González Bayón']
# ['Jesiel', 'Jesiel Cardoso Miranda']
# ['Maguinho', 'Magno José da Silva']
# ['Wanderson', 'Wanderson Santos Pereira']
# ['Valery', 'Valery Fernández Estrada']
# ['Mika', 'Micael Filipe Correia Borges']
# ['Romera', 'José Antonio Romera Navarro']
# ['Kiki', 'Christian Neiva Afonso']
# ['Cidinho', 'Alcides  de Souza Faria Junior']
# ['Vagner', 'Vagner José Dias Goncalves']
# ['Peixotacinho', 'Allison Alan Peixoto Gomes']
# ['Benito', 'Benito Ramírez del Toro']
# ['Caíque', 'Caíque Venâncio Lemes']
# ['Felipe', 'Felipe Alfonso Criado']
# ['Fernando', 'Fernando Martínez Rubio']
# ['Marcelo', 'Marcelo Machado dos Santos']
# ['Muñoz', 'Aihen Muñoz Capellán']
# ['Berrocal', 'Juan Berrocal González']
# ['Luquinhas', 'Lucas Lima Linhares']
# ['Marquitos', 'Marcos García Barreno']
# ['Noblejas', 'Javier García-Noblejas']
# ['Igor', 'Igor Julio dos Santos de Paulo']
# ['Aitor', 'Aitor Fernández López']
# ['Aguado', 'Álvaro Aguado Méndez']
# ['Chumi', 'Juan Brandáriz Movilla']
# ['Ronan', 'Ronan David Jeronimo']
# ['Lelêu', 'Claudionor Souza de Jesus']
# ['Aloísio', 'Aloísio Soares Neto']
# ['Yago', 'Yago César da Silva']
# ['Mateus', 'Mateus dos Santos Castro']
# ['Fidalgo', 'Álvaro Fidalgo Fernández']
# ['Patrick', 'Fábio Patrick Santos Fernandes']
# ['Nanu', 'Eulânio Ângelo Chipela Gomes']
# ['Marcão', 'Marcos Wilson da Silva']
# ['Airam', 'Airam López Cabrera']
# ['Guilherme', 'Guilherme Schettine Guimarães']
# ['Salva', 'Salvador Ferrer Canals']
# ['Danilo', 'Danilo Pereira Da Silva']
# ['Pastrana', 'Víctor Pastrana Carrasco']
# ['Víctor', 'Víctor García Raja']
# ['Nathan', 'Nathan Raphael Pelae Cardoso']
# ['Manu', 'José Manuel Rodríguez Morgade']
# ['Isidoro', 'José Isidoro Gómez Torres']
# ['Leandro', 'Weverson Leandro Oliveira Moura']
# ['Judson', 'Judson Silva Tavares']
# ['Héctor', 'Héctor Hernández Marrero']
# ['Pardo', 'José Antonio Pardo Lucas']
# ['Pipa', 'Gonzalo Ávila Gordón']
# ['Olabe', 'Roberto Olabe Del Arco']
# ['Varela', 'Francisco Miguel Varela Martín']
# ['Erik', 'Erik Roberto Silva do Nascimento']
# ['Gabriel', 'Gabriel dos Santos Magalhães']
# ['Pepelu', 'Jose Luís García Vayá']
# ['Pablo', 'Pablo Diogo Lopes de Lima']
# ['Jano', 'Alejandro Velasco Fariñas']
# ['Fábinho', 'Fabio  Alves Macedo']
# ['Euller', 'Elosman Euller Silva Cavalcanti']
# ['Augusto', 'Augusto Pereira Loureiro']
# ['Chuca', 'Víctor Moya Martínez']
# ['Klauss', 'João Klauss de Mello']
# ['Joca', 'Jorge Samuel  Figueiredo Fernandes']
# ['Botelhinonsa', 'João Rodolfo Botelho Maia']
# ['Morillas', 'David Morillas Jiménez']
# ['Martínez', 'José Antonio Martínez Gil']
# ['Escriche', 'Daniel Escriche Romero']
# ['Miranda', 'Juan Miranda González']
# ['Gaspar', 'Gaspar Panadero Zamora']
# ['Lazo', 'José Carlos Lazo Romero']
# ['Ilsinho', 'Ilson Pereira Dias Júnior']
# ['Cleylton', 'Jose Cleylton de Morais dos Santos']
# ['Jhonnattann', 'Jhonnattann Benites da Conceiçao']
# ['Rufo', 'Ruben Herráiz Alcaraz']
# ['Corpas', 'José Corpas Serna']
# ['Bicho', 'Javier Fernández Abruñedo']
# ['Olavide', 'Miguel Olavide Montes']
# ['Crysan', 'Crysan C. Queiroz Barcelos']
# ['Sancet', 'Oihan Sancet Tirapu']
# ['Derik', 'Derik Osede Prieto']
# ['Adaílton', 'Adaílton dos Santos da Silva']
# ['Abraham', 'Abraham  Minero Fernández']
# ['Jaílson', 'Jaílson Marques Siqueira']
# ['Quintanilla', 'Álex Quintanilla Urionabarrenetxea']
# ['Nano', 'Mariano González Maroto']
# ['Guarrotxena', 'Iker Guarrotxena Vallejo']
# ['Accioly', 'Danildo Jose Sao Pedro Accioly Filho']
# ['Estevãtinho', 'Estevão Danilo Rios Chiamulera']
# ['Charles', 'Charles Fernando Basilio da Silva']
# ['Tekio', 'Sergio Blázquez Sánchez']
# ['Camacho', 'Juan José Camacho Barnola']
# ['Zubiaurre', 'Andoni Zubiaurre Dorronsoro']
# ['Castro', 'Carlos Castro García']
# ['Serginho', 'Sérgio Gabriel da Silva Andrade']
# ['Freire', 'Leandro Freire de Araújo']
# ['Fábio', 'Fábio Szymonek']
# ['Fabrício', 'Fabrício Silva Dornellas']
# ['Toché', 'José Verdú Nicolás']
# ['Getterson', 'Getterson Alves dos Santos']
# ['Samu', 'Fábio Samuel Amorim Silva']
# ['Akieme', 'Sergio Akieme Rodríguez']
# ['Assis', 'Assis Giovanaz']
# ['Tyronne', 'Tyronne Gustavo Del Pino Ramos']
# ['Douglas', 'Douglas da Silva Vieira']
# ['Clemente', 'Paulo Clemente Ventura Raimundo']
# ['Josan', 'José Antonio Ferrández Pomares']
# ['Bastos', 'Ángel Bastos Teijeira']
# ['Yago', 'Yago Henrique Severino dos Santos']
# ['Caro', 'José Antonio Caro Díaz']
# ['Josema', 'José Manuel Sánchez Guillén']
# ['Guruzeta', 'Gorka Guruzeta Rodríguez']
# ['Wellington', 'Wellington Luís de Sousa']
# ['Cristiano', 'Cristiano Pereira Figueiredo']
# ['Carbonell', 'Alejandro Carbonell Vallés']
# ['Hicham', 'Hicham Boussefiane']
# ['Toquero', 'Gaizka Toquero Pinedo']
# ['Edgar', 'Edgar Bruno da Silva']
# ['Pedrosa', 'André Alexandre Antunes Pedrosa']
# ['Etxeberría', 'Markel Etxeberría Mendiola']
# ['Álvaro', 'Álvaro Giménez Candela']
# ['Héctor', 'Héctor Hernández Ortega']
# ['Cesinha', 'Cesar Fernando Silva Melo']
# ['Joaquín', 'Joaquín Fernández Moreno']
# ['Mandi', 'Armando Sosa Peña']
# ['Ícaro', 'Ícaro do Carmo Silva']
# ['Vinícius', 'Paulo Vinícius Souza dos Santos']
# ['Campabadal', 'Eduard Campabadal Claros']
# ['Matos', 'José Joaquín Matos García']
# ['Dalmau', 'Adriàn Dalmau Vaquer']
# ['Delmás', 'Julián Javier Delmás Germán']
# ['Fernández', 'José Manuel Fernández Reyes']
# ['Nouhou', 'Nouhou Tolo']
# ['Bellvís', 'Carlos Bellvís Llorens']
# ['Gorosabel', 'Andoni Gorosabel Espinosa']
# ['Caro', 'José Antonio Caro Martínez']
# ['Querol', 'David Querol Blanco']
# ['Messias', 'Messias Rodrigues Silva Jr.']
# ['Pacheco', 'Pedro Miguel  Salgadinho Pacheco de Melo']
# ['Rafinha', 'Rafael Scapini de Almeida']
# ['Bernabé', 'Bernabé Barragán Maestre']
# ['Elgezabal', 'Unai Elgezabal Udondo']
# ['Lillo', 'Manuel  Castellano Castro']
# ['Pleguezuelo', 'Julio José Pleguezuelo Selva']
# ['Kevin', 'Kevin Vázquez Comesaña']
# ['Carrillo', 'José Ángel Carrillo Casamayor']
# ['Galán', 'Ernesto Galán Iñigo']
# ['Alcatraz', 'Gilberto García Olarte']
# ['Jairo', 'Jairo Izquierdo González']
# ['Pejiño', 'Francisco Jesús Crespo García']
# ['Dálcio', 'Euciodálcio Gomes']
# ['Soriano', 'Juan Soriano Oropesa']
# ['Carlinhos', 'Carlos Antonio de Souza Júnior']
# ['Casto', 'Casto Espinosa Barriga']
# ['Merquelanz', 'Martín Merquelanz']
# ['Quini', 'Joaquín Marín Ruiz']
# ['Jadson', 'Jadson Silva de Morais']
# ['Evander', 'Evander da Silva Ferreira']
# ['Catena', 'Alejandro Catena Marugán']
# ['Muralha', 'Luiz Philipe Lima de Oliveira']
# ['Jael', 'Jael Ferreira Vieira']
# ['Rochinha', 'Diogo Filipe Rocha Costa']
# ['Undabarrena', 'Iker Undabarrena Martínez']
# ['Tomané', 'António Manuel Fernandes Mendes']
# ['Cotán', 'Antonio Jesús Cotán Pérez']
# ['Verdasca', 'Diogo Sousa Verdasca']
# ['Raillo', 'Antonio José Raillo Arenas']
# ['Aguza', 'Sergio Aguza Santiago']
# ['Nicolas', 'David Nicolas Andrade']
# ['Niltinho', 'Nilton Soares Rodrigues']
# ['Emerson', 'Emerson Leite De Souza']
# ['Auro', 'Auro Alvaro da Cruz Junior']
# ['Buatu', 'Jonathan Buatu Mananga']
# ['Momo', 'Jerónimo Figueroa Cabrera']
# ['Servando', 'Servando Sánchez Barahona']
# ['Cris', 'Bruno Cristiano Carvalho Santos']
# ['Pomares', 'Carlos Pomares Rayo']
# ['Verza', 'José Antonio García Rabasco']
# ['Wellington', 'Wellington Nascimento Carvalho']
# ['Mika', 'Michael Simões Domingues']
# ['Baena', 'José Raúl Baena Urdiales']
# ['Farley', 'Farley Vieira Rosa']
# ['Palanca', 'Miguel Palanca Fernández']
# ['Josete', 'José Antonio Malagón Rubio']
# ['Ripa', 'Adrián Ripa Cruz']
# ['Miguelón', 'Miguel Juan Llambrich']
# ['Leandrinho', 'Leandro de Lima Silva']
# ['Santamaría', 'Roberto Santamaría Ciprián']
# ['Alfaro', 'Alejandro Alfaro Ligero']
# ['Carvamelinho', 'Samuel Thomas Carvalho Melo']
# ['Linares', 'Miguel Linares Cólera']
# ['Enzo', 'Enzo Alan Zidane Fernández']
# ['Gégé', 'Admilson E. Dias de Barros']
# ['Iago', 'Iago Azevedo dos Santos']
# ['Cifu', 'Miguel Ángel Garrido Cifuentes']
# ['Reinildo', 'Reinildo Isnard Mandava']
# ['Nano', 'Alexander Mesa Travieso']
# ['Pinillos', 'Daniel Pinillos González']
# ['Magno', 'Magno Damasceno Santos da Cruz']
# ['Villalibre', 'Asier Villalibre Molina']
# ['Zapater', 'Alberto Zapater Arjol']
# ['Crivellaro', 'Rafael Schuler Crivellaro']
# ['Minhoca', 'Nélson Alexandre Farpelha Estrela']
# ['Fali', 'Rafael Jiménez Jarque']
# ['Matheus', 'Matheus Borges Domingues']
# ['Flávio', 'Flávio da Silva Ramos']
# ['Luisinho', 'Luis Gustavo Melere da Silva']
# ['Licá', 'Luis Carlos Pereira Carneiro']
# ['Rogério', 'Rogério Oliveira da Silva']
# ['Ademilson', 'Ademilson Braga Bispo Júnior']
# ['Kalindi', 'Kalindi Alves de Souza']
# ['Platiny', 'Higor Inácio Platiny de Oliveira Rodrigues']
# ['Joãozinho', 'João Carlos Reis Graça']
# ['Aketxe', 'Ager Aketxe Barrutia']
# ['Johannesson', 'Diego Johannesson Pando']
# ['Witi', 'Witiness Chimoio Joao Quembo']
# ['Alef', 'Alef dos Santos Saldanha']
# ['Bóveda', 'Eneko Bóveda Altube']
# ['Derley', 'Vanderley Dias Marinho']
# ['Xisco', 'Francisco Jiménez Tejada']
# ['Lasure', 'Daniel Lasure Briz']
# ['Nino', 'Juan Francisco Martínez Modesto']
# ['Iriome', 'Iriome González González']
# ['Germán', 'Germán Sánchez Barahona']
# ['Nolaskoain', 'Peru Nolaskoain Esnal']
# ['Saúl', 'Saúl García Cabrero']
# ['Lionn', 'José Lionn Barbosa de Lucena']
# ['Rubén', 'Rubén Iván Martínez Andrade']
# ['Nono', 'David González Plata']
# ['Aridane', 'Aridane Hernández Umpiérrez']
# ['Akapo', 'Carlos Akapo Martínez']
# ['Ewandro', 'Ewandro Felipe de Lima Costa']
# ['Lombán', 'David Rodríguez Lombán']
# ['Barbosaldinho', 'Luciano Renato Barbosa Baumer']
# ['Felipe', 'Felipe Aliste Lopes']
# ['Arsénio', 'Arsénio Martins Lafuente Nunes']
# ['Patrick', 'Patrick De Oliveira Vieira']
# ['Deivid', 'David Omar Rodríguez Barrera']
# ['Pombaxinho', 'Arturo Jonaldo Pombal de Faria']
# ['Mano', 'Luís Miguel Lopes Mendes']
# ['Arroyo', 'Álvaro Arroyo Martínez']
# ['Tito', 'Roberto Román Triguero']
# ['Adriano', 'Carlos Adriano de Souza Cruz']
# ['Tramontinaldo', 'Márcio Anderson Tramontino Sá']
# ['Ukra', 'André Filipe Alves Monteiro']
# ['Adryan', 'Adryan Oliveira Tavares']
# ['Nauzet', 'Cecilio Nauzet Pérez González']
# ['Botía', 'Alberto Tomás Botía Rabasco']
# ['Dorado', 'José Antonio Dorado Ramírez']
# ['Evandro', 'Evandro Goebel']
# ['Fredy', 'Alfredo Kulembe Ribeiro']
# ['Bueno', 'Alberto  Bueno Calvo']
# ['Fede', 'Federico San Emeterio Díaz']
# ['Gumbau', 'Gerard Gumbau Garriga']
# ['Antoñito', 'Antonio Jesús Regal Angulo']
# ['Jota', 'João Tiago Serrão Garcês']
# ['Vinícius', 'Carlos Vinícius Alves Morais']
# ['Artur', 'José Artur de Lima Junior']
# ['Varela', 'Silvestre Manuel Gonçalves Varela']
# ['Pita', 'Carlos Pita González']
# ['Escassi', 'Alberto Escassi Oliva']
# ['Elsinho', 'Elson Ferreira de Souza']
# ['Garrido', 'Jon Ander Garrido Moracia']
# ['Guillermo', 'Guillermo Fernández Hierro']
# ['Paulinho', 'Paulo Henrique Sampaio Filho']
# ['Welinton', 'Welinton Souza Silva']
# ['Mossa', 'José María Angresola Jiménez']
# ['Paulolettinho', 'Paulo Bernard Alves Coelho']
# ['Shikabala', 'Mahmoud Abdel Razek Fadlallah']
# ['Felipe', 'Felipe Trevizan Martins']
# ['Jota', 'João Pedro Neves Filipe']
# ['Ewerton', 'Ewerton da Silva Pereira']
# ['Cyriac', 'Cyriac Gohi Bi Zoro']
# ['Osmar', 'Osmar Ibáñez Barba']
# ['Susaeta', 'Néstor Susaeta Jaurrieta']
# ['Somália', 'Calmon Wergiton do Rosário']
# ['Rodolfo', 'Rodolfo Almeida Guimarães']
# ['Babanco', 'Elvis Manuel Monteiro Macedo']
# ['Eugeni', 'Eugeni Valderrama Domènech']
# ['Lyanco', 'Lyanco Neves Vojnovic']
# ['Naranjo', 'José Manuel García Naranjo']
# ['Serginho', 'Sérgio Antônio Borges Júnior']
# ['Sivera', 'Antonio Sivera Salvá']
# ['Cafú', 'Carlos Miguel Ribeiro Dias']
# ['Elustondo', 'Gorka Elustondo Urkola']
# ['Djalma', 'Djalma Braume Manuel Abel Campos']
# ['Fábio', 'Fábio Pereira da Silva']
# ['Xavier', 'António Manuel Pereira Xavier']
# ['Vigaray', 'Carlos Martín Vigaray']
# ['Oier', 'Oier Sanjurjo Maté']
# ['Danilo', 'Danilo Teodoro Soares']
# ['Ontiveros', 'Javier Ontiveros Parra']
# ['Tiago', 'Tiago Pagnussat']
# ['Maycon', 'Maycon de Andrade Barberan']
# ['Camacho', 'João Pedro Gomes Camacho']
# ['Jandrei', 'Jandrei Chitolina Carniel']
# ['Ayrton', 'Ayrton Lucas Dantas de Medeiros']
# ['Marcão', 'Marcos Nascimento Teixeira']
# ['Allano', 'Allano Brendon de Souza Lima']
# ['Martos', 'Francisco Javier Martos Espigares']
# ['Murilo', 'Murilo de Souza Costa']
# ['René', 'René Román Hinojo']
# ['Bracali', 'Rafael Wihby Bracalli']
# ['Charles', 'Charles Marcelo da Silva']
# ['Rogerinho', 'Rogerio De Assis Silva Coutinho']
# ['Felipe', 'Felipe Martins']
# ['Simy', 'Simeon Tochukwu Nwankwo']
# ['Costinha', 'João José  Pereira da Costa']
# ['Claiton', 'Claiton Machado dos Santos']
# ['Salomão', 'Diogo Ferreira Salomão']
# ['Jairinhazo', 'Jairo Ralph Resende dos Santos']
# ['Clerc', 'Carlos Clerc Martínez']
# ['Guitián', 'Alberto Guitián Ceballos']
# ['Angulo', 'Igor Angulo Albóniga']
# ['Joselu', 'José Luís Moreno Barroso']
# ['Montoro', 'Ángel Montoro Sánchez']
# ['Alberto', 'Alberto García Cabrera']
# ['Fernandinho', 'Luiz Fernando Pereira da Silva']
# ['Porphirinho', 'R. Nicholas Porfírio Jardim']
# ['Carlos', 'Carlos Alberto Carvalho Silva Jr.']
# ['Juankar', 'Juan Carlos Pérez López']
# ['Pimentiscinho', 'Miguel Edson Pimenta Baia']
# ['Dener', 'Dener Gomes Clemente']
# ['Patric', 'Patricio Gabarrón Gil']
# ['Isaías', 'Isaías Sánchez Cortés']
# ['Molinero', 'Francisco José Molinero Calderón']
# ['Laure', 'Laureano Sanabria Ruiz']
# ['Ailton', 'Ailton Ferreira Silva']
# ['Bobô', 'Deivson Rogério Da Silva']
# ['Hervías', 'Pablo Hervías Rubio']
# ['Juanfran', 'Juan Francisco Moreno Fuertes']
# ['Chiquinho', 'Francisco Leonel Lima Silva Machado']
# ['Pelé', 'Judilson Mamadu Tuncará Gomes']
# ['Wallace', 'Wallace Reis da Silva']
# ['Douglas', 'Douglas Chagas Matos']
# ['Amilton', 'Amilton Minervino da Silva']
# ['Calero', 'Fernando Calero Villa']
# ['Kuca', 'Jaílton Alves Miranda']
# ['Cucurella', 'Marc Cucurella Saseta']
# ['Galeno', 'Wenderson Nascimento Galeno']
# ['Perdigão', 'Jeferson Fernandes Macedo']
# ['Cristiano', 'Cristiano da Silva']
# ['Samir', 'Samir Caetano de Souza Santos']
# ['Munir', 'Munir Mohand Mohamedi']
# ['Jorge', 'Jorge Marco de Oliveira Moraes']
# ['Élton', 'Élton José Xavier  Gomes']
# ['Alexis', 'Alexis Ruano Delgado']
# ['Cifuentes', 'Alberto Cifuentes Martínez']
# ['Aitor', 'Aitor Fernández']
# ['Vadillo', 'Álvaro Vadillo Cifuentes']
# ['Manquillo', 'Javier Manquillo Gaitán']
# ['Guerrero', 'Miguel Ángel Guerrero Martín']
# ['Vesga', 'Mikel Vesga Arruti']
# ['Welthon', 'Welthon Fiel Sampaio']
# ['Camilo', 'Camilo da Silva Sanvezzo']
# ['Baiano', 'Wanderson  Souza Carneiro']
# ['Ricardo', 'Ricardo Jorge Novo Nunes']
# ['Gabrìel', 'Gabriel Vasconelos Ferreira']
# ['Adama', 'Adama Traoré Diarra']
# ['Padilhisco', 'Adolfo Heitor Padilha Alves']
# ['Dentinho', 'Bruno Ferreira Bonfim']
# ['Carmona', 'Carlos Carmona Bonet']
# ['Quique', 'Enrique González Casín']
# ['Patric', 'Anderson Patric Aguiar Oliveira']
# ['Zainadine', 'Zainadine Chavango Júnior']
# ['Arana', 'Guilherme Arana Lopes']
# ['Bigas', 'Pedro Bigas Rigo']
# ['Rafael', 'Rafael Cabral Barbosa']
# ['Crespo', 'José Ángel Crespo Rincón']
# ['Ewerton', 'Ewerton José Almeida Santos']
# ['Riesgo', 'Asier Riesgo Unamuno']
# ['Pozo', 'José Ángel Pozo la Rosa']
# ['Maurício', 'Maurício de Carvalho António']
# ['Edvaldisco', 'Edvaldo Flávio Rebelo de Freit']
# ['William', 'William de Asevedo Furtado']
# ['Bojan', 'Bojan Krkić Pérez']
# ['Renatinho', 'Renato Ribeiro Calixto Aguiar']
# ['Kahraba', 'Mahmoud Abdel Moneim']
# ['Seoane', 'Fernando Seoane Antelo']
# ['Lato', 'Antonio Latorre Grueso']
# ['Róber', 'Roberto Suárez Pier']
# ['Gálvez', 'Alejandro Gálvez Jimena']
# ['Jairo', 'Jairo Samperio Bustara']
# ['Joselu', 'José Luis Sanmartín Mato']
# ['Gerson', 'Gerson Santos da Silva']
# ['Eduardo', 'Eduardo dos Reis Carvalho']
# ['Anselmo', 'Anselmo de Moraes']
# ['Zubeldia', 'Igor Zubeldia Elorza']
# ['Bebeto', 'Roberto Jesus Machado Beto Alves']
# ['Ivi', 'Iván López Álvarez']
# ['Francis', 'Francisco Javier Guerrero Martín']
# ['Medrán', 'Álvaro Medrán Just']
# ['Guilherme', 'Guilherme Costa Marques']
# ['Lekue', 'Iñigo Lekue Martínez']
# ['Titi', 'Cristian Chagas Tarouco']
# ['Tarantini', 'Ricardo José Vaz Alves Monteiro']
# ['Pedraza', 'Alfonso Pedraza Sag']
# ['Lafortiscinho', 'Erick Sebastião Laforte Medeiros']
# ['Sequeira', 'Nuno Miguel Ribeiro da Cruz Jerónimo Sequeira']
# ['Rochina', 'Rubén  Rochina Naixes']
# ['Mosquera', 'Pedro Mosquera Parada']
# ['Mexer', 'Edson André Sitoe']
# ['Melero', 'Gonzalo Julián Melero Manzanares']
# ['Hernâni', 'Hernâni Jorge Santos Fortes']
# ['Zeca', 'José Carlos Gonçalves Rodrigues']
# ['Merino', 'Mikel Merino Zazón']
# ['Martín', 'Martín Aguirregabiria']
# ['Timor', 'David Timor Copoví']
# ['Cássio', 'Cássio Albuquerque dos Anjos']
# ['Melendo', 'Óscar Melendo Jiménez']
# ['Sandro', 'Sandro  Ramírez Castillo']
# ['Keko', 'Sergio Gontán Gallardo']
# ['Postigo', 'Sergio Postigo Redondo']
# ['Fabrício', 'Fabrício dos Santos Messias']
# ['Carlitos', 'Carlos Daniel López Huesca']
# ['Jorginhson', 'Jorgino Silas Ruiz Prestes']
# ['Oier', 'Oier Olazábal Paredes']
# ['Bernardo', 'Bernardo Fernandes da Silva Junior']
# ['Bustinza', 'Unai Bustinza Martínez']
# ['Éder', 'Éderzito António Macedo Lopes']
# ['Iraizoz', 'Gorka Iraizoz Moreno']
# ['Kaku', 'Alejandro Romero Gamarra']
# ['Portillo', 'Francisco Portillo Soler']
# ['Rafael', 'Rafael  de Andrade Bittencourt Pinheiro']
# ['Danilo', 'Danilo Barbosa da Silva']
# ['Fransérgio', 'Fransérgio Rodrigues Barbosa']
# ['Palhinha', 'João Maria Lobo Alves Palhinha Gonçalves']
# ['Alcalá', 'Pedro Alcalá Guirado']
# ['Rolando', 'Rolando Jorge Pires da Fonseca']
# ['Adrián', 'Adrián López Álvarez']
# ['Jonathas', 'Jonathas de Jesus Maurício']
# ['Jemerson', 'Jemerson de Jesus Nascimento']
# ['Victildinho', 'Victor Martin Maia Padilha']
# ['Jaume', 'Jaume Domenech Sánchez']
# ['Camarasa', 'Víctor Camarasa Ferrando']
# ['Rafinha', 'Márcio Rafael Ferreira de Souza']
# ['Vieirinha', 'Adelino André Vieira de Freitas']
# ['Iturraspe', 'Ander Iturraspe Derteano']
# ['Joelinton', 'Joelinton Apolinário de Lira']
# ['Beto', 'António Alberto Bastos Pimparel']
# ['Yoel', 'Yoel Rodríguez Oterino']
# ['Gil', 'Carlos Gilberto do Nascimento Silva']
# ['Soldado', 'Roberto Soldado Rillo']
# ['Naldo', 'Edinaldo Gomes Pereira']
# ['Josué', 'Josué Filipe Soares Pesqueira']
# ['Claudemir', 'Claudemir Domingues de Souza']
# ['Embarba', 'Adrián Embarba Blazquez']
# ['Héldon', 'Héldon Augusto Almeida Ramos']
# ['Dalbert', 'Dalbert Henrique Chagas Estevão']
# ['Gomes', 'Heurelho da Silva Gomes']
# ['Jesé', 'Jesé Rodríguez Ruiz']
# ['Juanmi', 'Juan Miguel Jiménez López']
# ['Otávio', 'Otávio Henrique Passos Santos']
# ['Tozé', 'António José Pinheiro Carvalho']
# ['Vieirundinho', 'Danilo Manuel Vieira Espíndola']
# ['Angeliño', 'José Ángel Esmoris Tasende']
# ['Jony', 'Jonathan Rodríguez Menéndez']
# ['Sergio', 'Sergio Álvarez Conde']
# ['Sidcley', 'Sidcley Ferreira Pereira']
# ['Cote', 'José Ángel Valdés Díaz']
# ['Danilo', 'Danilo Larangeira']
# ['Varela', 'Fernando Lopes dos Santos Varela']
# ['Douglas', 'Douglas Renato de Jesus']
# ['Laguardia', 'Víctor Laguardia Cisneros']
# ['Maurício', 'Maurício José da Silveira Júnior']
# ['Wendell', 'Wendell Nascimento Borges']
# ['Vallejo', 'Jesús Vallejo Lázaro']
# ['Formosandrinho', 'Estevão Daniel Formoso Serpa']
# ['Pablo', 'Pablo Nascimento Castro']
# ['Jô', 'João Alves de Assis Silva']
# ['Munir', 'Munir El Haddadi']
# ['Marçal', 'Fernando Marçal de Oliveira']
# ['Mata', 'Jaime Mata Arnaiz']
# ['Montoya', 'Martín Montoya Torralbo']
# ['Arbilla', 'Anaitz Arbilla Zabala']
# ['Gazzolisco', 'Gérson Adriano Gutierres Serra']
# ['Bruno', 'Bruno González Cabrera']
# ['Wendel', 'Marcus Wendel Valle da Silva']
# ['Gervinho', 'Gervais Lombe Yao Kouassi']
# ['Guilherme', 'Guilherme Alvim Marinato']
# ['Bernat', 'Juan Bernat Velasco']
# ['Matheus', 'Matheus Lima Magalhães']
# ['Gabriel', 'Gabriel Appelt Pires']
# ['Bruma', 'Armindo Tué Na Bangna']
# ['Bastos', 'Bartolomeu Jacinto Quissanga']
# ['Petros', 'Petros Matheus dos Santos Araujo']
# ['Granell', 'Àlex Granell Nogué']
# ['Trezeguet', 'Mahmoud Hassan']
# ['Yeray', 'Yeray Álvarez López']
# ['Everticinho', 'Everton Jorge Simão Resende']
# ['Wesley', 'Wesley Moraes Ferreira da Silva']
# ['Ángel', 'Ángel Luís Rodríguez Díaz']
# ['Eder', 'Eder Citadin Martins']
# ['Marcelo', 'Marcelo Antônio Guedes Filho']
# ['Bruno', 'Bruno  Soriano Llido']
# ['Fernando', 'Fernando Francisco Reges']
# ['Mariano', 'Mariano Ferreira Filho']
# ['Susaeta', 'Markel Susaeta Laskurain']
# ['Souza', 'Josef de Souza Dias']
# ['Iborra', 'Vicente Iborra de la Fuente']
# ['Rafael', 'Rafael Pereira da Silva']
# ['Danilo', 'Danilo Luiz da Silva']
# ['Nolito', 'Manuel Agudo Durán']
# ['Campaña', 'José Ángel Gómez Campaña']
# ['Deulofeu', 'Gerard Deulofeu Lázaro']
# ['Pozuelo', 'Alejandro Pozuelo Melero']
# ['Roger', 'Roger Martí Salvador']
# ['Soares', 'Francisco das Chagas Soares dos Santos']
# ['Raphinha', 'Raphael Dias Belloli']
# ['Loren', 'Lorenzo Morón García']
# ['Marcano', 'Iván Marcano Sierra']
# ['Beñat', 'Beñat Etxebarria Urkiaga']
# ['Antunes', 'Vitorino Gabriel  Pacheco Antunes']
# ['Sidnei', 'Sidnei Rechel da Silva Júnior']
# ['Camacho', 'Ignacio Camacho Barnola']
# ['Guaita', 'Vicente Guaita Panadero']
# ['Maicon', 'Maicon Pereira Roque']
# ['Portu', 'Cristian Portugués Manzanera']
# ['Bernard', 'Bernard  Anício Caldeira Duarte']
# ['Fred', 'Frederico R. de Paula Santos']
# ['Pacheco', 'Fernando Pacheco Flores']
# ['Gayà', 'José Luís Gayà Peña']
# ['Williams', 'Iñaki Williams Arthuer']
# ['Rafa', 'Rafael Alexandre Fernandes Ferreira da Silva']
# ['Raúl', 'Raúl Michel Melo da Silva']
# ['Mariano', 'Mariano Díaz Mejía']
# ['Nani', 'Luís Carlos Almeida da Cunha']
# ['Hulk', 'Givanildo Vieira de Souza']
# ['Muniain', 'Iker Muniain Goñi']
# ['Vitolo', 'Víctor Machín Pérez']
# ['Morales', 'José Luis Morales Nogales']
# ['Aduriz', 'Aritz Aduriz Zubeldia']
# ['Jardel', 'Jardel Nivaldo Vieira']
# ['Adán', 'Antonio Adán Garrido']
# ['Pedro', 'Pedro Eliezer Rodríguez Ledesma']
# ['Bartra', 'Marc Bartra Aregall']
# ['Morata', 'Álvaro Borja Morata Martín']
# ['Rafinha', 'Rafael Alcântara do Nascimento']
# ['Grimaldo', 'Alejandro Grimaldo García']
# ['Casillas', 'Iker Casillas Fernández']
# ['Sokratis', 'Sokratis Papastathopoulos']
# ['Jonas', 'Jonas Gonçalves Oliveira']
# ['Oscar', 'Oscar dos Santos Emboaba Júnior']
# ['Canales', 'Sergio Canales Madrazo']
# ['Neto', 'Norberto Murara Neto']
# ['Pizzi', 'Luís Miguel Afonso Fernandes']
# ['Rodrigo', 'Rodrigo Moreno Machado']
# ['Suso', 'Jesús Joaquín Fernández Sáez']
# ['Quaresma', 'Ricardo Andrade Quaresma Bernardo']
# ['Falcao', 'Radamel Falcao García Zárate']
# ['Miranda', 'João Miranda de Souza Filho']
# ['Naldo', 'Ronaldo  Aparecido Rodrigues']
# ['Willian', 'Willian Borges da Silva']
# ['Illarramendi', 'Asier Illarramendi Andonegi']
# ['Allan', 'Allan Marques Loureiro']
# ['Pepe', 'Képler Laveran Lima Ferreira']
# ['Paulinho', 'José Paulo Bezzera Maciel Júnior']
# ['Parejo', 'Daniel Parejo Muñoz']
# ['Koke', 'Jorge Resurrección Merodio']
# ['Carvajal', 'Daniel Carvajal Ramos']
# ['Marquinhos', 'Marcos  Aoás Corrêa']
# ['Saúl', 'Saúl Ñíguez Esclápez']
# ['Azpilicueta', 'César Azpilicueta Tanco']
# ['Ederson', 'Ederson Santana de Moraes']
# ['Alisson', 'Alisson Ramses Becker']
# ['Piqué', 'Gerard Piqué Bernabéu']
# ['Coutinho', 'Philippe Coutinho Correia']

# %%
# Check assertion 1
for tp in lines:
    numname = len(tp.split(',')[0].split(' '))
    if numname==2:
        fn = tp.split(',')[0].split(' ')[0]
        surname = tp.split(',')[0].split(' ')[1]
        fullname = tp.split(',')[1]
        if surname in fullname.split(' '):
            if fullname.split(' ').index(surname)==0:
                print(surname + ' ---> ' + fullname)
# Out:
# André ---> André Filipe Brás André
# Chan ---> Chan Kim
# Gang ---> Gang Feng
# Xiaoxuan ---> Xiaoxuan Ji
# Yuqin ---> Yuqin Gao
# Shilong ---> Shilong Wang
# Hui ---> Hui Zhang
# Guoyuan ---> Guoyuan Yang
# Peilei ---> Peilei Cai
# Jinze ---> Jinze Wang
# Liuyu ---> Liuyu Duan
# Jianfei ---> Jianfei Zhao
# Tang ---> Tang Chen
# Junlin ---> Junlin Chen
# Seong-Hoon ---> Seong-Hoon Cheon
# Lario ---> Lario Martínez Jerónimo Manuel
# Wai-Tsun ---> Wai-Tsun Dai
# Weicheng ---> Weicheng Wang
# Ilgyu ---> Ilgyu Park
# Ogude ---> Ogude Emmanuel Ifeanyi
# Djené ---> Djené Dakonam Ortega

# %%
['A', 'Bv', 'Def'].index('Bv')
# Out:
# 1
